# %%
import pandas as pd
import os

# %%
raw_data_path = '../AFOLU/yf_agrc_raw_data'
raw_data_file_name = 'FAOSTAT_crop_data.csv'

# %%
# Import raw data from FAO csv file
raw_data_df = pd.read_csv(os.path.join(raw_data_path, raw_data_file_name))
raw_data_df.head()
# Out:
#   Domain Code                        Domain Area Code (ISO3)         Area  \
# 0         QCL  Crops and livestock products              AFG  Afghanistan
# 1         QCL  Crops and livestock products              AFG  Afghanistan
# 2         QCL  Crops and livestock products              AFG  Afghanistan
# 3         QCL  Crops and livestock products              AFG  Afghanistan
# 4         QCL  Crops and livestock products              AFG  Afghanistan
#
#    Element Code Element  Item Code (CPC)               Item  Year Code  Year  \
# 0          5412   Yield           1371.0  Almonds, in shell       2011  2011
# 1          5412   Yield           1371.0  Almonds, in shell       2012  2012
# 2          5412   Yield           1371.0  Almonds, in shell       2013  2013
# 3          5412   Yield           1371.0  Almonds, in shell       2014  2014
# 4          5412   Yield           1371.0  Almonds, in shell       2015  2015
#
#     Unit   Value Flag Flag Description
# 0  kg/ha  4500.0    A  Official figure
# 1  kg/ha  4596.0    A  Official figure
# 2  kg/ha  2991.0    A  Official figure
# 3  kg/ha  1999.6    A  Official figure
# 4  kg/ha  1652.1    A  Official figure

# %%
# Drop irrelevant columns and modify names to match SISEPUEDE input style
yf_df = raw_data_df[['Area Code (ISO3)', 'Area', 'Item', 'Year', 'Value']]
yf_df = yf_df.rename(columns={'Area Code (ISO3)':'iso_code3', 'Area':'Nation'})
yf_df.head()
# Out:
#   iso_code3       Nation               Item  Year   Value
# 0       AFG  Afghanistan  Almonds, in shell  2011  4500.0
# 1       AFG  Afghanistan  Almonds, in shell  2012  4596.0
# 2       AFG  Afghanistan  Almonds, in shell  2013  2991.0
# 3       AFG  Afghanistan  Almonds, in shell  2014  1999.6
# 4       AFG  Afghanistan  Almonds, in shell  2015  1652.1

# %%
yf_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107993 entries, 0 to 107992
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   iso_code3  107993 non-null  object
#  1   Nation     107993 non-null  object
#  2   Item       107993 non-null  object
#  3   Year       107993 non-null  int64
#  4   Value      107993 non-null  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
# Checking for null values
yf_df.isnull().sum()
# Out:
# iso_code3    0
# Nation       0
# Item         0
# Year         0
# Value        0
# dtype: int64

# %%
# Importing crosswalk file
cw_df = pd.read_csv("https://raw.githubusercontent.com/jcsyme/sisepuede/main/ref/data_crosswalks/fao_crop_categories.csv")
cw_df = cw_df.rename(columns = {"fao_crop" : "Item", "``$CAT-AGRICULTURE$``" : "sisepuede_item"})
cw_df["sisepuede_item"] = cw_df["sisepuede_item"].apply(lambda x : f"yf_agrc_{x}_tonne_ha")
cw_df.head()
# Out:
#                         Item   cat_1           sisepuede_item        super_cat
# 0    Abaca, manila hemp, raw  fibers  yf_agrc_fibers_tonne_ha           fibers
# 1           Agave fibres nes  fibers  yf_agrc_fibers_tonne_ha           fibers
# 2  Agave fibres, raw, n.e.c.  fibers  yf_agrc_fibers_tonne_ha           fibers
# 3          Almonds, in shell    nuts    yf_agrc_nuts_tonne_ha  woody_perennial
# 4        Almonds, with shell    nuts    yf_agrc_nuts_tonne_ha  woody_perennial

# %%
# Creating crosswalk dictionary
cw_dict = dict(zip(cw_df['Item'], cw_df['sisepuede_item']))
# cw_dict

# %%
# Adding a column with sisepuede_items input style using the cw dictionary
yf_df["sisepuede_item"] = yf_df["Item"].replace(cw_dict)

# Queries all data except where item == Mate
yf_df = yf_df.query("Item != 'Maté'")

yf_df.head()
# Out:
#   iso_code3       Nation               Item  Year   Value  \
# 0       AFG  Afghanistan  Almonds, in shell  2011  4500.0
# 1       AFG  Afghanistan  Almonds, in shell  2012  4596.0
# 2       AFG  Afghanistan  Almonds, in shell  2013  2991.0
# 3       AFG  Afghanistan  Almonds, in shell  2014  1999.6
# 4       AFG  Afghanistan  Almonds, in shell  2015  1652.1
#
#           sisepuede_item
# 0  yf_agrc_nuts_tonne_ha
# 1  yf_agrc_nuts_tonne_ha
# 2  yf_agrc_nuts_tonne_ha
# 3  yf_agrc_nuts_tonne_ha
# 4  yf_agrc_nuts_tonne_ha

# %%
# Checking that all the cw mapping was done for all items
yf_df.isnull().sum()
# Out:
# iso_code3         0
# Nation            0
# Item              0
# Year              0
# Value             0
# sisepuede_item    0
# dtype: int64

# %%
# Performing groupby since many items from FAO where mapped to the same category
# yf_df.groupby(["Nation","Year","sisepuede_item"])["Value"].mean()

yf_df_grouped = yf_df.groupby(["iso_code3", "Nation","Year","sisepuede_item"])["Value"].mean().reset_index() 
yf_df_grouped.head()
# Out:
#   iso_code3       Nation  Year  \
# 0       AFG  Afghanistan  2011
# 1       AFG  Afghanistan  2011
# 2       AFG  Afghanistan  2011
# 3       AFG  Afghanistan  2011
# 4       AFG  Afghanistan  2011
#
#                                      sisepuede_item        Value
# 0                          yf_agrc_cereals_tonne_ha  1941.975000
# 1                           yf_agrc_fibers_tonne_ha  1000.000000
# 2                           yf_agrc_fruits_tonne_ha  7305.607692
# 3  yf_agrc_herbs_and_other_perennial_crops_tonne_ha   641.400000
# 4                             yf_agrc_nuts_tonne_ha  3167.300000

# %%
yf_df_pivot = yf_df_grouped.pivot(index=['iso_code3', 'Nation', 'Year'], columns='sisepuede_item', values='Value').reset_index()  
yf_df_pivot.head()
# Out:
# sisepuede_item iso_code3       Nation  Year  yf_agrc_bevs_and_spices_tonne_ha  \
# 0                    AFG  Afghanistan  2011                               NaN
# 1                    AFG  Afghanistan  2012                               NaN
# 2                    AFG  Afghanistan  2013                               NaN
# 3                    AFG  Afghanistan  2014                               NaN
# 4                    AFG  Afghanistan  2015                               NaN
#
# sisepuede_item  yf_agrc_cereals_tonne_ha  yf_agrc_fibers_tonne_ha  \
# 0                               1941.975                   1000.0
# 1                               2252.250                   1100.0
# 2                               2167.725                   1161.8
# 3                               2129.475                   1223.7
# 4                               2022.725                   1198.4
#
# sisepuede_item  yf_agrc_fruits_tonne_ha  \
# 0                           7305.607692
# 1                           7737.607692
# 2                           7541.530769
# 3                           7407.823077
# 4                           7303.730769
#
# sisepuede_item  yf_agrc_herbs_and_other_perennial_crops_tonne_ha  \
# 0                                                          641.4
# 1                                                          675.7
# 2                                                          675.7
# 3                                                          716.7
# 4                                                          720.0
#
# sisepuede_item  yf_agrc_nuts_tonne_ha  yf_agrc_other_annual_tonne_ha  \
# 0                            3167.300                    1383.650000
# 1                            3195.475                    1645.850000
# 2                            2479.775                    1645.850000
# 3                            2157.600                    1296.700000
# 4                            1341.825                     937.233333
#
# sisepuede_item  yf_agrc_other_woody_perennial_tonne_ha  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
#
# sisepuede_item  yf_agrc_pulses_tonne_ha  yf_agrc_rice_tonne_ha  \
# 0                                 827.2                 3200.0
# 1                                 798.9                 3429.3
# 2                                 809.6                 3726.8
# 3                                 752.4                 3643.2
# 4                                 742.9                 3731.7
#
# sisepuede_item  yf_agrc_sugar_cane_tonne_ha  yf_agrc_tubers_tonne_ha  \
# 0                                   30000.0                 11500.00
# 1                                   25000.0                 11476.20
# 2                                   28000.0                 14131.15
# 3                                   23390.0                 12583.30
# 4                                   14471.7                 10624.10
#
# sisepuede_item  yf_agrc_vegetables_and_vines_tonne_ha
# 0                                             8689.96
# 1                                             8601.68
# 2                                             9019.42
# 3                                            10405.68
# 4                                             8312.70

# %%
# Create historical input data
sisepuede_items = yf_df_grouped.sisepuede_item.unique()

for sise_var in sisepuede_items:

    # Convertion Kilograms to Ton (metric) : 1 kg = 0.00110231 t
    yf_df_pivot[sise_var] *= 0.00110231 # Change this value if the raw data is in different units

    if yf_df_pivot[sise_var].isna().any():

        yf_df_pivot[sise_var] = yf_df_pivot.groupby(["Nation"])[sise_var].apply(lambda x: x.interpolate().fillna(method='bfill')).reset_index()[sise_var].fillna(0)
    
    dir_path = f'../AFOLU/{sise_var}/input_to_sisepuede'
    yf_df_pivot[["iso_code3","Nation", "Year", sise_var]].to_csv(os.path.join(dir_path,f"historical/{sise_var}.csv"), index = False)
# Out:
# /tmp/ipykernel_72625/3511680694.py:11: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   yf_df_pivot[sise_var] = yf_df_pivot.groupby(["Nation"])[sise_var].apply(lambda x: x.interpolate().fillna(method='bfill')).reset_index()[sise_var].fillna(0)
# /tmp/ipykernel_72625/3511680694.py:11: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   yf_df_pivot[sise_var] = yf_df_pivot.groupby(["Nation"])[sise_var].apply(lambda x: x.interpolate().fillna(method='bfill')).reset_index()[sise_var].fillna(0)
# /tmp/ipykernel_72625/3511680694.py:11: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   yf_df_pivot[sise_var] = yf_df_pivot.groupby(["Nation"])[sise_var].apply(lambda x: x.interpolate().fillna(method='bfill')).reset_index()[sise_var].fillna(0)
# /tmp/ipykernel_72625/3511680694.py:11: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   yf_df_pivot[sise_var] = yf_df_pivot.groupby(["Nation"])[sise_var].apply(lambda x: x.interpolate().fillna(method='bfill')).reset_index()[sise_var].fillna(0)
# /tmp/ipykernel_72625/3511680694.py:11: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   yf_df_pivot[sise_var] = yf_df_pivot.groupby(["Nation"])[sise_var].apply(lambda x: x.interpolate().fillna(method='bfill')).reset_index()[sise_var].fillna(0)
# /tmp/ipykernel_72625/3511680694.py:11: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   yf_df_pivot[sise_var] = yf_df_pivot.groupby(["Nation"])[sise_var].apply(lambda x: x.interpolate().fillna(method='bfill')).reset_index()[sise_var].fillna(0)
# /tmp/ipykernel_72625/3511680694.py:11: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   yf_df_pivot[sise_var] = yf_df_pivot.groupby(["Nation"])[sise_var].apply(lambda x: x.interpolate().fillna(method='bfill')).reset_index()[sise_var].fillna(0)
# /tmp/ipykernel_72625/3511680694.py:11: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   yf_df_pivot[sise_var] = yf_df_pivot.groupby(["Nation"])[sise_var].apply(lambda x: x.interpolate().fillna(method='bfill')).reset_index()[sise_var].fillna(0)
# /tmp/ipykernel_72625/3511680694.py:11: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   yf_df_pivot[sise_var] = yf_df_pivot.groupby(["Nation"])[sise_var].apply(lambda x: x.interpolate().fillna(method='bfill')).reset_index()[sise_var].fillna(0)
# /tmp/ipykernel_72625/3511680694.py:11: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   yf_df_pivot[sise_var] = yf_df_pivot.groupby(["Nation"])[sise_var].apply(lambda x: x.interpolate().fillna(method='bfill')).reset_index()[sise_var].fillna(0)
# /tmp/ipykernel_72625/3511680694.py:11: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   yf_df_pivot[sise_var] = yf_df_pivot.groupby(["Nation"])[sise_var].apply(lambda x: x.interpolate().fillna(method='bfill')).reset_index()[sise_var].fillna(0)
# /tmp/ipykernel_72625/3511680694.py:11: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   yf_df_pivot[sise_var] = yf_df_pivot.groupby(["Nation"])[sise_var].apply(lambda x: x.interpolate().fillna(method='bfill')).reset_index()[sise_var].fillna(0)
# /tmp/ipykernel_72625/3511680694.py:11: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   yf_df_pivot[sise_var] = yf_df_pivot.groupby(["Nation"])[sise_var].apply(lambda x: x.interpolate().fillna(method='bfill')).reset_index()[sise_var].fillna(0)

# %%
# Create projected input data
max_year = yf_df_pivot.Year.max()

yf_data_projected = yf_df_pivot.query(f"Year=={max_year}")

yf_data_projected = yf_data_projected.drop(columns = "Year")

df_year = pd.DataFrame({"Year" : range(max_year+1, 2051)})

yf_data_projected = yf_data_projected.merge(df_year, how = "cross") 

for sise_var in sisepuede_items:
    dir_path = f'../AFOLU/{sise_var}/input_to_sisepuede'
    yf_data_projected[["iso_code3","Nation", "Year",sise_var]].to_csv(os.path.join(dir_path,f"projected/{sise_var}.csv"), index = False)

# %%
# Checking Iran Data
# yf_df_pivot[yf_df_pivot.iso_code3 == 'IRN'].head(15)
# Out:
# sisepuede_item iso_code3                      Nation  Year  \
# 985                  IRN  Iran (Islamic Republic of)  2011
# 986                  IRN  Iran (Islamic Republic of)  2012
# 987                  IRN  Iran (Islamic Republic of)  2013
# 988                  IRN  Iran (Islamic Republic of)  2014
# 989                  IRN  Iran (Islamic Republic of)  2015
# 990                  IRN  Iran (Islamic Republic of)  2016
# 991                  IRN  Iran (Islamic Republic of)  2017
# 992                  IRN  Iran (Islamic Republic of)  2018
# 993                  IRN  Iran (Islamic Republic of)  2019
# 994                  IRN  Iran (Islamic Republic of)  2020
# 995                  IRN  Iran (Islamic Republic of)  2021
# 996                  IRN  Iran (Islamic Republic of)  2022
#
# sisepuede_item  yf_agrc_bevs_and_spices_tonne_ha  yf_agrc_cereals_tonne_ha  \
# 985                                     0.000000                  3.512842
# 986                                     0.000000                  3.512842
# 987                                     0.000000                  3.512842
# 988                                     0.000000                  3.512842
# 989                                     0.000000                  3.541281
# 990                                     0.000000                  3.884320
# 991                                     0.000000                  2.866006
# 992                                     0.000000                  3.958285
# 993                                     0.000000                  5.355022
# 994                                     0.000000                  3.440089
# 995                                     0.000000                  3.270223
# 996                                     2.092471                  2.195471
#
# sisepuede_item  yf_agrc_fibers_tonne_ha  yf_agrc_fruits_tonne_ha  \
# 985                            0.000000                 0.000000
# 986                            0.000000                 0.000000
# 987                            0.000000                 0.000000
# 988                            0.000000                 0.000000
# 989                            0.000000                 0.000000
# 990                            0.000000                 0.000000
# 991                            0.000000                 0.000000
# 992                            0.000000                 0.000000
# 993                            0.000000                 0.000000
# 994                            0.000000                 0.000000
# 995                            0.000000                 0.000000
# 996                            1.946202                12.291287
#
# sisepuede_item  yf_agrc_herbs_and_other_perennial_crops_tonne_ha  \
# 985                                                     0.000000
# 986                                                     0.000000
# 987                                                     0.000000
# 988                                                     0.000000
# 989                                                     0.000000
# 990                                                     0.000000
# 991                                                     0.000000
# 992                                                     0.000000
# 993                                                     0.000000
# 994                                                     0.000000
# 995                                                     0.000000
# 996                                                     3.021928
#
# sisepuede_item  yf_agrc_nuts_tonne_ha  yf_agrc_other_annual_tonne_ha  \
# 985                          0.000000                       0.000000
# 986                          0.000000                       0.000000
# 987                          0.000000                       0.000000
# 988                          0.000000                       0.000000
# 989                          0.000000                       0.000000
# 990                          0.000000                       0.000000
# 991                          0.000000                       0.000000
# 992                          0.000000                       0.000000
# 993                          0.000000                       0.000000
# 994                          0.000000                       0.000000
# 995                          0.000000                       0.000000
# 996                          1.207774                       1.122455
#
# sisepuede_item  yf_agrc_other_woody_perennial_tonne_ha  \
# 985                                           0.000000
# 986                                           0.000000
# 987                                           0.000000
# 988                                           0.000000
# 989                                           0.000000
# 990                                           0.000000
# 991                                           0.000000
# 992                                           0.000000
# 993                                           0.000000
# 994                                           0.000000
# 995                                           0.000000
# 996                                           1.862022
#
# sisepuede_item  yf_agrc_pulses_tonne_ha  yf_agrc_rice_tonne_ha  \
# 985                            0.000000               0.000000
# 986                            0.000000               0.000000
# 987                            0.000000               0.000000
# 988                            0.000000               0.000000
# 989                            0.000000               0.000000
# 990                            0.000000               0.000000
# 991                            0.000000               0.000000
# 992                            0.000000               0.000000
# 993                            0.000000               0.000000
# 994                            0.000000               0.000000
# 995                            0.000000               0.000000
# 996                            2.213576               3.954868
#
# sisepuede_item  yf_agrc_sugar_cane_tonne_ha  yf_agrc_tubers_tonne_ha  \
# 985                                 0.00000                21.173060
# 986                                 0.00000                13.227720
# 987                                 0.00000                15.248585
# 988                                 0.00000                16.626472
# 989                                 0.00000                18.243230
# 990                                 0.00000                16.534650
# 991                                 0.00000                11.059807
# 992                                 0.00000                15.064940
# 993                                 0.00000                20.334864
# 994                                 0.00000                15.567042
# 995                                 0.00000                17.636960
# 996                                76.33122                25.149791
#
# sisepuede_item  yf_agrc_vegetables_and_vines_tonne_ha
# 985                                        260.077214
# 986                                        232.736817
# 987                                        239.716313
# 988                                        237.056241
# 989                                        249.320740
# 990                                        243.143417
# 991                                        222.736440
# 992                                        232.339302
# 993                                        212.567344
# 994                                        214.270700
# 995                                        217.629063
# 996                                         13.691656
