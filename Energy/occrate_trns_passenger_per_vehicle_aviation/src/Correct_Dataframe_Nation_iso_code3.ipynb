# %%
#Add parent and grandparent folder to sys.path and get variable name
import os
import sys
import inspect

parentdir = os.path.abspath('..')
grandparentdir=os.path.dirname(parentdir)
sys.path.insert(0, parentdir)
sys.path.insert(0, grandparentdir)

var_name=os.path.basename(parentdir)

var_name
# Out:
# 'occrate_trns_passenger_per_vehicle_aviation'

# %%
import pandas as pd
import numpy as np

df_hist=pd.read_csv('../input_to_sisepuede/historical/'+var_name+'.csv')
df_proj=pd.read_csv('../input_to_sisepuede/projected/'+var_name+'.csv')
df_hist.columns
# Out:
# Index(['Unnamed: 0', 'Nation', 'iso_3', 'Year',
#        'occrate_trns_passenger_per_vehicle_aviation'],
#       dtype='object')

# %%
if 'Country' in df_hist.columns:
    df_hist.rename(columns = {'Country':'Nation'}, inplace = True)
if 'Country' in df_proj.columns:
    df_proj.rename(columns = {'Country':'Nation'}, inplace = True)
if 'ISO3' in df_hist.columns:
    df_hist.rename(columns = {'ISO3':'iso_code3'}, inplace = True)
if 'ISO3' in df_proj.columns:
    df_proj.rename(columns = {'ISO3':'iso_code3'}, inplace = True)
    
if 'iso_3' in df_hist.columns:
    df_hist.rename(columns = {'iso_3':'iso_code3'}, inplace = True)
if 'iso_3' in df_proj.columns:
    df_proj.rename(columns = {'iso_3':'iso_code3'}, inplace = True)
    
if 'Unnamed: 0' in df_hist.columns:
    df_hist=df_hist.drop(['Unnamed: 0'],axis=1)
if 'Unnamed: 0' in df_proj.columns:
    df_proj=df_proj.drop(['Unnamed: 0'],axis=1)

# %%
df_hist
# Out:
#         Nation iso_code3  Year  occrate_trns_passenger_per_vehicle_aviation
# 0        Aruba       ABW  1991                                        0.568
# 1        Aruba       ABW  1992                                        0.567
# 2        Aruba       ABW  1993                                        0.579
# 3        Aruba       ABW  1994                                        0.606
# 4        Aruba       ABW  1995                                        0.613
# ...        ...       ...   ...                                          ...
# 4517  Zimbabwe       ZWE  2003                                        0.647
# 4518  Zimbabwe       ZWE  2004                                        0.654
# 4519  Zimbabwe       ZWE  2005                                        0.759
# 4520  Zimbabwe       ZWE  2006                                        0.764
# 4521  Zimbabwe       ZWE  2007                                        0.770
#
# [4522 rows x 4 columns]

# %%
df_proj
# Out:
#          Nation iso_code3    Year  occrate_trns_passenger_per_vehicle_aviation
# 0         Aruba       ABW  2008.0                                         0.77
# 1         Aruba       ABW  2009.0                                         0.77
# 2         Aruba       ABW  2010.0                                         0.77
# 3         Aruba       ABW  2011.0                                         0.77
# 4         Aruba       ABW  2012.0                                         0.77
# ...         ...       ...     ...                                          ...
# 11433  Zimbabwe       ZWE  2046.0                                         0.77
# 11434  Zimbabwe       ZWE  2047.0                                         0.77
# 11435  Zimbabwe       ZWE  2048.0                                         0.77
# 11436  Zimbabwe       ZWE  2049.0                                         0.77
# 11437  Zimbabwe       ZWE  2050.0                                         0.77
#
# [11438 rows x 4 columns]

# %%
df_hist.to_csv('../input_to_sisepuede/historical/'+var_name+'.csv')
df_proj.to_csv('../input_to_sisepuede/projected/'+var_name+'.csv')
