# %%
# Add Parent Folder to System Path

import os
import sys
import inspect

currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0, parentdir) 

####

import pandas as pd
import numpy as np

# %%
df_coal=pd.read_csv("../row_data/coal-prices.csv")
df_countries=pd.read_csv("../row_data/Countries_ISO3.csv")

# %%
df_coal
# Out:
#                                                 Entity  Code  Year  \
# 0                              Asian marker price (BP)   NaN  2001
# 1                              Asian marker price (BP)   NaN  2002
# 2                              Asian marker price (BP)   NaN  2003
# 3                              Asian marker price (BP)   NaN  2004
# 4                              Asian marker price (BP)   NaN  2005
# ..                                                 ...   ...   ...
# 142  US Central Appalachian coal spot price index (BP)   NaN  2017
# 143  US Central Appalachian coal spot price index (BP)   NaN  2018
# 144  US Central Appalachian coal spot price index (BP)   NaN  2019
# 145  US Central Appalachian coal spot price index (BP)   NaN  2020
# 146  US Central Appalachian coal spot price index (BP)   NaN  2021
#
#      Coal - Prices
# 0        36.894600
# 1        30.406666
# 2        36.529198
# 3        72.416664
# 4        61.840000
# ..             ...
# 142      63.825291
# 143      72.844009
# 144      57.163982
# 145      42.766369
# 146      68.538139
#
# [147 rows x 4 columns]

# %%
df_countries=pd.read_csv("../row_data/Countries_ISO3.csv")

# %%
df_countries
# Out:
#                     Country Name ISO3
# 0                          Aruba  ABW
# 1    Africa Eastern and Southern  AFE
# 2                    Afghanistan  AFG
# 3     Africa Western and Central  AFW
# 4                         Angola  AGO
# ..                           ...  ...
# 261                       Kosovo  XKX
# 262                  Yemen, Rep.  YEM
# 263                 South Africa  ZAF
# 264                       Zambia  ZMB
# 265                     Zimbabwe  ZWE
#
# [266 rows x 2 columns]

# %%
countries=df_countries['Country Name'].values

# %%
ISO3=np.unique(df_countries['ISO3'].values)

# %%
years=np.unique(df_coal['Year'].values)

# %%
coun_year=[]
for count in zip(countries,ISO3):
    for year in years:
        coun_year.append([count[0],count[1],year])
coun_year
# Out:
# [['Aruba', 'ABW', 2001],
#  ['Aruba', 'ABW', 2002],
#  ['Aruba', 'ABW', 2003],
#  ['Aruba', 'ABW', 2004],
#  ['Aruba', 'ABW', 2005],
#  ['Aruba', 'ABW', 2006],
#  ['Aruba', 'ABW', 2007],
#  ['Aruba', 'ABW', 2008],
#  ['Aruba', 'ABW', 2009],
#  ['Aruba', 'ABW', 2010],
#  ['Aruba', 'ABW', 2011],
#  ['Aruba', 'ABW', 2012],
#  ['Aruba', 'ABW', 2013],
#  ['Aruba', 'ABW', 2014],
#  ['Aruba', 'ABW', 2015],
#  ['Aruba', 'ABW', 2016],
#  ['Aruba', 'ABW', 2017],
#  ['Aruba', 'ABW', 2018],
#  ['Aruba', 'ABW', 2019],
#  ['Aruba', 'ABW', 2020],
#  ['Aruba', 'ABW', 2021],
#  ['Africa Eastern and Southern', 'AFE', 2001],
#  ['Africa Eastern and Southern', 'AFE', 2002],
#  ['Africa Eastern and Southern', 'AFE', 2003],
#  ['Africa Eastern and Southern', 'AFE', 2004],
#  ['Africa Eastern and Southern', 'AFE', 2005],
#  ['Africa Eastern and Southern', 'AFE', 2006],
#  ['Africa Eastern and Southern', 'AFE', 2007],
#  ['Africa Eastern and Southern', 'AFE', 2008],
#  ['Africa Eastern and Southern', 'AFE', 2009],
#  ['Africa Eastern and Southern', 'AFE', 2010],
#  ['Africa Eastern and Southern', 'AFE', 2011],
#  ['Africa Eastern and Southern', 'AFE', 2012],
#  ['Africa Eastern and Southern', 'AFE', 2013],
#  ['Africa Eastern and Southern', 'AFE', 2014],
#  ['Africa Eastern and Southern', 'AFE', 2015],
#  ['Africa Eastern and Southern', 'AFE', 2016],
#  ['Africa Eastern and Southern', 'AFE', 2017],
#  ['Africa Eastern and Southern', 'AFE', 2018],
#  ['Africa Eastern and Southern', 'AFE', 2019],
#  ['Africa Eastern and Southern', 'AFE', 2020],
#  ['Africa Eastern and Southern', 'AFE', 2021],
#  ['Afghanistan', 'AFG', 2001],
#  ['Afghanistan', 'AFG', 2002],
#  ['Afghanistan', 'AFG', 2003],
#  ['Afghanistan', 'AFG', 2004],
#  ['Afghanistan', 'AFG', 2005],
#  ['Afghanistan', 'AFG', 2006],
#  ['Afghanistan', 'AFG', 2007],
#  ['Afghanistan', 'AFG', 2008],
#  ['Afghanistan', 'AFG', 2009],
#  ['Afghanistan', 'AFG', 2010],
#  ['Afghanistan', 'AFG', 2011],
#  ['Afghanistan', 'AFG', 2012],
#  ['Afghanistan', 'AFG', 2013],
#  ['Afghanistan', 'AFG', 2014],
#  ['Afghanistan', 'AFG', 2015],
#  ['Afghanistan', 'AFG', 2016],
#  ['Afghanistan', 'AFG', 2017],
#  ['Afghanistan', 'AFG', 2018],
#  ['Afghanistan', 'AFG', 2019],
#  ['Afghanistan', 'AFG', 2020],
#  ['Afghanistan', 'AFG', 2021],
#  ['Africa Western and Central', 'AFW', 2001],
#  ['Africa Western and Central', 'AFW', 2002],
#  ['Africa Western and Central', 'AFW', 2003],
#  ['Africa Western and Central', 'AFW', 2004],
#  ['Africa Western and Central', 'AFW', 2005],
#  ['Africa Western and Central', 'AFW', 2006],
#  ['Africa Western and Central', 'AFW', 2007],
#  ['Africa Western and Central', 'AFW', 2008],
#  ['Africa Western and Central', 'AFW', 2009],
#  ['Africa Western and Central', 'AFW', 2010],
#  ['Africa Western and Central', 'AFW', 2011],
#  ['Africa Western and Central', 'AFW', 2012],
#  ['Africa Western and Central', 'AFW', 2013],
#  ['Africa Western and Central', 'AFW', 2014],
#  ['Africa Western and Central', 'AFW', 2015],
#  ['Africa Western and Central', 'AFW', 2016],
#  ['Africa Western and Central', 'AFW', 2017],
#  ['Africa Western and Central', 'AFW', 2018],
#  ['Africa Western and Central', 'AFW', 2019],
#  ['Africa Western and Central', 'AFW', 2020],
#  ['Africa Western and Central', 'AFW', 2021],
#  ['Angola', 'AGO', 2001],
#  ['Angola', 'AGO', 2002],
#  ['Angola', 'AGO', 2003],
#  ['Angola', 'AGO', 2004],
#  ['Angola', 'AGO', 2005],
#  ['Angola', 'AGO', 2006],
#  ['Angola', 'AGO', 2007],
#  ['Angola', 'AGO', 2008],
#  ['Angola', 'AGO', 2009],
#  ['Angola', 'AGO', 2010],
#  ['Angola', 'AGO', 2011],
#  ['Angola', 'AGO', 2012],
#  ['Angola', 'AGO', 2013],
#  ['Angola', 'AGO', 2014],
#  ['Angola', 'AGO', 2015],
#  ['Angola', 'AGO', 2016],
#  ['Angola', 'AGO', 2017],
#  ['Angola', 'AGO', 2018],
#  ['Angola', 'AGO', 2019],
#  ['Angola', 'AGO', 2020],
#  ['Angola', 'AGO', 2021],
#  ['Albania', 'ALB', 2001],
#  ['Albania', 'ALB', 2002],
#  ['Albania', 'ALB', 2003],
#  ['Albania', 'ALB', 2004],
#  ['Albania', 'ALB', 2005],
#  ['Albania', 'ALB', 2006],
#  ['Albania', 'ALB', 2007],
#  ['Albania', 'ALB', 2008],
#  ['Albania', 'ALB', 2009],
#  ['Albania', 'ALB', 2010],
#  ['Albania', 'ALB', 2011],
#  ['Albania', 'ALB', 2012],
#  ['Albania', 'ALB', 2013],
#  ['Albania', 'ALB', 2014],
#  ['Albania', 'ALB', 2015],
#  ['Albania', 'ALB', 2016],
#  ['Albania', 'ALB', 2017],
#  ['Albania', 'ALB', 2018],
#  ['Albania', 'ALB', 2019],
#  ['Albania', 'ALB', 2020],
#  ['Albania', 'ALB', 2021],
#  ['Andorra', 'AND', 2001],
#  ['Andorra', 'AND', 2002],
#  ['Andorra', 'AND', 2003],
#  ['Andorra', 'AND', 2004],
#  ['Andorra', 'AND', 2005],
#  ['Andorra', 'AND', 2006],
#  ['Andorra', 'AND', 2007],
#  ['Andorra', 'AND', 2008],
#  ['Andorra', 'AND', 2009],
#  ['Andorra', 'AND', 2010],
#  ['Andorra', 'AND', 2011],
#  ['Andorra', 'AND', 2012],
#  ['Andorra', 'AND', 2013],
#  ['Andorra', 'AND', 2014],
#  ['Andorra', 'AND', 2015],
#  ['Andorra', 'AND', 2016],
#  ['Andorra', 'AND', 2017],
#  ['Andorra', 'AND', 2018],
#  ['Andorra', 'AND', 2019],
#  ['Andorra', 'AND', 2020],
#  ['Andorra', 'AND', 2021],
#  ['Arab World', 'ARB', 2001],
#  ['Arab World', 'ARB', 2002],
#  ['Arab World', 'ARB', 2003],
#  ['Arab World', 'ARB', 2004],
#  ['Arab World', 'ARB', 2005],
#  ['Arab World', 'ARB', 2006],
#  ['Arab World', 'ARB', 2007],
#  ['Arab World', 'ARB', 2008],
#  ['Arab World', 'ARB', 2009],
#  ['Arab World', 'ARB', 2010],
#  ['Arab World', 'ARB', 2011],
#  ['Arab World', 'ARB', 2012],
#  ['Arab World', 'ARB', 2013],
#  ['Arab World', 'ARB', 2014],
#  ['Arab World', 'ARB', 2015],
#  ['Arab World', 'ARB', 2016],
#  ['Arab World', 'ARB', 2017],
#  ['Arab World', 'ARB', 2018],
#  ['Arab World', 'ARB', 2019],
#  ['Arab World', 'ARB', 2020],
#  ['Arab World', 'ARB', 2021],
#  ['United Arab Emirates', 'ARE', 2001],
#  ['United Arab Emirates', 'ARE', 2002],
#  ['United Arab Emirates', 'ARE', 2003],
#  ['United Arab Emirates', 'ARE', 2004],
#  ['United Arab Emirates', 'ARE', 2005],
#  ['United Arab Emirates', 'ARE', 2006],
#  ['United Arab Emirates', 'ARE', 2007],
#  ['United Arab Emirates', 'ARE', 2008],
#  ['United Arab Emirates', 'ARE', 2009],
#  ['United Arab Emirates', 'ARE', 2010],
#  ['United Arab Emirates', 'ARE', 2011],
#  ['United Arab Emirates', 'ARE', 2012],
#  ['United Arab Emirates', 'ARE', 2013],
#  ['United Arab Emirates', 'ARE', 2014],
#  ['United Arab Emirates', 'ARE', 2015],
#  ['United Arab Emirates', 'ARE', 2016],
#  ['United Arab Emirates', 'ARE', 2017],
#  ['United Arab Emirates', 'ARE', 2018],
#  ['United Arab Emirates', 'ARE', 2019],
#  ['United Arab Emirates', 'ARE', 2020],
#  ['United Arab Emirates', 'ARE', 2021],
#  ['Argentina', 'ARG', 2001],
#  ['Argentina', 'ARG', 2002],
#  ['Argentina', 'ARG', 2003],
#  ['Argentina', 'ARG', 2004],
#  ['Argentina', 'ARG', 2005],
#  ['Argentina', 'ARG', 2006],
#  ['Argentina', 'ARG', 2007],
#  ['Argentina', 'ARG', 2008],
#  ['Argentina', 'ARG', 2009],
#  ['Argentina', 'ARG', 2010],
#  ['Argentina', 'ARG', 2011],
#  ['Argentina', 'ARG', 2012],
#  ['Argentina', 'ARG', 2013],
#  ['Argentina', 'ARG', 2014],
#  ['Argentina', 'ARG', 2015],
#  ['Argentina', 'ARG', 2016],
#  ['Argentina', 'ARG', 2017],
#  ['Argentina', 'ARG', 2018],
#  ['Argentina', 'ARG', 2019],
#  ['Argentina', 'ARG', 2020],
#  ['Argentina', 'ARG', 2021],
#  ['Armenia', 'ARM', 2001],
#  ['Armenia', 'ARM', 2002],
#  ['Armenia', 'ARM', 2003],
#  ['Armenia', 'ARM', 2004],
#  ['Armenia', 'ARM', 2005],
#  ['Armenia', 'ARM', 2006],
#  ['Armenia', 'ARM', 2007],
#  ['Armenia', 'ARM', 2008],
#  ['Armenia', 'ARM', 2009],
#  ['Armenia', 'ARM', 2010],
#  ['Armenia', 'ARM', 2011],
#  ['Armenia', 'ARM', 2012],
#  ['Armenia', 'ARM', 2013],
#  ['Armenia', 'ARM', 2014],
#  ['Armenia', 'ARM', 2015],
#  ['Armenia', 'ARM', 2016],
#  ['Armenia', 'ARM', 2017],
#  ['Armenia', 'ARM', 2018],
#  ['Armenia', 'ARM', 2019],
#  ['Armenia', 'ARM', 2020],
#  ['Armenia', 'ARM', 2021],
#  ['American Samoa', 'ASM', 2001],
#  ['American Samoa', 'ASM', 2002],
#  ['American Samoa', 'ASM', 2003],
#  ['American Samoa', 'ASM', 2004],
#  ['American Samoa', 'ASM', 2005],
#  ['American Samoa', 'ASM', 2006],
#  ['American Samoa', 'ASM', 2007],
#  ['American Samoa', 'ASM', 2008],
#  ['American Samoa', 'ASM', 2009],
#  ['American Samoa', 'ASM', 2010],
#  ['American Samoa', 'ASM', 2011],
#  ['American Samoa', 'ASM', 2012],
#  ['American Samoa', 'ASM', 2013],
#  ['American Samoa', 'ASM', 2014],
#  ['American Samoa', 'ASM', 2015],
#  ['American Samoa', 'ASM', 2016],
#  ['American Samoa', 'ASM', 2017],
#  ['American Samoa', 'ASM', 2018],
#  ['American Samoa', 'ASM', 2019],
#  ['American Samoa', 'ASM', 2020],
#  ['American Samoa', 'ASM', 2021],
#  ['Antigua and Barbuda', 'ATG', 2001],
#  ['Antigua and Barbuda', 'ATG', 2002],
#  ['Antigua and Barbuda', 'ATG', 2003],
#  ['Antigua and Barbuda', 'ATG', 2004],
#  ['Antigua and Barbuda', 'ATG', 2005],
#  ['Antigua and Barbuda', 'ATG', 2006],
#  ['Antigua and Barbuda', 'ATG', 2007],
#  ['Antigua and Barbuda', 'ATG', 2008],
#  ['Antigua and Barbuda', 'ATG', 2009],
#  ['Antigua and Barbuda', 'ATG', 2010],
#  ['Antigua and Barbuda', 'ATG', 2011],
#  ['Antigua and Barbuda', 'ATG', 2012],
#  ['Antigua and Barbuda', 'ATG', 2013],
#  ['Antigua and Barbuda', 'ATG', 2014],
#  ['Antigua and Barbuda', 'ATG', 2015],
#  ['Antigua and Barbuda', 'ATG', 2016],
#  ['Antigua and Barbuda', 'ATG', 2017],
#  ['Antigua and Barbuda', 'ATG', 2018],
#  ['Antigua and Barbuda', 'ATG', 2019],
#  ['Antigua and Barbuda', 'ATG', 2020],
#  ['Antigua and Barbuda', 'ATG', 2021],
#  ['Australia', 'AUS', 2001],
#  ['Australia', 'AUS', 2002],
#  ['Australia', 'AUS', 2003],
#  ['Australia', 'AUS', 2004],
#  ['Australia', 'AUS', 2005],
#  ['Australia', 'AUS', 2006],
#  ['Australia', 'AUS', 2007],
#  ['Australia', 'AUS', 2008],
#  ['Australia', 'AUS', 2009],
#  ['Australia', 'AUS', 2010],
#  ['Australia', 'AUS', 2011],
#  ['Australia', 'AUS', 2012],
#  ['Australia', 'AUS', 2013],
#  ['Australia', 'AUS', 2014],
#  ['Australia', 'AUS', 2015],
#  ['Australia', 'AUS', 2016],
#  ['Australia', 'AUS', 2017],
#  ['Australia', 'AUS', 2018],
#  ['Australia', 'AUS', 2019],
#  ['Australia', 'AUS', 2020],
#  ['Australia', 'AUS', 2021],
#  ['Austria', 'AUT', 2001],
#  ['Austria', 'AUT', 2002],
#  ['Austria', 'AUT', 2003],
#  ['Austria', 'AUT', 2004],
#  ['Austria', 'AUT', 2005],
#  ['Austria', 'AUT', 2006],
#  ['Austria', 'AUT', 2007],
#  ['Austria', 'AUT', 2008],
#  ['Austria', 'AUT', 2009],
#  ['Austria', 'AUT', 2010],
#  ['Austria', 'AUT', 2011],
#  ['Austria', 'AUT', 2012],
#  ['Austria', 'AUT', 2013],
#  ['Austria', 'AUT', 2014],
#  ['Austria', 'AUT', 2015],
#  ['Austria', 'AUT', 2016],
#  ['Austria', 'AUT', 2017],
#  ['Austria', 'AUT', 2018],
#  ['Austria', 'AUT', 2019],
#  ['Austria', 'AUT', 2020],
#  ['Austria', 'AUT', 2021],
#  ['Azerbaijan', 'AZE', 2001],
#  ['Azerbaijan', 'AZE', 2002],
#  ['Azerbaijan', 'AZE', 2003],
#  ['Azerbaijan', 'AZE', 2004],
#  ['Azerbaijan', 'AZE', 2005],
#  ['Azerbaijan', 'AZE', 2006],
#  ['Azerbaijan', 'AZE', 2007],
#  ['Azerbaijan', 'AZE', 2008],
#  ['Azerbaijan', 'AZE', 2009],
#  ['Azerbaijan', 'AZE', 2010],
#  ['Azerbaijan', 'AZE', 2011],
#  ['Azerbaijan', 'AZE', 2012],
#  ['Azerbaijan', 'AZE', 2013],
#  ['Azerbaijan', 'AZE', 2014],
#  ['Azerbaijan', 'AZE', 2015],
#  ['Azerbaijan', 'AZE', 2016],
#  ['Azerbaijan', 'AZE', 2017],
#  ['Azerbaijan', 'AZE', 2018],
#  ['Azerbaijan', 'AZE', 2019],
#  ['Azerbaijan', 'AZE', 2020],
#  ['Azerbaijan', 'AZE', 2021],
#  ['Burundi', 'BDI', 2001],
#  ['Burundi', 'BDI', 2002],
#  ['Burundi', 'BDI', 2003],
#  ['Burundi', 'BDI', 2004],
#  ['Burundi', 'BDI', 2005],
#  ['Burundi', 'BDI', 2006],
#  ['Burundi', 'BDI', 2007],
#  ['Burundi', 'BDI', 2008],
#  ['Burundi', 'BDI', 2009],
#  ['Burundi', 'BDI', 2010],
#  ['Burundi', 'BDI', 2011],
#  ['Burundi', 'BDI', 2012],
#  ['Burundi', 'BDI', 2013],
#  ['Burundi', 'BDI', 2014],
#  ['Burundi', 'BDI', 2015],
#  ['Burundi', 'BDI', 2016],
#  ['Burundi', 'BDI', 2017],
#  ['Burundi', 'BDI', 2018],
#  ['Burundi', 'BDI', 2019],
#  ['Burundi', 'BDI', 2020],
#  ['Burundi', 'BDI', 2021],
#  ['Belgium', 'BEL', 2001],
#  ['Belgium', 'BEL', 2002],
#  ['Belgium', 'BEL', 2003],
#  ['Belgium', 'BEL', 2004],
#  ['Belgium', 'BEL', 2005],
#  ['Belgium', 'BEL', 2006],
#  ['Belgium', 'BEL', 2007],
#  ['Belgium', 'BEL', 2008],
#  ['Belgium', 'BEL', 2009],
#  ['Belgium', 'BEL', 2010],
#  ['Belgium', 'BEL', 2011],
#  ['Belgium', 'BEL', 2012],
#  ['Belgium', 'BEL', 2013],
#  ['Belgium', 'BEL', 2014],
#  ['Belgium', 'BEL', 2015],
#  ['Belgium', 'BEL', 2016],
#  ['Belgium', 'BEL', 2017],
#  ['Belgium', 'BEL', 2018],
#  ['Belgium', 'BEL', 2019],
#  ['Belgium', 'BEL', 2020],
#  ['Belgium', 'BEL', 2021],
#  ['Benin', 'BEN', 2001],
#  ['Benin', 'BEN', 2002],
#  ['Benin', 'BEN', 2003],
#  ['Benin', 'BEN', 2004],
#  ['Benin', 'BEN', 2005],
#  ['Benin', 'BEN', 2006],
#  ['Benin', 'BEN', 2007],
#  ['Benin', 'BEN', 2008],
#  ['Benin', 'BEN', 2009],
#  ['Benin', 'BEN', 2010],
#  ['Benin', 'BEN', 2011],
#  ['Benin', 'BEN', 2012],
#  ['Benin', 'BEN', 2013],
#  ['Benin', 'BEN', 2014],
#  ['Benin', 'BEN', 2015],
#  ['Benin', 'BEN', 2016],
#  ['Benin', 'BEN', 2017],
#  ['Benin', 'BEN', 2018],
#  ['Benin', 'BEN', 2019],
#  ['Benin', 'BEN', 2020],
#  ['Benin', 'BEN', 2021],
#  ['Burkina Faso', 'BFA', 2001],
#  ['Burkina Faso', 'BFA', 2002],
#  ['Burkina Faso', 'BFA', 2003],
#  ['Burkina Faso', 'BFA', 2004],
#  ['Burkina Faso', 'BFA', 2005],
#  ['Burkina Faso', 'BFA', 2006],
#  ['Burkina Faso', 'BFA', 2007],
#  ['Burkina Faso', 'BFA', 2008],
#  ['Burkina Faso', 'BFA', 2009],
#  ['Burkina Faso', 'BFA', 2010],
#  ['Burkina Faso', 'BFA', 2011],
#  ['Burkina Faso', 'BFA', 2012],
#  ['Burkina Faso', 'BFA', 2013],
#  ['Burkina Faso', 'BFA', 2014],
#  ['Burkina Faso', 'BFA', 2015],
#  ['Burkina Faso', 'BFA', 2016],
#  ['Burkina Faso', 'BFA', 2017],
#  ['Burkina Faso', 'BFA', 2018],
#  ['Burkina Faso', 'BFA', 2019],
#  ['Burkina Faso', 'BFA', 2020],
#  ['Burkina Faso', 'BFA', 2021],
#  ['Bangladesh', 'BGD', 2001],
#  ['Bangladesh', 'BGD', 2002],
#  ['Bangladesh', 'BGD', 2003],
#  ['Bangladesh', 'BGD', 2004],
#  ['Bangladesh', 'BGD', 2005],
#  ['Bangladesh', 'BGD', 2006],
#  ['Bangladesh', 'BGD', 2007],
#  ['Bangladesh', 'BGD', 2008],
#  ['Bangladesh', 'BGD', 2009],
#  ['Bangladesh', 'BGD', 2010],
#  ['Bangladesh', 'BGD', 2011],
#  ['Bangladesh', 'BGD', 2012],
#  ['Bangladesh', 'BGD', 2013],
#  ['Bangladesh', 'BGD', 2014],
#  ['Bangladesh', 'BGD', 2015],
#  ['Bangladesh', 'BGD', 2016],
#  ['Bangladesh', 'BGD', 2017],
#  ['Bangladesh', 'BGD', 2018],
#  ['Bangladesh', 'BGD', 2019],
#  ['Bangladesh', 'BGD', 2020],
#  ['Bangladesh', 'BGD', 2021],
#  ['Bulgaria', 'BGR', 2001],
#  ['Bulgaria', 'BGR', 2002],
#  ['Bulgaria', 'BGR', 2003],
#  ['Bulgaria', 'BGR', 2004],
#  ['Bulgaria', 'BGR', 2005],
#  ['Bulgaria', 'BGR', 2006],
#  ['Bulgaria', 'BGR', 2007],
#  ['Bulgaria', 'BGR', 2008],
#  ['Bulgaria', 'BGR', 2009],
#  ['Bulgaria', 'BGR', 2010],
#  ['Bulgaria', 'BGR', 2011],
#  ['Bulgaria', 'BGR', 2012],
#  ['Bulgaria', 'BGR', 2013],
#  ['Bulgaria', 'BGR', 2014],
#  ['Bulgaria', 'BGR', 2015],
#  ['Bulgaria', 'BGR', 2016],
#  ['Bulgaria', 'BGR', 2017],
#  ['Bulgaria', 'BGR', 2018],
#  ['Bulgaria', 'BGR', 2019],
#  ['Bulgaria', 'BGR', 2020],
#  ['Bulgaria', 'BGR', 2021],
#  ['Bahrain', 'BHR', 2001],
#  ['Bahrain', 'BHR', 2002],
#  ['Bahrain', 'BHR', 2003],
#  ['Bahrain', 'BHR', 2004],
#  ['Bahrain', 'BHR', 2005],
#  ['Bahrain', 'BHR', 2006],
#  ['Bahrain', 'BHR', 2007],
#  ['Bahrain', 'BHR', 2008],
#  ['Bahrain', 'BHR', 2009],
#  ['Bahrain', 'BHR', 2010],
#  ['Bahrain', 'BHR', 2011],
#  ['Bahrain', 'BHR', 2012],
#  ['Bahrain', 'BHR', 2013],
#  ['Bahrain', 'BHR', 2014],
#  ['Bahrain', 'BHR', 2015],
#  ['Bahrain', 'BHR', 2016],
#  ['Bahrain', 'BHR', 2017],
#  ['Bahrain', 'BHR', 2018],
#  ['Bahrain', 'BHR', 2019],
#  ['Bahrain', 'BHR', 2020],
#  ['Bahrain', 'BHR', 2021],
#  ['Bahamas, The', 'BHS', 2001],
#  ['Bahamas, The', 'BHS', 2002],
#  ['Bahamas, The', 'BHS', 2003],
#  ['Bahamas, The', 'BHS', 2004],
#  ['Bahamas, The', 'BHS', 2005],
#  ['Bahamas, The', 'BHS', 2006],
#  ['Bahamas, The', 'BHS', 2007],
#  ['Bahamas, The', 'BHS', 2008],
#  ['Bahamas, The', 'BHS', 2009],
#  ['Bahamas, The', 'BHS', 2010],
#  ['Bahamas, The', 'BHS', 2011],
#  ['Bahamas, The', 'BHS', 2012],
#  ['Bahamas, The', 'BHS', 2013],
#  ['Bahamas, The', 'BHS', 2014],
#  ['Bahamas, The', 'BHS', 2015],
#  ['Bahamas, The', 'BHS', 2016],
#  ['Bahamas, The', 'BHS', 2017],
#  ['Bahamas, The', 'BHS', 2018],
#  ['Bahamas, The', 'BHS', 2019],
#  ['Bahamas, The', 'BHS', 2020],
#  ['Bahamas, The', 'BHS', 2021],
#  ['Bosnia and Herzegovina', 'BIH', 2001],
#  ['Bosnia and Herzegovina', 'BIH', 2002],
#  ['Bosnia and Herzegovina', 'BIH', 2003],
#  ['Bosnia and Herzegovina', 'BIH', 2004],
#  ['Bosnia and Herzegovina', 'BIH', 2005],
#  ['Bosnia and Herzegovina', 'BIH', 2006],
#  ['Bosnia and Herzegovina', 'BIH', 2007],
#  ['Bosnia and Herzegovina', 'BIH', 2008],
#  ['Bosnia and Herzegovina', 'BIH', 2009],
#  ['Bosnia and Herzegovina', 'BIH', 2010],
#  ['Bosnia and Herzegovina', 'BIH', 2011],
#  ['Bosnia and Herzegovina', 'BIH', 2012],
#  ['Bosnia and Herzegovina', 'BIH', 2013],
#  ['Bosnia and Herzegovina', 'BIH', 2014],
#  ['Bosnia and Herzegovina', 'BIH', 2015],
#  ['Bosnia and Herzegovina', 'BIH', 2016],
#  ['Bosnia and Herzegovina', 'BIH', 2017],
#  ['Bosnia and Herzegovina', 'BIH', 2018],
#  ['Bosnia and Herzegovina', 'BIH', 2019],
#  ['Bosnia and Herzegovina', 'BIH', 2020],
#  ['Bosnia and Herzegovina', 'BIH', 2021],
#  ['Belarus', 'BLR', 2001],
#  ['Belarus', 'BLR', 2002],
#  ['Belarus', 'BLR', 2003],
#  ['Belarus', 'BLR', 2004],
#  ['Belarus', 'BLR', 2005],
#  ['Belarus', 'BLR', 2006],
#  ['Belarus', 'BLR', 2007],
#  ['Belarus', 'BLR', 2008],
#  ['Belarus', 'BLR', 2009],
#  ['Belarus', 'BLR', 2010],
#  ['Belarus', 'BLR', 2011],
#  ['Belarus', 'BLR', 2012],
#  ['Belarus', 'BLR', 2013],
#  ['Belarus', 'BLR', 2014],
#  ['Belarus', 'BLR', 2015],
#  ['Belarus', 'BLR', 2016],
#  ['Belarus', 'BLR', 2017],
#  ['Belarus', 'BLR', 2018],
#  ['Belarus', 'BLR', 2019],
#  ['Belarus', 'BLR', 2020],
#  ['Belarus', 'BLR', 2021],
#  ['Belize', 'BLZ', 2001],
#  ['Belize', 'BLZ', 2002],
#  ['Belize', 'BLZ', 2003],
#  ['Belize', 'BLZ', 2004],
#  ['Belize', 'BLZ', 2005],
#  ['Belize', 'BLZ', 2006],
#  ['Belize', 'BLZ', 2007],
#  ['Belize', 'BLZ', 2008],
#  ['Belize', 'BLZ', 2009],
#  ['Belize', 'BLZ', 2010],
#  ['Belize', 'BLZ', 2011],
#  ['Belize', 'BLZ', 2012],
#  ['Belize', 'BLZ', 2013],
#  ['Belize', 'BLZ', 2014],
#  ['Belize', 'BLZ', 2015],
#  ['Belize', 'BLZ', 2016],
#  ['Belize', 'BLZ', 2017],
#  ['Belize', 'BLZ', 2018],
#  ['Belize', 'BLZ', 2019],
#  ['Belize', 'BLZ', 2020],
#  ['Belize', 'BLZ', 2021],
#  ['Bermuda', 'BMU', 2001],
#  ['Bermuda', 'BMU', 2002],
#  ['Bermuda', 'BMU', 2003],
#  ['Bermuda', 'BMU', 2004],
#  ['Bermuda', 'BMU', 2005],
#  ['Bermuda', 'BMU', 2006],
#  ['Bermuda', 'BMU', 2007],
#  ['Bermuda', 'BMU', 2008],
#  ['Bermuda', 'BMU', 2009],
#  ['Bermuda', 'BMU', 2010],
#  ['Bermuda', 'BMU', 2011],
#  ['Bermuda', 'BMU', 2012],
#  ['Bermuda', 'BMU', 2013],
#  ['Bermuda', 'BMU', 2014],
#  ['Bermuda', 'BMU', 2015],
#  ['Bermuda', 'BMU', 2016],
#  ['Bermuda', 'BMU', 2017],
#  ['Bermuda', 'BMU', 2018],
#  ['Bermuda', 'BMU', 2019],
#  ['Bermuda', 'BMU', 2020],
#  ['Bermuda', 'BMU', 2021],
#  ['Bolivia', 'BOL', 2001],
#  ['Bolivia', 'BOL', 2002],
#  ['Bolivia', 'BOL', 2003],
#  ['Bolivia', 'BOL', 2004],
#  ['Bolivia', 'BOL', 2005],
#  ['Bolivia', 'BOL', 2006],
#  ['Bolivia', 'BOL', 2007],
#  ['Bolivia', 'BOL', 2008],
#  ['Bolivia', 'BOL', 2009],
#  ['Bolivia', 'BOL', 2010],
#  ['Bolivia', 'BOL', 2011],
#  ['Bolivia', 'BOL', 2012],
#  ['Bolivia', 'BOL', 2013],
#  ['Bolivia', 'BOL', 2014],
#  ['Bolivia', 'BOL', 2015],
#  ['Bolivia', 'BOL', 2016],
#  ['Bolivia', 'BOL', 2017],
#  ['Bolivia', 'BOL', 2018],
#  ['Bolivia', 'BOL', 2019],
#  ['Bolivia', 'BOL', 2020],
#  ['Bolivia', 'BOL', 2021],
#  ['Brazil', 'BRA', 2001],
#  ['Brazil', 'BRA', 2002],
#  ['Brazil', 'BRA', 2003],
#  ['Brazil', 'BRA', 2004],
#  ['Brazil', 'BRA', 2005],
#  ['Brazil', 'BRA', 2006],
#  ['Brazil', 'BRA', 2007],
#  ['Brazil', 'BRA', 2008],
#  ['Brazil', 'BRA', 2009],
#  ['Brazil', 'BRA', 2010],
#  ['Brazil', 'BRA', 2011],
#  ['Brazil', 'BRA', 2012],
#  ['Brazil', 'BRA', 2013],
#  ['Brazil', 'BRA', 2014],
#  ['Brazil', 'BRA', 2015],
#  ['Brazil', 'BRA', 2016],
#  ['Brazil', 'BRA', 2017],
#  ['Brazil', 'BRA', 2018],
#  ['Brazil', 'BRA', 2019],
#  ['Brazil', 'BRA', 2020],
#  ['Brazil', 'BRA', 2021],
#  ['Barbados', 'BRB', 2001],
#  ['Barbados', 'BRB', 2002],
#  ['Barbados', 'BRB', 2003],
#  ['Barbados', 'BRB', 2004],
#  ['Barbados', 'BRB', 2005],
#  ['Barbados', 'BRB', 2006],
#  ['Barbados', 'BRB', 2007],
#  ['Barbados', 'BRB', 2008],
#  ['Barbados', 'BRB', 2009],
#  ['Barbados', 'BRB', 2010],
#  ['Barbados', 'BRB', 2011],
#  ['Barbados', 'BRB', 2012],
#  ['Barbados', 'BRB', 2013],
#  ['Barbados', 'BRB', 2014],
#  ['Barbados', 'BRB', 2015],
#  ['Barbados', 'BRB', 2016],
#  ['Barbados', 'BRB', 2017],
#  ['Barbados', 'BRB', 2018],
#  ['Barbados', 'BRB', 2019],
#  ['Barbados', 'BRB', 2020],
#  ['Barbados', 'BRB', 2021],
#  ['Brunei Darussalam', 'BRN', 2001],
#  ['Brunei Darussalam', 'BRN', 2002],
#  ['Brunei Darussalam', 'BRN', 2003],
#  ['Brunei Darussalam', 'BRN', 2004],
#  ['Brunei Darussalam', 'BRN', 2005],
#  ['Brunei Darussalam', 'BRN', 2006],
#  ['Brunei Darussalam', 'BRN', 2007],
#  ['Brunei Darussalam', 'BRN', 2008],
#  ['Brunei Darussalam', 'BRN', 2009],
#  ['Brunei Darussalam', 'BRN', 2010],
#  ['Brunei Darussalam', 'BRN', 2011],
#  ['Brunei Darussalam', 'BRN', 2012],
#  ['Brunei Darussalam', 'BRN', 2013],
#  ['Brunei Darussalam', 'BRN', 2014],
#  ['Brunei Darussalam', 'BRN', 2015],
#  ['Brunei Darussalam', 'BRN', 2016],
#  ['Brunei Darussalam', 'BRN', 2017],
#  ['Brunei Darussalam', 'BRN', 2018],
#  ['Brunei Darussalam', 'BRN', 2019],
#  ['Brunei Darussalam', 'BRN', 2020],
#  ['Brunei Darussalam', 'BRN', 2021],
#  ['Bhutan', 'BTN', 2001],
#  ['Bhutan', 'BTN', 2002],
#  ['Bhutan', 'BTN', 2003],
#  ['Bhutan', 'BTN', 2004],
#  ['Bhutan', 'BTN', 2005],
#  ['Bhutan', 'BTN', 2006],
#  ['Bhutan', 'BTN', 2007],
#  ['Bhutan', 'BTN', 2008],
#  ['Bhutan', 'BTN', 2009],
#  ['Bhutan', 'BTN', 2010],
#  ['Bhutan', 'BTN', 2011],
#  ['Bhutan', 'BTN', 2012],
#  ['Bhutan', 'BTN', 2013],
#  ['Bhutan', 'BTN', 2014],
#  ['Bhutan', 'BTN', 2015],
#  ['Bhutan', 'BTN', 2016],
#  ['Bhutan', 'BTN', 2017],
#  ['Bhutan', 'BTN', 2018],
#  ['Bhutan', 'BTN', 2019],
#  ['Bhutan', 'BTN', 2020],
#  ['Bhutan', 'BTN', 2021],
#  ['Botswana', 'BWA', 2001],
#  ['Botswana', 'BWA', 2002],
#  ['Botswana', 'BWA', 2003],
#  ['Botswana', 'BWA', 2004],
#  ['Botswana', 'BWA', 2005],
#  ['Botswana', 'BWA', 2006],
#  ['Botswana', 'BWA', 2007],
#  ['Botswana', 'BWA', 2008],
#  ['Botswana', 'BWA', 2009],
#  ['Botswana', 'BWA', 2010],
#  ['Botswana', 'BWA', 2011],
#  ['Botswana', 'BWA', 2012],
#  ['Botswana', 'BWA', 2013],
#  ['Botswana', 'BWA', 2014],
#  ['Botswana', 'BWA', 2015],
#  ['Botswana', 'BWA', 2016],
#  ['Botswana', 'BWA', 2017],
#  ['Botswana', 'BWA', 2018],
#  ['Botswana', 'BWA', 2019],
#  ['Botswana', 'BWA', 2020],
#  ['Botswana', 'BWA', 2021],
#  ['Central African Republic', 'CAF', 2001],
#  ['Central African Republic', 'CAF', 2002],
#  ['Central African Republic', 'CAF', 2003],
#  ['Central African Republic', 'CAF', 2004],
#  ['Central African Republic', 'CAF', 2005],
#  ['Central African Republic', 'CAF', 2006],
#  ['Central African Republic', 'CAF', 2007],
#  ['Central African Republic', 'CAF', 2008],
#  ['Central African Republic', 'CAF', 2009],
#  ['Central African Republic', 'CAF', 2010],
#  ['Central African Republic', 'CAF', 2011],
#  ['Central African Republic', 'CAF', 2012],
#  ['Central African Republic', 'CAF', 2013],
#  ['Central African Republic', 'CAF', 2014],
#  ['Central African Republic', 'CAF', 2015],
#  ['Central African Republic', 'CAF', 2016],
#  ['Central African Republic', 'CAF', 2017],
#  ['Central African Republic', 'CAF', 2018],
#  ['Central African Republic', 'CAF', 2019],
#  ['Central African Republic', 'CAF', 2020],
#  ['Central African Republic', 'CAF', 2021],
#  ['Canada', 'CAN', 2001],
#  ['Canada', 'CAN', 2002],
#  ['Canada', 'CAN', 2003],
#  ['Canada', 'CAN', 2004],
#  ['Canada', 'CAN', 2005],
#  ['Canada', 'CAN', 2006],
#  ['Canada', 'CAN', 2007],
#  ['Canada', 'CAN', 2008],
#  ['Canada', 'CAN', 2009],
#  ['Canada', 'CAN', 2010],
#  ['Canada', 'CAN', 2011],
#  ['Canada', 'CAN', 2012],
#  ['Canada', 'CAN', 2013],
#  ['Canada', 'CAN', 2014],
#  ['Canada', 'CAN', 2015],
#  ['Canada', 'CAN', 2016],
#  ['Canada', 'CAN', 2017],
#  ['Canada', 'CAN', 2018],
#  ['Canada', 'CAN', 2019],
#  ['Canada', 'CAN', 2020],
#  ['Canada', 'CAN', 2021],
#  ['Central Europe and the Baltics', 'CEB', 2001],
#  ['Central Europe and the Baltics', 'CEB', 2002],
#  ['Central Europe and the Baltics', 'CEB', 2003],
#  ['Central Europe and the Baltics', 'CEB', 2004],
#  ['Central Europe and the Baltics', 'CEB', 2005],
#  ['Central Europe and the Baltics', 'CEB', 2006],
#  ['Central Europe and the Baltics', 'CEB', 2007],
#  ['Central Europe and the Baltics', 'CEB', 2008],
#  ['Central Europe and the Baltics', 'CEB', 2009],
#  ['Central Europe and the Baltics', 'CEB', 2010],
#  ['Central Europe and the Baltics', 'CEB', 2011],
#  ['Central Europe and the Baltics', 'CEB', 2012],
#  ['Central Europe and the Baltics', 'CEB', 2013],
#  ['Central Europe and the Baltics', 'CEB', 2014],
#  ['Central Europe and the Baltics', 'CEB', 2015],
#  ['Central Europe and the Baltics', 'CEB', 2016],
#  ['Central Europe and the Baltics', 'CEB', 2017],
#  ['Central Europe and the Baltics', 'CEB', 2018],
#  ['Central Europe and the Baltics', 'CEB', 2019],
#  ['Central Europe and the Baltics', 'CEB', 2020],
#  ['Central Europe and the Baltics', 'CEB', 2021],
#  ['Switzerland', 'CHE', 2001],
#  ['Switzerland', 'CHE', 2002],
#  ['Switzerland', 'CHE', 2003],
#  ['Switzerland', 'CHE', 2004],
#  ['Switzerland', 'CHE', 2005],
#  ['Switzerland', 'CHE', 2006],
#  ['Switzerland', 'CHE', 2007],
#  ['Switzerland', 'CHE', 2008],
#  ['Switzerland', 'CHE', 2009],
#  ['Switzerland', 'CHE', 2010],
#  ['Switzerland', 'CHE', 2011],
#  ['Switzerland', 'CHE', 2012],
#  ['Switzerland', 'CHE', 2013],
#  ['Switzerland', 'CHE', 2014],
#  ['Switzerland', 'CHE', 2015],
#  ['Switzerland', 'CHE', 2016],
#  ['Switzerland', 'CHE', 2017],
#  ['Switzerland', 'CHE', 2018],
#  ['Switzerland', 'CHE', 2019],
#  ['Switzerland', 'CHE', 2020],
#  ['Switzerland', 'CHE', 2021],
#  ['Channel Islands', 'CHI', 2001],
#  ['Channel Islands', 'CHI', 2002],
#  ['Channel Islands', 'CHI', 2003],
#  ['Channel Islands', 'CHI', 2004],
#  ['Channel Islands', 'CHI', 2005],
#  ['Channel Islands', 'CHI', 2006],
#  ['Channel Islands', 'CHI', 2007],
#  ['Channel Islands', 'CHI', 2008],
#  ['Channel Islands', 'CHI', 2009],
#  ['Channel Islands', 'CHI', 2010],
#  ['Channel Islands', 'CHI', 2011],
#  ['Channel Islands', 'CHI', 2012],
#  ['Channel Islands', 'CHI', 2013],
#  ['Channel Islands', 'CHI', 2014],
#  ['Channel Islands', 'CHI', 2015],
#  ['Channel Islands', 'CHI', 2016],
#  ['Channel Islands', 'CHI', 2017],
#  ['Channel Islands', 'CHI', 2018],
#  ['Channel Islands', 'CHI', 2019],
#  ['Channel Islands', 'CHI', 2020],
#  ['Channel Islands', 'CHI', 2021],
#  ['Chile', 'CHL', 2001],
#  ['Chile', 'CHL', 2002],
#  ['Chile', 'CHL', 2003],
#  ['Chile', 'CHL', 2004],
#  ['Chile', 'CHL', 2005],
#  ['Chile', 'CHL', 2006],
#  ['Chile', 'CHL', 2007],
#  ['Chile', 'CHL', 2008],
#  ['Chile', 'CHL', 2009],
#  ['Chile', 'CHL', 2010],
#  ['Chile', 'CHL', 2011],
#  ['Chile', 'CHL', 2012],
#  ['Chile', 'CHL', 2013],
#  ['Chile', 'CHL', 2014],
#  ['Chile', 'CHL', 2015],
#  ['Chile', 'CHL', 2016],
#  ['Chile', 'CHL', 2017],
#  ['Chile', 'CHL', 2018],
#  ['Chile', 'CHL', 2019],
#  ['Chile', 'CHL', 2020],
#  ['Chile', 'CHL', 2021],
#  ['China', 'CHN', 2001],
#  ['China', 'CHN', 2002],
#  ['China', 'CHN', 2003],
#  ['China', 'CHN', 2004],
#  ['China', 'CHN', 2005],
#  ['China', 'CHN', 2006],
#  ['China', 'CHN', 2007],
#  ['China', 'CHN', 2008],
#  ['China', 'CHN', 2009],
#  ['China', 'CHN', 2010],
#  ['China', 'CHN', 2011],
#  ['China', 'CHN', 2012],
#  ['China', 'CHN', 2013],
#  ['China', 'CHN', 2014],
#  ['China', 'CHN', 2015],
#  ['China', 'CHN', 2016],
#  ['China', 'CHN', 2017],
#  ['China', 'CHN', 2018],
#  ['China', 'CHN', 2019],
#  ['China', 'CHN', 2020],
#  ['China', 'CHN', 2021],
#  ["Cote d'Ivoire", 'CIV', 2001],
#  ["Cote d'Ivoire", 'CIV', 2002],
#  ["Cote d'Ivoire", 'CIV', 2003],
#  ["Cote d'Ivoire", 'CIV', 2004],
#  ["Cote d'Ivoire", 'CIV', 2005],
#  ["Cote d'Ivoire", 'CIV', 2006],
#  ["Cote d'Ivoire", 'CIV', 2007],
#  ["Cote d'Ivoire", 'CIV', 2008],
#  ["Cote d'Ivoire", 'CIV', 2009],
#  ["Cote d'Ivoire", 'CIV', 2010],
#  ["Cote d'Ivoire", 'CIV', 2011],
#  ["Cote d'Ivoire", 'CIV', 2012],
#  ["Cote d'Ivoire", 'CIV', 2013],
#  ["Cote d'Ivoire", 'CIV', 2014],
#  ["Cote d'Ivoire", 'CIV', 2015],
#  ["Cote d'Ivoire", 'CIV', 2016],
#  ["Cote d'Ivoire", 'CIV', 2017],
#  ["Cote d'Ivoire", 'CIV', 2018],
#  ["Cote d'Ivoire", 'CIV', 2019],
#  ["Cote d'Ivoire", 'CIV', 2020],
#  ["Cote d'Ivoire", 'CIV', 2021],
#  ['Cameroon', 'CMR', 2001],
#  ['Cameroon', 'CMR', 2002],
#  ['Cameroon', 'CMR', 2003],
#  ['Cameroon', 'CMR', 2004],
#  ['Cameroon', 'CMR', 2005],
#  ['Cameroon', 'CMR', 2006],
#  ['Cameroon', 'CMR', 2007],
#  ['Cameroon', 'CMR', 2008],
#  ['Cameroon', 'CMR', 2009],
#  ['Cameroon', 'CMR', 2010],
#  ['Cameroon', 'CMR', 2011],
#  ['Cameroon', 'CMR', 2012],
#  ['Cameroon', 'CMR', 2013],
#  ['Cameroon', 'CMR', 2014],
#  ['Cameroon', 'CMR', 2015],
#  ['Cameroon', 'CMR', 2016],
#  ['Cameroon', 'CMR', 2017],
#  ['Cameroon', 'CMR', 2018],
#  ['Cameroon', 'CMR', 2019],
#  ['Cameroon', 'CMR', 2020],
#  ['Cameroon', 'CMR', 2021],
#  ['Congo, Dem. Rep.', 'COD', 2001],
#  ['Congo, Dem. Rep.', 'COD', 2002],
#  ['Congo, Dem. Rep.', 'COD', 2003],
#  ['Congo, Dem. Rep.', 'COD', 2004],
#  ['Congo, Dem. Rep.', 'COD', 2005],
#  ['Congo, Dem. Rep.', 'COD', 2006],
#  ['Congo, Dem. Rep.', 'COD', 2007],
#  ['Congo, Dem. Rep.', 'COD', 2008],
#  ['Congo, Dem. Rep.', 'COD', 2009],
#  ['Congo, Dem. Rep.', 'COD', 2010],
#  ['Congo, Dem. Rep.', 'COD', 2011],
#  ['Congo, Dem. Rep.', 'COD', 2012],
#  ['Congo, Dem. Rep.', 'COD', 2013],
#  ['Congo, Dem. Rep.', 'COD', 2014],
#  ['Congo, Dem. Rep.', 'COD', 2015],
#  ['Congo, Dem. Rep.', 'COD', 2016],
#  ['Congo, Dem. Rep.', 'COD', 2017],
#  ['Congo, Dem. Rep.', 'COD', 2018],
#  ['Congo, Dem. Rep.', 'COD', 2019],
#  ['Congo, Dem. Rep.', 'COD', 2020],
#  ['Congo, Dem. Rep.', 'COD', 2021],
#  ['Congo, Rep.', 'COG', 2001],
#  ['Congo, Rep.', 'COG', 2002],
#  ['Congo, Rep.', 'COG', 2003],
#  ['Congo, Rep.', 'COG', 2004],
#  ['Congo, Rep.', 'COG', 2005],
#  ['Congo, Rep.', 'COG', 2006],
#  ['Congo, Rep.', 'COG', 2007],
#  ['Congo, Rep.', 'COG', 2008],
#  ['Congo, Rep.', 'COG', 2009],
#  ['Congo, Rep.', 'COG', 2010],
#  ['Congo, Rep.', 'COG', 2011],
#  ['Congo, Rep.', 'COG', 2012],
#  ['Congo, Rep.', 'COG', 2013],
#  ['Congo, Rep.', 'COG', 2014],
#  ['Congo, Rep.', 'COG', 2015],
#  ['Congo, Rep.', 'COG', 2016],
#  ['Congo, Rep.', 'COG', 2017],
#  ['Congo, Rep.', 'COG', 2018],
#  ['Congo, Rep.', 'COG', 2019],
#  ['Congo, Rep.', 'COG', 2020],
#  ['Congo, Rep.', 'COG', 2021],
#  ['Colombia', 'COL', 2001],
#  ['Colombia', 'COL', 2002],
#  ['Colombia', 'COL', 2003],
#  ['Colombia', 'COL', 2004],
#  ['Colombia', 'COL', 2005],
#  ['Colombia', 'COL', 2006],
#  ['Colombia', 'COL', 2007],
#  ['Colombia', 'COL', 2008],
#  ['Colombia', 'COL', 2009],
#  ['Colombia', 'COL', 2010],
#  ['Colombia', 'COL', 2011],
#  ['Colombia', 'COL', 2012],
#  ['Colombia', 'COL', 2013],
#  ['Colombia', 'COL', 2014],
#  ['Colombia', 'COL', 2015],
#  ['Colombia', 'COL', 2016],
#  ['Colombia', 'COL', 2017],
#  ['Colombia', 'COL', 2018],
#  ['Colombia', 'COL', 2019],
#  ['Colombia', 'COL', 2020],
#  ['Colombia', 'COL', 2021],
#  ['Comoros', 'COM', 2001],
#  ['Comoros', 'COM', 2002],
#  ['Comoros', 'COM', 2003],
#  ['Comoros', 'COM', 2004],
#  ['Comoros', 'COM', 2005],
#  ['Comoros', 'COM', 2006],
#  ['Comoros', 'COM', 2007],
#  ['Comoros', 'COM', 2008],
#  ['Comoros', 'COM', 2009],
#  ['Comoros', 'COM', 2010],
#  ['Comoros', 'COM', 2011],
#  ['Comoros', 'COM', 2012],
#  ['Comoros', 'COM', 2013],
#  ['Comoros', 'COM', 2014],
#  ['Comoros', 'COM', 2015],
#  ['Comoros', 'COM', 2016],
#  ['Comoros', 'COM', 2017],
#  ['Comoros', 'COM', 2018],
#  ['Comoros', 'COM', 2019],
#  ['Comoros', 'COM', 2020],
#  ['Comoros', 'COM', 2021],
#  ['Cabo Verde', 'CPV', 2001],
#  ['Cabo Verde', 'CPV', 2002],
#  ['Cabo Verde', 'CPV', 2003],
#  ['Cabo Verde', 'CPV', 2004],
#  ['Cabo Verde', 'CPV', 2005],
#  ['Cabo Verde', 'CPV', 2006],
#  ['Cabo Verde', 'CPV', 2007],
#  ['Cabo Verde', 'CPV', 2008],
#  ['Cabo Verde', 'CPV', 2009],
#  ['Cabo Verde', 'CPV', 2010],
#  ['Cabo Verde', 'CPV', 2011],
#  ['Cabo Verde', 'CPV', 2012],
#  ['Cabo Verde', 'CPV', 2013],
#  ...]

# %%
df_historical_out = pd.DataFrame(coun_year, columns=['Country','ISO3', 'Year'])
df_historical_out
# Out:
#        Country ISO3  Year
# 0        Aruba  ABW  2001
# 1        Aruba  ABW  2002
# 2        Aruba  ABW  2003
# 3        Aruba  ABW  2004
# 4        Aruba  ABW  2005
# ...        ...  ...   ...
# 5581  Zimbabwe  ZWE  2017
# 5582  Zimbabwe  ZWE  2018
# 5583  Zimbabwe  ZWE  2019
# 5584  Zimbabwe  ZWE  2020
# 5585  Zimbabwe  ZWE  2021
#
# [5586 rows x 3 columns]

# %%
#just to check how 'loc' works
df_coal.set_index("Entity", inplace = True)
 
# Using the operator .loc[]
# to select single row
result = df_coal.loc["US Central Appalachian coal spot price index (BP)"]
 
# Show the dataframe
result
# Out:
#                                                    Code  Year  Coal - Prices
# Entity
# US Central Appalachian coal spot price index (BP)   NaN  2001      50.154652
# US Central Appalachian coal spot price index (BP)   NaN  2002      33.197983
# US Central Appalachian coal spot price index (BP)   NaN  2003      38.522705
# US Central Appalachian coal spot price index (BP)   NaN  2004      64.901741
# US Central Appalachian coal spot price index (BP)   NaN  2005      70.122353
# US Central Appalachian coal spot price index (BP)   NaN  2006      57.816715
# US Central Appalachian coal spot price index (BP)   NaN  2007      49.733181
# US Central Appalachian coal spot price index (BP)   NaN  2008     117.417641
# US Central Appalachian coal spot price index (BP)   NaN  2009      60.734612
# US Central Appalachian coal spot price index (BP)   NaN  2010      67.874123
# US Central Appalachian coal spot price index (BP)   NaN  2011      84.754982
# US Central Appalachian coal spot price index (BP)   NaN  2012      67.281364
# US Central Appalachian coal spot price index (BP)   NaN  2013      69.717232
# US Central Appalachian coal spot price index (BP)   NaN  2014      67.084145
# US Central Appalachian coal spot price index (BP)   NaN  2015      51.566441
# US Central Appalachian coal spot price index (BP)   NaN  2016      51.447731
# US Central Appalachian coal spot price index (BP)   NaN  2017      63.825291
# US Central Appalachian coal spot price index (BP)   NaN  2018      72.844009
# US Central Appalachian coal spot price index (BP)   NaN  2019      57.163982
# US Central Appalachian coal spot price index (BP)   NaN  2020      42.766369
# US Central Appalachian coal spot price index (BP)   NaN  2021      68.538139

# %%
df_coal=pd.read_csv("../row_data/coal-prices.csv")
df_coal.set_index("Year", inplace = True)
# Using the operator .loc[]
# to select single row
average_prices=[]

for y in years:
    yp = np.average(df_coal.loc[y]['Coal - Prices'])
    average_prices.append(yp)

average_prices=np.array(average_prices)
prices=average_prices*1.346
p=[]
for i in countries:
    p=np.append(p,prices)

# %%
df_historical_out['cost_enfu_fuel_coal_usd_per_m3']=p

# %%
df_historical_out
# Out:
#        Country ISO3  Year  cost_enfu_fuel_coal_usd_per_m3
# 0        Aruba  ABW  2001                       52.849382
# 1        Aruba  ABW  2002                       45.924822
# 2        Aruba  ABW  2003                       51.208908
# 3        Aruba  ABW  2004                       84.361326
# 4        Aruba  ABW  2005                       88.587222
# ...        ...  ...   ...                             ...
# 5581  Zimbabwe  ZWE  2017                      132.258810
# 5582  Zimbabwe  ZWE  2018                      146.988496
# 5583  Zimbabwe  ZWE  2019                      122.191827
# 5584  Zimbabwe  ZWE  2020                       97.156686
# 5585  Zimbabwe  ZWE  2021                      174.900150
#
# [5586 rows x 4 columns]

# %%
df_historical_out.to_csv('../input_to_sisepuede/historical/cost_enfu_fuel_coal_usd_per_m3.csv')

# %%
#Prediction for the next years will be the last historical value
years2=years
prices2=prices
for y in np.arange(min(years2),2051,1):
    if y not in years2:
        years2=np.append(years2,y)
        prices2=np.append(prices2,prices2[-1])

coun_year2=[]
for count in zip(countries,ISO3):
    for y_p in zip(years2,prices2):
        coun_year2.append([count[0],count[1],y_p[0],y_p[1]])
coun_year2
# Out:
# [['Aruba', 'ABW', 2001, 52.84938242721558],
#  ['Aruba', 'ABW', 2002, 45.92482209287371],
#  ['Aruba', 'ABW', 2003, 51.20890788487026],
#  ['Aruba', 'ABW', 2004, 84.36132649557932],
#  ['Aruba', 'ABW', 2005, 88.58722214181083],
#  ['Aruba', 'ABW', 2006, 87.22858373369489],
#  ['Aruba', 'ABW', 2007, 103.44982431248258],
#  ['Aruba', 'ABW', 2008, 188.0238875645229],
#  ['Aruba', 'ABW', 2009, 126.77544344002861],
#  ['Aruba', 'ABW', 2010, 143.92199740382603],
#  ['Aruba', 'ABW', 2011, 182.80651943751747],
#  ['Aruba', 'ABW', 2012, 154.31903261893137],
#  ['Aruba', 'ABW', 2013, 130.63713507952008],
#  ['Aruba', 'ABW', 2014, 113.9612682952881],
#  ['Aruba', 'ABW', 2015, 90.91651816667829],
#  ['Aruba', 'ABW', 2016, 93.8407817404611],
#  ['Aruba', 'ABW', 2017, 132.25881008148195],
#  ['Aruba', 'ABW', 2018, 146.98849624851775],
#  ['Aruba', 'ABW', 2019, 122.19182656424387],
#  ['Aruba', 'ABW', 2020, 97.15668559592112],
#  ['Aruba', 'ABW', 2021, 174.90014990670343],
#  ['Aruba', 'ABW', 2022, 174.90014990670343],
#  ['Aruba', 'ABW', 2023, 174.90014990670343],
#  ['Aruba', 'ABW', 2024, 174.90014990670343],
#  ['Aruba', 'ABW', 2025, 174.90014990670343],
#  ['Aruba', 'ABW', 2026, 174.90014990670343],
#  ['Aruba', 'ABW', 2027, 174.90014990670343],
#  ['Aruba', 'ABW', 2028, 174.90014990670343],
#  ['Aruba', 'ABW', 2029, 174.90014990670343],
#  ['Aruba', 'ABW', 2030, 174.90014990670343],
#  ['Aruba', 'ABW', 2031, 174.90014990670343],
#  ['Aruba', 'ABW', 2032, 174.90014990670343],
#  ['Aruba', 'ABW', 2033, 174.90014990670343],
#  ['Aruba', 'ABW', 2034, 174.90014990670343],
#  ['Aruba', 'ABW', 2035, 174.90014990670343],
#  ['Aruba', 'ABW', 2036, 174.90014990670343],
#  ['Aruba', 'ABW', 2037, 174.90014990670343],
#  ['Aruba', 'ABW', 2038, 174.90014990670343],
#  ['Aruba', 'ABW', 2039, 174.90014990670343],
#  ['Aruba', 'ABW', 2040, 174.90014990670343],
#  ['Aruba', 'ABW', 2041, 174.90014990670343],
#  ['Aruba', 'ABW', 2042, 174.90014990670343],
#  ['Aruba', 'ABW', 2043, 174.90014990670343],
#  ['Aruba', 'ABW', 2044, 174.90014990670343],
#  ['Aruba', 'ABW', 2045, 174.90014990670343],
#  ['Aruba', 'ABW', 2046, 174.90014990670343],
#  ['Aruba', 'ABW', 2047, 174.90014990670343],
#  ['Aruba', 'ABW', 2048, 174.90014990670343],
#  ['Aruba', 'ABW', 2049, 174.90014990670343],
#  ['Aruba', 'ABW', 2050, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2001, 52.84938242721558],
#  ['Africa Eastern and Southern', 'AFE', 2002, 45.92482209287371],
#  ['Africa Eastern and Southern', 'AFE', 2003, 51.20890788487026],
#  ['Africa Eastern and Southern', 'AFE', 2004, 84.36132649557932],
#  ['Africa Eastern and Southern', 'AFE', 2005, 88.58722214181083],
#  ['Africa Eastern and Southern', 'AFE', 2006, 87.22858373369489],
#  ['Africa Eastern and Southern', 'AFE', 2007, 103.44982431248258],
#  ['Africa Eastern and Southern', 'AFE', 2008, 188.0238875645229],
#  ['Africa Eastern and Southern', 'AFE', 2009, 126.77544344002861],
#  ['Africa Eastern and Southern', 'AFE', 2010, 143.92199740382603],
#  ['Africa Eastern and Southern', 'AFE', 2011, 182.80651943751747],
#  ['Africa Eastern and Southern', 'AFE', 2012, 154.31903261893137],
#  ['Africa Eastern and Southern', 'AFE', 2013, 130.63713507952008],
#  ['Africa Eastern and Southern', 'AFE', 2014, 113.9612682952881],
#  ['Africa Eastern and Southern', 'AFE', 2015, 90.91651816667829],
#  ['Africa Eastern and Southern', 'AFE', 2016, 93.8407817404611],
#  ['Africa Eastern and Southern', 'AFE', 2017, 132.25881008148195],
#  ['Africa Eastern and Southern', 'AFE', 2018, 146.98849624851775],
#  ['Africa Eastern and Southern', 'AFE', 2019, 122.19182656424387],
#  ['Africa Eastern and Southern', 'AFE', 2020, 97.15668559592112],
#  ['Africa Eastern and Southern', 'AFE', 2021, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2022, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2023, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2024, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2025, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2026, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2027, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2028, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2029, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2030, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2031, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2032, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2033, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2034, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2035, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2036, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2037, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2038, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2039, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2040, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2041, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2042, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2043, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2044, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2045, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2046, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2047, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2048, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2049, 174.90014990670343],
#  ['Africa Eastern and Southern', 'AFE', 2050, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2001, 52.84938242721558],
#  ['Afghanistan', 'AFG', 2002, 45.92482209287371],
#  ['Afghanistan', 'AFG', 2003, 51.20890788487026],
#  ['Afghanistan', 'AFG', 2004, 84.36132649557932],
#  ['Afghanistan', 'AFG', 2005, 88.58722214181083],
#  ['Afghanistan', 'AFG', 2006, 87.22858373369489],
#  ['Afghanistan', 'AFG', 2007, 103.44982431248258],
#  ['Afghanistan', 'AFG', 2008, 188.0238875645229],
#  ['Afghanistan', 'AFG', 2009, 126.77544344002861],
#  ['Afghanistan', 'AFG', 2010, 143.92199740382603],
#  ['Afghanistan', 'AFG', 2011, 182.80651943751747],
#  ['Afghanistan', 'AFG', 2012, 154.31903261893137],
#  ['Afghanistan', 'AFG', 2013, 130.63713507952008],
#  ['Afghanistan', 'AFG', 2014, 113.9612682952881],
#  ['Afghanistan', 'AFG', 2015, 90.91651816667829],
#  ['Afghanistan', 'AFG', 2016, 93.8407817404611],
#  ['Afghanistan', 'AFG', 2017, 132.25881008148195],
#  ['Afghanistan', 'AFG', 2018, 146.98849624851775],
#  ['Afghanistan', 'AFG', 2019, 122.19182656424387],
#  ['Afghanistan', 'AFG', 2020, 97.15668559592112],
#  ['Afghanistan', 'AFG', 2021, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2022, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2023, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2024, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2025, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2026, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2027, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2028, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2029, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2030, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2031, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2032, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2033, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2034, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2035, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2036, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2037, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2038, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2039, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2040, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2041, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2042, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2043, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2044, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2045, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2046, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2047, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2048, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2049, 174.90014990670343],
#  ['Afghanistan', 'AFG', 2050, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2001, 52.84938242721558],
#  ['Africa Western and Central', 'AFW', 2002, 45.92482209287371],
#  ['Africa Western and Central', 'AFW', 2003, 51.20890788487026],
#  ['Africa Western and Central', 'AFW', 2004, 84.36132649557932],
#  ['Africa Western and Central', 'AFW', 2005, 88.58722214181083],
#  ['Africa Western and Central', 'AFW', 2006, 87.22858373369489],
#  ['Africa Western and Central', 'AFW', 2007, 103.44982431248258],
#  ['Africa Western and Central', 'AFW', 2008, 188.0238875645229],
#  ['Africa Western and Central', 'AFW', 2009, 126.77544344002861],
#  ['Africa Western and Central', 'AFW', 2010, 143.92199740382603],
#  ['Africa Western and Central', 'AFW', 2011, 182.80651943751747],
#  ['Africa Western and Central', 'AFW', 2012, 154.31903261893137],
#  ['Africa Western and Central', 'AFW', 2013, 130.63713507952008],
#  ['Africa Western and Central', 'AFW', 2014, 113.9612682952881],
#  ['Africa Western and Central', 'AFW', 2015, 90.91651816667829],
#  ['Africa Western and Central', 'AFW', 2016, 93.8407817404611],
#  ['Africa Western and Central', 'AFW', 2017, 132.25881008148195],
#  ['Africa Western and Central', 'AFW', 2018, 146.98849624851775],
#  ['Africa Western and Central', 'AFW', 2019, 122.19182656424387],
#  ['Africa Western and Central', 'AFW', 2020, 97.15668559592112],
#  ['Africa Western and Central', 'AFW', 2021, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2022, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2023, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2024, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2025, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2026, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2027, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2028, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2029, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2030, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2031, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2032, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2033, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2034, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2035, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2036, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2037, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2038, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2039, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2040, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2041, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2042, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2043, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2044, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2045, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2046, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2047, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2048, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2049, 174.90014990670343],
#  ['Africa Western and Central', 'AFW', 2050, 174.90014990670343],
#  ['Angola', 'AGO', 2001, 52.84938242721558],
#  ['Angola', 'AGO', 2002, 45.92482209287371],
#  ['Angola', 'AGO', 2003, 51.20890788487026],
#  ['Angola', 'AGO', 2004, 84.36132649557932],
#  ['Angola', 'AGO', 2005, 88.58722214181083],
#  ['Angola', 'AGO', 2006, 87.22858373369489],
#  ['Angola', 'AGO', 2007, 103.44982431248258],
#  ['Angola', 'AGO', 2008, 188.0238875645229],
#  ['Angola', 'AGO', 2009, 126.77544344002861],
#  ['Angola', 'AGO', 2010, 143.92199740382603],
#  ['Angola', 'AGO', 2011, 182.80651943751747],
#  ['Angola', 'AGO', 2012, 154.31903261893137],
#  ['Angola', 'AGO', 2013, 130.63713507952008],
#  ['Angola', 'AGO', 2014, 113.9612682952881],
#  ['Angola', 'AGO', 2015, 90.91651816667829],
#  ['Angola', 'AGO', 2016, 93.8407817404611],
#  ['Angola', 'AGO', 2017, 132.25881008148195],
#  ['Angola', 'AGO', 2018, 146.98849624851775],
#  ['Angola', 'AGO', 2019, 122.19182656424387],
#  ['Angola', 'AGO', 2020, 97.15668559592112],
#  ['Angola', 'AGO', 2021, 174.90014990670343],
#  ['Angola', 'AGO', 2022, 174.90014990670343],
#  ['Angola', 'AGO', 2023, 174.90014990670343],
#  ['Angola', 'AGO', 2024, 174.90014990670343],
#  ['Angola', 'AGO', 2025, 174.90014990670343],
#  ['Angola', 'AGO', 2026, 174.90014990670343],
#  ['Angola', 'AGO', 2027, 174.90014990670343],
#  ['Angola', 'AGO', 2028, 174.90014990670343],
#  ['Angola', 'AGO', 2029, 174.90014990670343],
#  ['Angola', 'AGO', 2030, 174.90014990670343],
#  ['Angola', 'AGO', 2031, 174.90014990670343],
#  ['Angola', 'AGO', 2032, 174.90014990670343],
#  ['Angola', 'AGO', 2033, 174.90014990670343],
#  ['Angola', 'AGO', 2034, 174.90014990670343],
#  ['Angola', 'AGO', 2035, 174.90014990670343],
#  ['Angola', 'AGO', 2036, 174.90014990670343],
#  ['Angola', 'AGO', 2037, 174.90014990670343],
#  ['Angola', 'AGO', 2038, 174.90014990670343],
#  ['Angola', 'AGO', 2039, 174.90014990670343],
#  ['Angola', 'AGO', 2040, 174.90014990670343],
#  ['Angola', 'AGO', 2041, 174.90014990670343],
#  ['Angola', 'AGO', 2042, 174.90014990670343],
#  ['Angola', 'AGO', 2043, 174.90014990670343],
#  ['Angola', 'AGO', 2044, 174.90014990670343],
#  ['Angola', 'AGO', 2045, 174.90014990670343],
#  ['Angola', 'AGO', 2046, 174.90014990670343],
#  ['Angola', 'AGO', 2047, 174.90014990670343],
#  ['Angola', 'AGO', 2048, 174.90014990670343],
#  ['Angola', 'AGO', 2049, 174.90014990670343],
#  ['Angola', 'AGO', 2050, 174.90014990670343],
#  ['Albania', 'ALB', 2001, 52.84938242721558],
#  ['Albania', 'ALB', 2002, 45.92482209287371],
#  ['Albania', 'ALB', 2003, 51.20890788487026],
#  ['Albania', 'ALB', 2004, 84.36132649557932],
#  ['Albania', 'ALB', 2005, 88.58722214181083],
#  ['Albania', 'ALB', 2006, 87.22858373369489],
#  ['Albania', 'ALB', 2007, 103.44982431248258],
#  ['Albania', 'ALB', 2008, 188.0238875645229],
#  ['Albania', 'ALB', 2009, 126.77544344002861],
#  ['Albania', 'ALB', 2010, 143.92199740382603],
#  ['Albania', 'ALB', 2011, 182.80651943751747],
#  ['Albania', 'ALB', 2012, 154.31903261893137],
#  ['Albania', 'ALB', 2013, 130.63713507952008],
#  ['Albania', 'ALB', 2014, 113.9612682952881],
#  ['Albania', 'ALB', 2015, 90.91651816667829],
#  ['Albania', 'ALB', 2016, 93.8407817404611],
#  ['Albania', 'ALB', 2017, 132.25881008148195],
#  ['Albania', 'ALB', 2018, 146.98849624851775],
#  ['Albania', 'ALB', 2019, 122.19182656424387],
#  ['Albania', 'ALB', 2020, 97.15668559592112],
#  ['Albania', 'ALB', 2021, 174.90014990670343],
#  ['Albania', 'ALB', 2022, 174.90014990670343],
#  ['Albania', 'ALB', 2023, 174.90014990670343],
#  ['Albania', 'ALB', 2024, 174.90014990670343],
#  ['Albania', 'ALB', 2025, 174.90014990670343],
#  ['Albania', 'ALB', 2026, 174.90014990670343],
#  ['Albania', 'ALB', 2027, 174.90014990670343],
#  ['Albania', 'ALB', 2028, 174.90014990670343],
#  ['Albania', 'ALB', 2029, 174.90014990670343],
#  ['Albania', 'ALB', 2030, 174.90014990670343],
#  ['Albania', 'ALB', 2031, 174.90014990670343],
#  ['Albania', 'ALB', 2032, 174.90014990670343],
#  ['Albania', 'ALB', 2033, 174.90014990670343],
#  ['Albania', 'ALB', 2034, 174.90014990670343],
#  ['Albania', 'ALB', 2035, 174.90014990670343],
#  ['Albania', 'ALB', 2036, 174.90014990670343],
#  ['Albania', 'ALB', 2037, 174.90014990670343],
#  ['Albania', 'ALB', 2038, 174.90014990670343],
#  ['Albania', 'ALB', 2039, 174.90014990670343],
#  ['Albania', 'ALB', 2040, 174.90014990670343],
#  ['Albania', 'ALB', 2041, 174.90014990670343],
#  ['Albania', 'ALB', 2042, 174.90014990670343],
#  ['Albania', 'ALB', 2043, 174.90014990670343],
#  ['Albania', 'ALB', 2044, 174.90014990670343],
#  ['Albania', 'ALB', 2045, 174.90014990670343],
#  ['Albania', 'ALB', 2046, 174.90014990670343],
#  ['Albania', 'ALB', 2047, 174.90014990670343],
#  ['Albania', 'ALB', 2048, 174.90014990670343],
#  ['Albania', 'ALB', 2049, 174.90014990670343],
#  ['Albania', 'ALB', 2050, 174.90014990670343],
#  ['Andorra', 'AND', 2001, 52.84938242721558],
#  ['Andorra', 'AND', 2002, 45.92482209287371],
#  ['Andorra', 'AND', 2003, 51.20890788487026],
#  ['Andorra', 'AND', 2004, 84.36132649557932],
#  ['Andorra', 'AND', 2005, 88.58722214181083],
#  ['Andorra', 'AND', 2006, 87.22858373369489],
#  ['Andorra', 'AND', 2007, 103.44982431248258],
#  ['Andorra', 'AND', 2008, 188.0238875645229],
#  ['Andorra', 'AND', 2009, 126.77544344002861],
#  ['Andorra', 'AND', 2010, 143.92199740382603],
#  ['Andorra', 'AND', 2011, 182.80651943751747],
#  ['Andorra', 'AND', 2012, 154.31903261893137],
#  ['Andorra', 'AND', 2013, 130.63713507952008],
#  ['Andorra', 'AND', 2014, 113.9612682952881],
#  ['Andorra', 'AND', 2015, 90.91651816667829],
#  ['Andorra', 'AND', 2016, 93.8407817404611],
#  ['Andorra', 'AND', 2017, 132.25881008148195],
#  ['Andorra', 'AND', 2018, 146.98849624851775],
#  ['Andorra', 'AND', 2019, 122.19182656424387],
#  ['Andorra', 'AND', 2020, 97.15668559592112],
#  ['Andorra', 'AND', 2021, 174.90014990670343],
#  ['Andorra', 'AND', 2022, 174.90014990670343],
#  ['Andorra', 'AND', 2023, 174.90014990670343],
#  ['Andorra', 'AND', 2024, 174.90014990670343],
#  ['Andorra', 'AND', 2025, 174.90014990670343],
#  ['Andorra', 'AND', 2026, 174.90014990670343],
#  ['Andorra', 'AND', 2027, 174.90014990670343],
#  ['Andorra', 'AND', 2028, 174.90014990670343],
#  ['Andorra', 'AND', 2029, 174.90014990670343],
#  ['Andorra', 'AND', 2030, 174.90014990670343],
#  ['Andorra', 'AND', 2031, 174.90014990670343],
#  ['Andorra', 'AND', 2032, 174.90014990670343],
#  ['Andorra', 'AND', 2033, 174.90014990670343],
#  ['Andorra', 'AND', 2034, 174.90014990670343],
#  ['Andorra', 'AND', 2035, 174.90014990670343],
#  ['Andorra', 'AND', 2036, 174.90014990670343],
#  ['Andorra', 'AND', 2037, 174.90014990670343],
#  ['Andorra', 'AND', 2038, 174.90014990670343],
#  ['Andorra', 'AND', 2039, 174.90014990670343],
#  ['Andorra', 'AND', 2040, 174.90014990670343],
#  ['Andorra', 'AND', 2041, 174.90014990670343],
#  ['Andorra', 'AND', 2042, 174.90014990670343],
#  ['Andorra', 'AND', 2043, 174.90014990670343],
#  ['Andorra', 'AND', 2044, 174.90014990670343],
#  ['Andorra', 'AND', 2045, 174.90014990670343],
#  ['Andorra', 'AND', 2046, 174.90014990670343],
#  ['Andorra', 'AND', 2047, 174.90014990670343],
#  ['Andorra', 'AND', 2048, 174.90014990670343],
#  ['Andorra', 'AND', 2049, 174.90014990670343],
#  ['Andorra', 'AND', 2050, 174.90014990670343],
#  ['Arab World', 'ARB', 2001, 52.84938242721558],
#  ['Arab World', 'ARB', 2002, 45.92482209287371],
#  ['Arab World', 'ARB', 2003, 51.20890788487026],
#  ['Arab World', 'ARB', 2004, 84.36132649557932],
#  ['Arab World', 'ARB', 2005, 88.58722214181083],
#  ['Arab World', 'ARB', 2006, 87.22858373369489],
#  ['Arab World', 'ARB', 2007, 103.44982431248258],
#  ['Arab World', 'ARB', 2008, 188.0238875645229],
#  ['Arab World', 'ARB', 2009, 126.77544344002861],
#  ['Arab World', 'ARB', 2010, 143.92199740382603],
#  ['Arab World', 'ARB', 2011, 182.80651943751747],
#  ['Arab World', 'ARB', 2012, 154.31903261893137],
#  ['Arab World', 'ARB', 2013, 130.63713507952008],
#  ['Arab World', 'ARB', 2014, 113.9612682952881],
#  ['Arab World', 'ARB', 2015, 90.91651816667829],
#  ['Arab World', 'ARB', 2016, 93.8407817404611],
#  ['Arab World', 'ARB', 2017, 132.25881008148195],
#  ['Arab World', 'ARB', 2018, 146.98849624851775],
#  ['Arab World', 'ARB', 2019, 122.19182656424387],
#  ['Arab World', 'ARB', 2020, 97.15668559592112],
#  ['Arab World', 'ARB', 2021, 174.90014990670343],
#  ['Arab World', 'ARB', 2022, 174.90014990670343],
#  ['Arab World', 'ARB', 2023, 174.90014990670343],
#  ['Arab World', 'ARB', 2024, 174.90014990670343],
#  ['Arab World', 'ARB', 2025, 174.90014990670343],
#  ['Arab World', 'ARB', 2026, 174.90014990670343],
#  ['Arab World', 'ARB', 2027, 174.90014990670343],
#  ['Arab World', 'ARB', 2028, 174.90014990670343],
#  ['Arab World', 'ARB', 2029, 174.90014990670343],
#  ['Arab World', 'ARB', 2030, 174.90014990670343],
#  ['Arab World', 'ARB', 2031, 174.90014990670343],
#  ['Arab World', 'ARB', 2032, 174.90014990670343],
#  ['Arab World', 'ARB', 2033, 174.90014990670343],
#  ['Arab World', 'ARB', 2034, 174.90014990670343],
#  ['Arab World', 'ARB', 2035, 174.90014990670343],
#  ['Arab World', 'ARB', 2036, 174.90014990670343],
#  ['Arab World', 'ARB', 2037, 174.90014990670343],
#  ['Arab World', 'ARB', 2038, 174.90014990670343],
#  ['Arab World', 'ARB', 2039, 174.90014990670343],
#  ['Arab World', 'ARB', 2040, 174.90014990670343],
#  ['Arab World', 'ARB', 2041, 174.90014990670343],
#  ['Arab World', 'ARB', 2042, 174.90014990670343],
#  ['Arab World', 'ARB', 2043, 174.90014990670343],
#  ['Arab World', 'ARB', 2044, 174.90014990670343],
#  ['Arab World', 'ARB', 2045, 174.90014990670343],
#  ['Arab World', 'ARB', 2046, 174.90014990670343],
#  ['Arab World', 'ARB', 2047, 174.90014990670343],
#  ['Arab World', 'ARB', 2048, 174.90014990670343],
#  ['Arab World', 'ARB', 2049, 174.90014990670343],
#  ['Arab World', 'ARB', 2050, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2001, 52.84938242721558],
#  ['United Arab Emirates', 'ARE', 2002, 45.92482209287371],
#  ['United Arab Emirates', 'ARE', 2003, 51.20890788487026],
#  ['United Arab Emirates', 'ARE', 2004, 84.36132649557932],
#  ['United Arab Emirates', 'ARE', 2005, 88.58722214181083],
#  ['United Arab Emirates', 'ARE', 2006, 87.22858373369489],
#  ['United Arab Emirates', 'ARE', 2007, 103.44982431248258],
#  ['United Arab Emirates', 'ARE', 2008, 188.0238875645229],
#  ['United Arab Emirates', 'ARE', 2009, 126.77544344002861],
#  ['United Arab Emirates', 'ARE', 2010, 143.92199740382603],
#  ['United Arab Emirates', 'ARE', 2011, 182.80651943751747],
#  ['United Arab Emirates', 'ARE', 2012, 154.31903261893137],
#  ['United Arab Emirates', 'ARE', 2013, 130.63713507952008],
#  ['United Arab Emirates', 'ARE', 2014, 113.9612682952881],
#  ['United Arab Emirates', 'ARE', 2015, 90.91651816667829],
#  ['United Arab Emirates', 'ARE', 2016, 93.8407817404611],
#  ['United Arab Emirates', 'ARE', 2017, 132.25881008148195],
#  ['United Arab Emirates', 'ARE', 2018, 146.98849624851775],
#  ['United Arab Emirates', 'ARE', 2019, 122.19182656424387],
#  ['United Arab Emirates', 'ARE', 2020, 97.15668559592112],
#  ['United Arab Emirates', 'ARE', 2021, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2022, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2023, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2024, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2025, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2026, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2027, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2028, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2029, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2030, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2031, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2032, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2033, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2034, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2035, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2036, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2037, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2038, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2039, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2040, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2041, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2042, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2043, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2044, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2045, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2046, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2047, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2048, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2049, 174.90014990670343],
#  ['United Arab Emirates', 'ARE', 2050, 174.90014990670343],
#  ['Argentina', 'ARG', 2001, 52.84938242721558],
#  ['Argentina', 'ARG', 2002, 45.92482209287371],
#  ['Argentina', 'ARG', 2003, 51.20890788487026],
#  ['Argentina', 'ARG', 2004, 84.36132649557932],
#  ['Argentina', 'ARG', 2005, 88.58722214181083],
#  ['Argentina', 'ARG', 2006, 87.22858373369489],
#  ['Argentina', 'ARG', 2007, 103.44982431248258],
#  ['Argentina', 'ARG', 2008, 188.0238875645229],
#  ['Argentina', 'ARG', 2009, 126.77544344002861],
#  ['Argentina', 'ARG', 2010, 143.92199740382603],
#  ['Argentina', 'ARG', 2011, 182.80651943751747],
#  ['Argentina', 'ARG', 2012, 154.31903261893137],
#  ['Argentina', 'ARG', 2013, 130.63713507952008],
#  ['Argentina', 'ARG', 2014, 113.9612682952881],
#  ['Argentina', 'ARG', 2015, 90.91651816667829],
#  ['Argentina', 'ARG', 2016, 93.8407817404611],
#  ['Argentina', 'ARG', 2017, 132.25881008148195],
#  ['Argentina', 'ARG', 2018, 146.98849624851775],
#  ['Argentina', 'ARG', 2019, 122.19182656424387],
#  ['Argentina', 'ARG', 2020, 97.15668559592112],
#  ['Argentina', 'ARG', 2021, 174.90014990670343],
#  ['Argentina', 'ARG', 2022, 174.90014990670343],
#  ['Argentina', 'ARG', 2023, 174.90014990670343],
#  ['Argentina', 'ARG', 2024, 174.90014990670343],
#  ['Argentina', 'ARG', 2025, 174.90014990670343],
#  ['Argentina', 'ARG', 2026, 174.90014990670343],
#  ['Argentina', 'ARG', 2027, 174.90014990670343],
#  ['Argentina', 'ARG', 2028, 174.90014990670343],
#  ['Argentina', 'ARG', 2029, 174.90014990670343],
#  ['Argentina', 'ARG', 2030, 174.90014990670343],
#  ['Argentina', 'ARG', 2031, 174.90014990670343],
#  ['Argentina', 'ARG', 2032, 174.90014990670343],
#  ['Argentina', 'ARG', 2033, 174.90014990670343],
#  ['Argentina', 'ARG', 2034, 174.90014990670343],
#  ['Argentina', 'ARG', 2035, 174.90014990670343],
#  ['Argentina', 'ARG', 2036, 174.90014990670343],
#  ['Argentina', 'ARG', 2037, 174.90014990670343],
#  ['Argentina', 'ARG', 2038, 174.90014990670343],
#  ['Argentina', 'ARG', 2039, 174.90014990670343],
#  ['Argentina', 'ARG', 2040, 174.90014990670343],
#  ['Argentina', 'ARG', 2041, 174.90014990670343],
#  ['Argentina', 'ARG', 2042, 174.90014990670343],
#  ['Argentina', 'ARG', 2043, 174.90014990670343],
#  ['Argentina', 'ARG', 2044, 174.90014990670343],
#  ['Argentina', 'ARG', 2045, 174.90014990670343],
#  ['Argentina', 'ARG', 2046, 174.90014990670343],
#  ['Argentina', 'ARG', 2047, 174.90014990670343],
#  ['Argentina', 'ARG', 2048, 174.90014990670343],
#  ['Argentina', 'ARG', 2049, 174.90014990670343],
#  ['Argentina', 'ARG', 2050, 174.90014990670343],
#  ['Armenia', 'ARM', 2001, 52.84938242721558],
#  ['Armenia', 'ARM', 2002, 45.92482209287371],
#  ['Armenia', 'ARM', 2003, 51.20890788487026],
#  ['Armenia', 'ARM', 2004, 84.36132649557932],
#  ['Armenia', 'ARM', 2005, 88.58722214181083],
#  ['Armenia', 'ARM', 2006, 87.22858373369489],
#  ['Armenia', 'ARM', 2007, 103.44982431248258],
#  ['Armenia', 'ARM', 2008, 188.0238875645229],
#  ['Armenia', 'ARM', 2009, 126.77544344002861],
#  ['Armenia', 'ARM', 2010, 143.92199740382603],
#  ['Armenia', 'ARM', 2011, 182.80651943751747],
#  ['Armenia', 'ARM', 2012, 154.31903261893137],
#  ['Armenia', 'ARM', 2013, 130.63713507952008],
#  ['Armenia', 'ARM', 2014, 113.9612682952881],
#  ['Armenia', 'ARM', 2015, 90.91651816667829],
#  ['Armenia', 'ARM', 2016, 93.8407817404611],
#  ['Armenia', 'ARM', 2017, 132.25881008148195],
#  ['Armenia', 'ARM', 2018, 146.98849624851775],
#  ['Armenia', 'ARM', 2019, 122.19182656424387],
#  ['Armenia', 'ARM', 2020, 97.15668559592112],
#  ['Armenia', 'ARM', 2021, 174.90014990670343],
#  ['Armenia', 'ARM', 2022, 174.90014990670343],
#  ['Armenia', 'ARM', 2023, 174.90014990670343],
#  ['Armenia', 'ARM', 2024, 174.90014990670343],
#  ['Armenia', 'ARM', 2025, 174.90014990670343],
#  ['Armenia', 'ARM', 2026, 174.90014990670343],
#  ['Armenia', 'ARM', 2027, 174.90014990670343],
#  ['Armenia', 'ARM', 2028, 174.90014990670343],
#  ['Armenia', 'ARM', 2029, 174.90014990670343],
#  ['Armenia', 'ARM', 2030, 174.90014990670343],
#  ['Armenia', 'ARM', 2031, 174.90014990670343],
#  ['Armenia', 'ARM', 2032, 174.90014990670343],
#  ['Armenia', 'ARM', 2033, 174.90014990670343],
#  ['Armenia', 'ARM', 2034, 174.90014990670343],
#  ['Armenia', 'ARM', 2035, 174.90014990670343],
#  ['Armenia', 'ARM', 2036, 174.90014990670343],
#  ['Armenia', 'ARM', 2037, 174.90014990670343],
#  ['Armenia', 'ARM', 2038, 174.90014990670343],
#  ['Armenia', 'ARM', 2039, 174.90014990670343],
#  ['Armenia', 'ARM', 2040, 174.90014990670343],
#  ['Armenia', 'ARM', 2041, 174.90014990670343],
#  ['Armenia', 'ARM', 2042, 174.90014990670343],
#  ['Armenia', 'ARM', 2043, 174.90014990670343],
#  ['Armenia', 'ARM', 2044, 174.90014990670343],
#  ['Armenia', 'ARM', 2045, 174.90014990670343],
#  ['Armenia', 'ARM', 2046, 174.90014990670343],
#  ['Armenia', 'ARM', 2047, 174.90014990670343],
#  ['Armenia', 'ARM', 2048, 174.90014990670343],
#  ['Armenia', 'ARM', 2049, 174.90014990670343],
#  ['Armenia', 'ARM', 2050, 174.90014990670343],
#  ['American Samoa', 'ASM', 2001, 52.84938242721558],
#  ['American Samoa', 'ASM', 2002, 45.92482209287371],
#  ['American Samoa', 'ASM', 2003, 51.20890788487026],
#  ['American Samoa', 'ASM', 2004, 84.36132649557932],
#  ['American Samoa', 'ASM', 2005, 88.58722214181083],
#  ['American Samoa', 'ASM', 2006, 87.22858373369489],
#  ['American Samoa', 'ASM', 2007, 103.44982431248258],
#  ['American Samoa', 'ASM', 2008, 188.0238875645229],
#  ['American Samoa', 'ASM', 2009, 126.77544344002861],
#  ['American Samoa', 'ASM', 2010, 143.92199740382603],
#  ['American Samoa', 'ASM', 2011, 182.80651943751747],
#  ['American Samoa', 'ASM', 2012, 154.31903261893137],
#  ['American Samoa', 'ASM', 2013, 130.63713507952008],
#  ['American Samoa', 'ASM', 2014, 113.9612682952881],
#  ['American Samoa', 'ASM', 2015, 90.91651816667829],
#  ['American Samoa', 'ASM', 2016, 93.8407817404611],
#  ['American Samoa', 'ASM', 2017, 132.25881008148195],
#  ['American Samoa', 'ASM', 2018, 146.98849624851775],
#  ['American Samoa', 'ASM', 2019, 122.19182656424387],
#  ['American Samoa', 'ASM', 2020, 97.15668559592112],
#  ['American Samoa', 'ASM', 2021, 174.90014990670343],
#  ['American Samoa', 'ASM', 2022, 174.90014990670343],
#  ['American Samoa', 'ASM', 2023, 174.90014990670343],
#  ['American Samoa', 'ASM', 2024, 174.90014990670343],
#  ['American Samoa', 'ASM', 2025, 174.90014990670343],
#  ['American Samoa', 'ASM', 2026, 174.90014990670343],
#  ['American Samoa', 'ASM', 2027, 174.90014990670343],
#  ['American Samoa', 'ASM', 2028, 174.90014990670343],
#  ['American Samoa', 'ASM', 2029, 174.90014990670343],
#  ['American Samoa', 'ASM', 2030, 174.90014990670343],
#  ['American Samoa', 'ASM', 2031, 174.90014990670343],
#  ['American Samoa', 'ASM', 2032, 174.90014990670343],
#  ['American Samoa', 'ASM', 2033, 174.90014990670343],
#  ['American Samoa', 'ASM', 2034, 174.90014990670343],
#  ['American Samoa', 'ASM', 2035, 174.90014990670343],
#  ['American Samoa', 'ASM', 2036, 174.90014990670343],
#  ['American Samoa', 'ASM', 2037, 174.90014990670343],
#  ['American Samoa', 'ASM', 2038, 174.90014990670343],
#  ['American Samoa', 'ASM', 2039, 174.90014990670343],
#  ['American Samoa', 'ASM', 2040, 174.90014990670343],
#  ['American Samoa', 'ASM', 2041, 174.90014990670343],
#  ['American Samoa', 'ASM', 2042, 174.90014990670343],
#  ['American Samoa', 'ASM', 2043, 174.90014990670343],
#  ['American Samoa', 'ASM', 2044, 174.90014990670343],
#  ['American Samoa', 'ASM', 2045, 174.90014990670343],
#  ['American Samoa', 'ASM', 2046, 174.90014990670343],
#  ['American Samoa', 'ASM', 2047, 174.90014990670343],
#  ['American Samoa', 'ASM', 2048, 174.90014990670343],
#  ['American Samoa', 'ASM', 2049, 174.90014990670343],
#  ['American Samoa', 'ASM', 2050, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2001, 52.84938242721558],
#  ['Antigua and Barbuda', 'ATG', 2002, 45.92482209287371],
#  ['Antigua and Barbuda', 'ATG', 2003, 51.20890788487026],
#  ['Antigua and Barbuda', 'ATG', 2004, 84.36132649557932],
#  ['Antigua and Barbuda', 'ATG', 2005, 88.58722214181083],
#  ['Antigua and Barbuda', 'ATG', 2006, 87.22858373369489],
#  ['Antigua and Barbuda', 'ATG', 2007, 103.44982431248258],
#  ['Antigua and Barbuda', 'ATG', 2008, 188.0238875645229],
#  ['Antigua and Barbuda', 'ATG', 2009, 126.77544344002861],
#  ['Antigua and Barbuda', 'ATG', 2010, 143.92199740382603],
#  ['Antigua and Barbuda', 'ATG', 2011, 182.80651943751747],
#  ['Antigua and Barbuda', 'ATG', 2012, 154.31903261893137],
#  ['Antigua and Barbuda', 'ATG', 2013, 130.63713507952008],
#  ['Antigua and Barbuda', 'ATG', 2014, 113.9612682952881],
#  ['Antigua and Barbuda', 'ATG', 2015, 90.91651816667829],
#  ['Antigua and Barbuda', 'ATG', 2016, 93.8407817404611],
#  ['Antigua and Barbuda', 'ATG', 2017, 132.25881008148195],
#  ['Antigua and Barbuda', 'ATG', 2018, 146.98849624851775],
#  ['Antigua and Barbuda', 'ATG', 2019, 122.19182656424387],
#  ['Antigua and Barbuda', 'ATG', 2020, 97.15668559592112],
#  ['Antigua and Barbuda', 'ATG', 2021, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2022, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2023, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2024, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2025, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2026, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2027, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2028, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2029, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2030, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2031, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2032, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2033, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2034, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2035, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2036, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2037, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2038, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2039, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2040, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2041, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2042, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2043, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2044, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2045, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2046, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2047, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2048, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2049, 174.90014990670343],
#  ['Antigua and Barbuda', 'ATG', 2050, 174.90014990670343],
#  ['Australia', 'AUS', 2001, 52.84938242721558],
#  ['Australia', 'AUS', 2002, 45.92482209287371],
#  ['Australia', 'AUS', 2003, 51.20890788487026],
#  ['Australia', 'AUS', 2004, 84.36132649557932],
#  ['Australia', 'AUS', 2005, 88.58722214181083],
#  ['Australia', 'AUS', 2006, 87.22858373369489],
#  ['Australia', 'AUS', 2007, 103.44982431248258],
#  ['Australia', 'AUS', 2008, 188.0238875645229],
#  ['Australia', 'AUS', 2009, 126.77544344002861],
#  ['Australia', 'AUS', 2010, 143.92199740382603],
#  ['Australia', 'AUS', 2011, 182.80651943751747],
#  ['Australia', 'AUS', 2012, 154.31903261893137],
#  ['Australia', 'AUS', 2013, 130.63713507952008],
#  ['Australia', 'AUS', 2014, 113.9612682952881],
#  ['Australia', 'AUS', 2015, 90.91651816667829],
#  ['Australia', 'AUS', 2016, 93.8407817404611],
#  ['Australia', 'AUS', 2017, 132.25881008148195],
#  ['Australia', 'AUS', 2018, 146.98849624851775],
#  ['Australia', 'AUS', 2019, 122.19182656424387],
#  ['Australia', 'AUS', 2020, 97.15668559592112],
#  ['Australia', 'AUS', 2021, 174.90014990670343],
#  ['Australia', 'AUS', 2022, 174.90014990670343],
#  ['Australia', 'AUS', 2023, 174.90014990670343],
#  ['Australia', 'AUS', 2024, 174.90014990670343],
#  ['Australia', 'AUS', 2025, 174.90014990670343],
#  ['Australia', 'AUS', 2026, 174.90014990670343],
#  ['Australia', 'AUS', 2027, 174.90014990670343],
#  ['Australia', 'AUS', 2028, 174.90014990670343],
#  ['Australia', 'AUS', 2029, 174.90014990670343],
#  ['Australia', 'AUS', 2030, 174.90014990670343],
#  ['Australia', 'AUS', 2031, 174.90014990670343],
#  ['Australia', 'AUS', 2032, 174.90014990670343],
#  ['Australia', 'AUS', 2033, 174.90014990670343],
#  ['Australia', 'AUS', 2034, 174.90014990670343],
#  ['Australia', 'AUS', 2035, 174.90014990670343],
#  ['Australia', 'AUS', 2036, 174.90014990670343],
#  ['Australia', 'AUS', 2037, 174.90014990670343],
#  ['Australia', 'AUS', 2038, 174.90014990670343],
#  ['Australia', 'AUS', 2039, 174.90014990670343],
#  ['Australia', 'AUS', 2040, 174.90014990670343],
#  ['Australia', 'AUS', 2041, 174.90014990670343],
#  ['Australia', 'AUS', 2042, 174.90014990670343],
#  ['Australia', 'AUS', 2043, 174.90014990670343],
#  ['Australia', 'AUS', 2044, 174.90014990670343],
#  ['Australia', 'AUS', 2045, 174.90014990670343],
#  ['Australia', 'AUS', 2046, 174.90014990670343],
#  ['Australia', 'AUS', 2047, 174.90014990670343],
#  ['Australia', 'AUS', 2048, 174.90014990670343],
#  ['Australia', 'AUS', 2049, 174.90014990670343],
#  ['Australia', 'AUS', 2050, 174.90014990670343],
#  ['Austria', 'AUT', 2001, 52.84938242721558],
#  ['Austria', 'AUT', 2002, 45.92482209287371],
#  ['Austria', 'AUT', 2003, 51.20890788487026],
#  ['Austria', 'AUT', 2004, 84.36132649557932],
#  ['Austria', 'AUT', 2005, 88.58722214181083],
#  ['Austria', 'AUT', 2006, 87.22858373369489],
#  ['Austria', 'AUT', 2007, 103.44982431248258],
#  ['Austria', 'AUT', 2008, 188.0238875645229],
#  ['Austria', 'AUT', 2009, 126.77544344002861],
#  ['Austria', 'AUT', 2010, 143.92199740382603],
#  ['Austria', 'AUT', 2011, 182.80651943751747],
#  ['Austria', 'AUT', 2012, 154.31903261893137],
#  ['Austria', 'AUT', 2013, 130.63713507952008],
#  ['Austria', 'AUT', 2014, 113.9612682952881],
#  ['Austria', 'AUT', 2015, 90.91651816667829],
#  ['Austria', 'AUT', 2016, 93.8407817404611],
#  ['Austria', 'AUT', 2017, 132.25881008148195],
#  ['Austria', 'AUT', 2018, 146.98849624851775],
#  ['Austria', 'AUT', 2019, 122.19182656424387],
#  ['Austria', 'AUT', 2020, 97.15668559592112],
#  ['Austria', 'AUT', 2021, 174.90014990670343],
#  ['Austria', 'AUT', 2022, 174.90014990670343],
#  ['Austria', 'AUT', 2023, 174.90014990670343],
#  ['Austria', 'AUT', 2024, 174.90014990670343],
#  ['Austria', 'AUT', 2025, 174.90014990670343],
#  ['Austria', 'AUT', 2026, 174.90014990670343],
#  ['Austria', 'AUT', 2027, 174.90014990670343],
#  ['Austria', 'AUT', 2028, 174.90014990670343],
#  ['Austria', 'AUT', 2029, 174.90014990670343],
#  ['Austria', 'AUT', 2030, 174.90014990670343],
#  ['Austria', 'AUT', 2031, 174.90014990670343],
#  ['Austria', 'AUT', 2032, 174.90014990670343],
#  ['Austria', 'AUT', 2033, 174.90014990670343],
#  ['Austria', 'AUT', 2034, 174.90014990670343],
#  ['Austria', 'AUT', 2035, 174.90014990670343],
#  ['Austria', 'AUT', 2036, 174.90014990670343],
#  ['Austria', 'AUT', 2037, 174.90014990670343],
#  ['Austria', 'AUT', 2038, 174.90014990670343],
#  ['Austria', 'AUT', 2039, 174.90014990670343],
#  ['Austria', 'AUT', 2040, 174.90014990670343],
#  ['Austria', 'AUT', 2041, 174.90014990670343],
#  ['Austria', 'AUT', 2042, 174.90014990670343],
#  ['Austria', 'AUT', 2043, 174.90014990670343],
#  ['Austria', 'AUT', 2044, 174.90014990670343],
#  ['Austria', 'AUT', 2045, 174.90014990670343],
#  ['Austria', 'AUT', 2046, 174.90014990670343],
#  ['Austria', 'AUT', 2047, 174.90014990670343],
#  ['Austria', 'AUT', 2048, 174.90014990670343],
#  ['Austria', 'AUT', 2049, 174.90014990670343],
#  ['Austria', 'AUT', 2050, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2001, 52.84938242721558],
#  ['Azerbaijan', 'AZE', 2002, 45.92482209287371],
#  ['Azerbaijan', 'AZE', 2003, 51.20890788487026],
#  ['Azerbaijan', 'AZE', 2004, 84.36132649557932],
#  ['Azerbaijan', 'AZE', 2005, 88.58722214181083],
#  ['Azerbaijan', 'AZE', 2006, 87.22858373369489],
#  ['Azerbaijan', 'AZE', 2007, 103.44982431248258],
#  ['Azerbaijan', 'AZE', 2008, 188.0238875645229],
#  ['Azerbaijan', 'AZE', 2009, 126.77544344002861],
#  ['Azerbaijan', 'AZE', 2010, 143.92199740382603],
#  ['Azerbaijan', 'AZE', 2011, 182.80651943751747],
#  ['Azerbaijan', 'AZE', 2012, 154.31903261893137],
#  ['Azerbaijan', 'AZE', 2013, 130.63713507952008],
#  ['Azerbaijan', 'AZE', 2014, 113.9612682952881],
#  ['Azerbaijan', 'AZE', 2015, 90.91651816667829],
#  ['Azerbaijan', 'AZE', 2016, 93.8407817404611],
#  ['Azerbaijan', 'AZE', 2017, 132.25881008148195],
#  ['Azerbaijan', 'AZE', 2018, 146.98849624851775],
#  ['Azerbaijan', 'AZE', 2019, 122.19182656424387],
#  ['Azerbaijan', 'AZE', 2020, 97.15668559592112],
#  ['Azerbaijan', 'AZE', 2021, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2022, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2023, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2024, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2025, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2026, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2027, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2028, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2029, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2030, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2031, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2032, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2033, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2034, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2035, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2036, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2037, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2038, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2039, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2040, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2041, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2042, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2043, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2044, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2045, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2046, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2047, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2048, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2049, 174.90014990670343],
#  ['Azerbaijan', 'AZE', 2050, 174.90014990670343],
#  ['Burundi', 'BDI', 2001, 52.84938242721558],
#  ['Burundi', 'BDI', 2002, 45.92482209287371],
#  ['Burundi', 'BDI', 2003, 51.20890788487026],
#  ['Burundi', 'BDI', 2004, 84.36132649557932],
#  ['Burundi', 'BDI', 2005, 88.58722214181083],
#  ['Burundi', 'BDI', 2006, 87.22858373369489],
#  ['Burundi', 'BDI', 2007, 103.44982431248258],
#  ['Burundi', 'BDI', 2008, 188.0238875645229],
#  ['Burundi', 'BDI', 2009, 126.77544344002861],
#  ['Burundi', 'BDI', 2010, 143.92199740382603],
#  ['Burundi', 'BDI', 2011, 182.80651943751747],
#  ['Burundi', 'BDI', 2012, 154.31903261893137],
#  ['Burundi', 'BDI', 2013, 130.63713507952008],
#  ['Burundi', 'BDI', 2014, 113.9612682952881],
#  ['Burundi', 'BDI', 2015, 90.91651816667829],
#  ['Burundi', 'BDI', 2016, 93.8407817404611],
#  ['Burundi', 'BDI', 2017, 132.25881008148195],
#  ['Burundi', 'BDI', 2018, 146.98849624851775],
#  ['Burundi', 'BDI', 2019, 122.19182656424387],
#  ['Burundi', 'BDI', 2020, 97.15668559592112],
#  ['Burundi', 'BDI', 2021, 174.90014990670343],
#  ['Burundi', 'BDI', 2022, 174.90014990670343],
#  ['Burundi', 'BDI', 2023, 174.90014990670343],
#  ['Burundi', 'BDI', 2024, 174.90014990670343],
#  ['Burundi', 'BDI', 2025, 174.90014990670343],
#  ['Burundi', 'BDI', 2026, 174.90014990670343],
#  ['Burundi', 'BDI', 2027, 174.90014990670343],
#  ['Burundi', 'BDI', 2028, 174.90014990670343],
#  ['Burundi', 'BDI', 2029, 174.90014990670343],
#  ['Burundi', 'BDI', 2030, 174.90014990670343],
#  ['Burundi', 'BDI', 2031, 174.90014990670343],
#  ['Burundi', 'BDI', 2032, 174.90014990670343],
#  ['Burundi', 'BDI', 2033, 174.90014990670343],
#  ['Burundi', 'BDI', 2034, 174.90014990670343],
#  ['Burundi', 'BDI', 2035, 174.90014990670343],
#  ['Burundi', 'BDI', 2036, 174.90014990670343],
#  ['Burundi', 'BDI', 2037, 174.90014990670343],
#  ['Burundi', 'BDI', 2038, 174.90014990670343],
#  ['Burundi', 'BDI', 2039, 174.90014990670343],
#  ['Burundi', 'BDI', 2040, 174.90014990670343],
#  ['Burundi', 'BDI', 2041, 174.90014990670343],
#  ['Burundi', 'BDI', 2042, 174.90014990670343],
#  ['Burundi', 'BDI', 2043, 174.90014990670343],
#  ['Burundi', 'BDI', 2044, 174.90014990670343],
#  ['Burundi', 'BDI', 2045, 174.90014990670343],
#  ['Burundi', 'BDI', 2046, 174.90014990670343],
#  ['Burundi', 'BDI', 2047, 174.90014990670343],
#  ['Burundi', 'BDI', 2048, 174.90014990670343],
#  ['Burundi', 'BDI', 2049, 174.90014990670343],
#  ['Burundi', 'BDI', 2050, 174.90014990670343],
#  ['Belgium', 'BEL', 2001, 52.84938242721558],
#  ['Belgium', 'BEL', 2002, 45.92482209287371],
#  ['Belgium', 'BEL', 2003, 51.20890788487026],
#  ['Belgium', 'BEL', 2004, 84.36132649557932],
#  ['Belgium', 'BEL', 2005, 88.58722214181083],
#  ['Belgium', 'BEL', 2006, 87.22858373369489],
#  ['Belgium', 'BEL', 2007, 103.44982431248258],
#  ['Belgium', 'BEL', 2008, 188.0238875645229],
#  ['Belgium', 'BEL', 2009, 126.77544344002861],
#  ['Belgium', 'BEL', 2010, 143.92199740382603],
#  ['Belgium', 'BEL', 2011, 182.80651943751747],
#  ['Belgium', 'BEL', 2012, 154.31903261893137],
#  ['Belgium', 'BEL', 2013, 130.63713507952008],
#  ['Belgium', 'BEL', 2014, 113.9612682952881],
#  ['Belgium', 'BEL', 2015, 90.91651816667829],
#  ['Belgium', 'BEL', 2016, 93.8407817404611],
#  ['Belgium', 'BEL', 2017, 132.25881008148195],
#  ['Belgium', 'BEL', 2018, 146.98849624851775],
#  ['Belgium', 'BEL', 2019, 122.19182656424387],
#  ['Belgium', 'BEL', 2020, 97.15668559592112],
#  ['Belgium', 'BEL', 2021, 174.90014990670343],
#  ['Belgium', 'BEL', 2022, 174.90014990670343],
#  ['Belgium', 'BEL', 2023, 174.90014990670343],
#  ['Belgium', 'BEL', 2024, 174.90014990670343],
#  ['Belgium', 'BEL', 2025, 174.90014990670343],
#  ['Belgium', 'BEL', 2026, 174.90014990670343],
#  ['Belgium', 'BEL', 2027, 174.90014990670343],
#  ['Belgium', 'BEL', 2028, 174.90014990670343],
#  ['Belgium', 'BEL', 2029, 174.90014990670343],
#  ['Belgium', 'BEL', 2030, 174.90014990670343],
#  ['Belgium', 'BEL', 2031, 174.90014990670343],
#  ['Belgium', 'BEL', 2032, 174.90014990670343],
#  ['Belgium', 'BEL', 2033, 174.90014990670343],
#  ['Belgium', 'BEL', 2034, 174.90014990670343],
#  ['Belgium', 'BEL', 2035, 174.90014990670343],
#  ['Belgium', 'BEL', 2036, 174.90014990670343],
#  ['Belgium', 'BEL', 2037, 174.90014990670343],
#  ['Belgium', 'BEL', 2038, 174.90014990670343],
#  ['Belgium', 'BEL', 2039, 174.90014990670343],
#  ['Belgium', 'BEL', 2040, 174.90014990670343],
#  ['Belgium', 'BEL', 2041, 174.90014990670343],
#  ['Belgium', 'BEL', 2042, 174.90014990670343],
#  ['Belgium', 'BEL', 2043, 174.90014990670343],
#  ['Belgium', 'BEL', 2044, 174.90014990670343],
#  ['Belgium', 'BEL', 2045, 174.90014990670343],
#  ['Belgium', 'BEL', 2046, 174.90014990670343],
#  ['Belgium', 'BEL', 2047, 174.90014990670343],
#  ['Belgium', 'BEL', 2048, 174.90014990670343],
#  ['Belgium', 'BEL', 2049, 174.90014990670343],
#  ['Belgium', 'BEL', 2050, 174.90014990670343],
#  ['Benin', 'BEN', 2001, 52.84938242721558],
#  ['Benin', 'BEN', 2002, 45.92482209287371],
#  ['Benin', 'BEN', 2003, 51.20890788487026],
#  ['Benin', 'BEN', 2004, 84.36132649557932],
#  ['Benin', 'BEN', 2005, 88.58722214181083],
#  ['Benin', 'BEN', 2006, 87.22858373369489],
#  ['Benin', 'BEN', 2007, 103.44982431248258],
#  ['Benin', 'BEN', 2008, 188.0238875645229],
#  ['Benin', 'BEN', 2009, 126.77544344002861],
#  ['Benin', 'BEN', 2010, 143.92199740382603],
#  ['Benin', 'BEN', 2011, 182.80651943751747],
#  ['Benin', 'BEN', 2012, 154.31903261893137],
#  ['Benin', 'BEN', 2013, 130.63713507952008],
#  ['Benin', 'BEN', 2014, 113.9612682952881],
#  ['Benin', 'BEN', 2015, 90.91651816667829],
#  ['Benin', 'BEN', 2016, 93.8407817404611],
#  ['Benin', 'BEN', 2017, 132.25881008148195],
#  ['Benin', 'BEN', 2018, 146.98849624851775],
#  ['Benin', 'BEN', 2019, 122.19182656424387],
#  ['Benin', 'BEN', 2020, 97.15668559592112],
#  ['Benin', 'BEN', 2021, 174.90014990670343],
#  ['Benin', 'BEN', 2022, 174.90014990670343],
#  ['Benin', 'BEN', 2023, 174.90014990670343],
#  ['Benin', 'BEN', 2024, 174.90014990670343],
#  ['Benin', 'BEN', 2025, 174.90014990670343],
#  ['Benin', 'BEN', 2026, 174.90014990670343],
#  ['Benin', 'BEN', 2027, 174.90014990670343],
#  ['Benin', 'BEN', 2028, 174.90014990670343],
#  ['Benin', 'BEN', 2029, 174.90014990670343],
#  ['Benin', 'BEN', 2030, 174.90014990670343],
#  ['Benin', 'BEN', 2031, 174.90014990670343],
#  ['Benin', 'BEN', 2032, 174.90014990670343],
#  ['Benin', 'BEN', 2033, 174.90014990670343],
#  ['Benin', 'BEN', 2034, 174.90014990670343],
#  ['Benin', 'BEN', 2035, 174.90014990670343],
#  ['Benin', 'BEN', 2036, 174.90014990670343],
#  ['Benin', 'BEN', 2037, 174.90014990670343],
#  ['Benin', 'BEN', 2038, 174.90014990670343],
#  ['Benin', 'BEN', 2039, 174.90014990670343],
#  ['Benin', 'BEN', 2040, 174.90014990670343],
#  ['Benin', 'BEN', 2041, 174.90014990670343],
#  ['Benin', 'BEN', 2042, 174.90014990670343],
#  ['Benin', 'BEN', 2043, 174.90014990670343],
#  ['Benin', 'BEN', 2044, 174.90014990670343],
#  ['Benin', 'BEN', 2045, 174.90014990670343],
#  ['Benin', 'BEN', 2046, 174.90014990670343],
#  ['Benin', 'BEN', 2047, 174.90014990670343],
#  ['Benin', 'BEN', 2048, 174.90014990670343],
#  ['Benin', 'BEN', 2049, 174.90014990670343],
#  ['Benin', 'BEN', 2050, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2001, 52.84938242721558],
#  ['Burkina Faso', 'BFA', 2002, 45.92482209287371],
#  ['Burkina Faso', 'BFA', 2003, 51.20890788487026],
#  ['Burkina Faso', 'BFA', 2004, 84.36132649557932],
#  ['Burkina Faso', 'BFA', 2005, 88.58722214181083],
#  ['Burkina Faso', 'BFA', 2006, 87.22858373369489],
#  ['Burkina Faso', 'BFA', 2007, 103.44982431248258],
#  ['Burkina Faso', 'BFA', 2008, 188.0238875645229],
#  ['Burkina Faso', 'BFA', 2009, 126.77544344002861],
#  ['Burkina Faso', 'BFA', 2010, 143.92199740382603],
#  ['Burkina Faso', 'BFA', 2011, 182.80651943751747],
#  ['Burkina Faso', 'BFA', 2012, 154.31903261893137],
#  ['Burkina Faso', 'BFA', 2013, 130.63713507952008],
#  ['Burkina Faso', 'BFA', 2014, 113.9612682952881],
#  ['Burkina Faso', 'BFA', 2015, 90.91651816667829],
#  ['Burkina Faso', 'BFA', 2016, 93.8407817404611],
#  ['Burkina Faso', 'BFA', 2017, 132.25881008148195],
#  ['Burkina Faso', 'BFA', 2018, 146.98849624851775],
#  ['Burkina Faso', 'BFA', 2019, 122.19182656424387],
#  ['Burkina Faso', 'BFA', 2020, 97.15668559592112],
#  ['Burkina Faso', 'BFA', 2021, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2022, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2023, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2024, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2025, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2026, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2027, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2028, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2029, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2030, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2031, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2032, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2033, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2034, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2035, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2036, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2037, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2038, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2039, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2040, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2041, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2042, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2043, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2044, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2045, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2046, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2047, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2048, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2049, 174.90014990670343],
#  ['Burkina Faso', 'BFA', 2050, 174.90014990670343],
#  ...]

# %%
df_projected_out = pd.DataFrame(coun_year2, columns=['Country','ISO3', 'Year','cost_enfu_fuel_coal_usd_per_m3'])
df_projected_out
# Out:
#         Country ISO3  Year  cost_enfu_fuel_coal_usd_per_m3
# 0         Aruba  ABW  2001                       52.849382
# 1         Aruba  ABW  2002                       45.924822
# 2         Aruba  ABW  2003                       51.208908
# 3         Aruba  ABW  2004                       84.361326
# 4         Aruba  ABW  2005                       88.587222
# ...         ...  ...   ...                             ...
# 13295  Zimbabwe  ZWE  2046                      174.900150
# 13296  Zimbabwe  ZWE  2047                      174.900150
# 13297  Zimbabwe  ZWE  2048                      174.900150
# 13298  Zimbabwe  ZWE  2049                      174.900150
# 13299  Zimbabwe  ZWE  2050                      174.900150
#
# [13300 rows x 4 columns]

# %%
df_projected_out.to_csv('../input_to_sisepuede/projected/cost_enfu_fuel_coal_usd_per_m3.csv')
