# %%
#Add parent and grandparent folder to sys.path and get variable name
import os
import sys
import inspect

parentdir = os.path.abspath('..')
grandparentdir=os.path.dirname(parentdir)
ggpdir=os.path.dirname(grandparentdir)

sys.path.insert(0, parentdir)
sys.path.insert(0, grandparentdir)
sys.path.insert(0, ggpdir)

# var_name=os.path.basename(parentdir)

# var_name


# #scoe crowss walk 
# scoe_energy_demands = {
#    consumpinit_scoe_gj_per_hh_residential_elec_appliances : [all but (residential space heating +residential cooking+ clothes dryers)]
#    consumpinit_scoe_gj_per_hh_residential_heat_energy : [residential space heating +residential cooking+ clothes dryers]
#    consumpinit_scoe_tj_per_mmmgdp_commercial_municipal_elec_appliances : (share of electric in residential [0-1.0])*0.9*[sheet: services, End use =="other building energy use" & PRoduct= "total final energy"]
#    consumpinit_scoe_tj_per_mmmgdp_commercial_municipal_heat_energy  (1- share of electri in residential)*0.9*[sheet: services, End use =="other building energy use" & PRoduct= "total final energy"]
#    consumpinit_scoe_tj_per_mmmgdp_other_se_elec_appliances :  (share of electric in residential [0-1.0])*0.1*[sheet: services, End use =="other building energy use"]
#    consumpinit_scoe_tj_per_mmmgdp_other_se_heat_energy (1-share of electric in residential [0-1.0])*0.1*[sheet: services, End use =="other building energy use"]


#  frac_scoe_X_coal : [Coal and coal products (PJ)      ]
#  frac_scoe_X_diesel : [0.4*Oil and oil products (PJ)      ]
#  frac_scoe_X_electricity : [Electricity (PJ)      ]
#  frac_scoe_X_gas_petroleum_liquid:  [0.4*Oil and oil products (PJ)      ]
#  frac_scoe_X_gasoline :  [0.1*Oil and oil products (PJ)      ]
#  frac_scoe_X_hydrocarbon_gas_liquids :  [0.1*Oil and oil products (PJ)      ]
#  frac_scoe_X_hydrogen : 0
#  frac_scoe_X_kerosene:  [Other sources (PJ)        ]
#  frac_scoe_X_natural_gas : [Gas (PJ) + Heat (PJ)              ]
#  frac_scoe_X_solid_biomass : [Biofuels and waste (PJ)   ]
 
#  frac_scoe_heat_energy_other_se_coal  frac_scoe_heat_energy_other_se_diesel 
#     frac_scoe_heat_energy_other_se_electricity 
# frac_scoe_heat_energy_other_se_gas_petroleum_liquid
#     frac_scoe_heat_energy_other_se_gasoline 
#     frac_scoe_heat_energy_other_se_hydrocarbon_gas_liquids 
#     frac_scoe_heat_energy_other_se_hydrogen 	 frac_scoe_heat_energy_other_se_kerosene 	
#     frac_scoe_heat_energy_other_se_natural_gas 	 frac_scoe_heat_energy_other_se_solid_biomass 
#     frac_scoe_heat_energy_residential_coal 	 frac_scoe_heat_energy_residential_diesel 
#     frac_scoe_heat_energy_residential_electricity 	 frac_scoe_heat_energy_residential_gas_petroleum_liquid 
#     frac_scoe_heat_energy_residential_gasoline 	 frac_scoe_heat_energy_residential_hydrocarbon_gas_liquids 
# frac_scoe_heat_energy_residential_hydrogen 	 frac_scoe_heat_energy_residential_kerosene 
#     frac_scoe_heat_energy_residential_natural_gas 	 frac_scoe_heat_energy_residential_solid_biomass

# %%
import pandas as pd
import numpy as np

df_countries=pd.read_csv("../row_data/Countries_ISO3.csv")
df_countries
# Out:
#                     Country Name ISO3
# 0                          Aruba  ABW
# 1    Africa Eastern and Southern  AFE
# 2                    Afghanistan  AFG
# 3     Africa Western and Central  AFW
# 4                         Angola  AGO
# ..                           ...  ...
# 261                       Kosovo  XKX
# 262                  Yemen, Rep.  YEM
# 263                 South Africa  ZAF
# 264                       Zambia  ZMB
# 265                     Zimbabwe  ZWE
#
# [266 rows x 2 columns]

# %%
#Socioeconomic varibles

# # #GDP
# df_gdp_hist = pd.read_csv(ggpdir+'/Socioeconomic/gdp_mmm_usd/input_to_sisepuede/historical/gdp_mmm_usd.csv')
# df_gdp_proj = pd.read_csv(ggpdir+'/Socioeconomic/gdp_mmm_usd/input_to_sisepuede/projected/gdp_mmm_usd.csv')

# df_gdp_hist = df_gdp_hist.sort_values(['Nation','Year'])

# df_gdp_proj = df_gdp_proj.sort_values(['Nation','Year'])

# df_gdp_all=pd.concat([df_gdp_hist,df_gdp_proj])

# df_gdp_all

# #Rural population
# df_popru_hist = pd.read_csv(ggpdir+
#         '/Socioeconomic/population_gnrl_rural/input_to_sisepuede/historical/population_gnrl_rural.csv')
# df_popru_proj = pd.read_csv(ggpdir+
#         '/Socioeconomic/population_gnrl_rural/input_to_sisepuede/projected/population_gnrl_rural.csv')

# df_popru_hist = df_popru_hist.sort_values(['Nation','Year'])

# df_popru_proj = df_popru_proj.sort_values(['Nation','Year'])

# df_popru_all=pd.concat([df_popru_hist,df_popru_proj])

# df_popru_all
# #Urban population
# df_popur_hist = pd.read_csv(ggpdir+
#         '/Socioeconomic/population_gnrl_urban/input_to_sisepuede/historical/population_gnrl_urban.csv')
# df_popur_proj = pd.read_csv(ggpdir+
#         '/Socioeconomic/population_gnrl_urban/input_to_sisepuede/projected/population_gnrl_urban.csv')

# df_popur_hist = df_popur_hist.sort_values(['Nation','Year'])

# df_popur_proj = df_popur_proj.sort_values(['Nation','Year'])

# df_popur_all=pd.concat([df_popur_hist,df_popur_proj])

# df_popur_all

# df_pop_ru_ur=df_popru_all.merge(df_popur_all,on=['Nation','Year','iso_code3'])

# df_pop_ru_ur

# df_pop_gdp_all=df_gdp_all.merge(df_pop_ru_ur,on=['Nation','Year','iso_code3'])

# df_pop_gdp_all

# %%
# No funciona:
# df_pop_gdp_all[df_pop_gdp_all['iso_code3']=='ABW']

# %%
#Socioeconomic varibles

#GDP
df_gdp_hist = pd.read_csv(ggpdir+'/Socioeconomic/gdp_mmm_usd/input_to_sisepuede/historical/gdp_mmm_usd.csv')
df_gdp_proj = pd.read_csv(ggpdir+'/Socioeconomic/gdp_mmm_usd/input_to_sisepuede/projected/gdp_mmm_usd.csv')

nation_gdp = sorted(set(df_gdp_proj['Nation'].values))

years_all = range(min(df_gdp_hist['Year'].values),max(df_gdp_proj['Year'].values)+1)
c_y_gdp = []
for c in nation_gdp:
    for y in years_all:
    
        try:
            gdp = df_gdp_hist.loc[(df_gdp_hist['Nation']==c) & (df_gdp_hist['Year']==y),]['gdp_mmm_usd'].values[0]
            
        except:
            gdp = df_gdp_proj.loc[(df_gdp_proj['Nation']==c) & (df_gdp_proj['Year']==y)]['gdp_mmm_usd'].values[0]
            
        c_y_gdp.append([c,y,gdp])

df_gdp_all = pd.DataFrame(c_y_gdp,columns=['Nation', 'Year', 'gdp_mmm_usd'])



#Rural population
df_popru_hist = pd.read_csv(ggpdir+
        '/Socioeconomic/population_gnrl_rural/input_to_sisepuede/historical/population_gnrl_rural.csv')
df_popru_proj = pd.read_csv(ggpdir+
        '/Socioeconomic/population_gnrl_rural/input_to_sisepuede/projected/population_gnrl_rural.csv')

#Urban population
df_popur_hist = pd.read_csv(ggpdir+
        '/Socioeconomic/population_gnrl_urban/input_to_sisepuede/historical/population_gnrl_urban.csv')
df_popur_proj = pd.read_csv(ggpdir+
        '/Socioeconomic/population_gnrl_urban/input_to_sisepuede/projected/population_gnrl_urban.csv')

nation_pop = sorted(set(df_popur_proj['Nation'].values))

years_all = range(min(df_popur_hist['Year'].values),max(df_popur_proj['Year'].values)+1)
c_y_pop = []
for c in nation_pop:
    for y in years_all:
    
        try:
            pop_ur = df_popur_hist.loc[(df_popur_hist['Nation']==c) &
                                       (df_popur_hist['Year']==y),]['population_gnrl_urban'].values[0]
            pop_ru = df_popru_hist.loc[(df_popru_hist['Nation']==c) &
                                       (df_popru_hist['Year']==y),]['population_gnrl_rural'].values[0]
            
        except:
            pop_ur = df_popur_proj.loc[(df_popur_proj['Nation']==c) &
                                       (df_popur_proj['Year']==y),]['population_gnrl_urban'].values[0]
            pop_ru = df_popru_proj.loc[(df_popru_proj['Nation']==c) &
                                       (df_popru_proj['Year']==y),]['population_gnrl_rural'].values[0]
            
        c_y_pop.append([c,y,pop_ur,pop_ru])

df_pop_all = pd.DataFrame(c_y_pop,columns=['Nation', 'Year', 'population_gnrl_urban','population_gnrl_rural'])

#All Together
nation_pop_gdp = sorted(set(nation_pop).intersection(set(nation_gdp)))
years_all = range(min(df_popur_hist['Year'].values),max(df_popur_proj['Year'].values)+1)
c_y_pop_gdp = []
for c in nation_pop_gdp:
    iso3 = df_gdp_hist.loc[df_gdp_hist['Nation']==c]['iso_code3'].values[0]
    for y in years_all:
        pop_ur = df_pop_all.loc[(df_pop_all['Nation']==c) &
                                       (df_pop_all['Year']==y),]['population_gnrl_urban'].values[0]
        
        pop_ru = df_pop_all.loc[(df_pop_all['Nation']==c) &
                                       (df_pop_all['Year']==y),]['population_gnrl_rural'].values[0]
        
        gdp = df_gdp_all.loc[(df_gdp_all['Nation']==c) & (df_gdp_all['Year']==y)]['gdp_mmm_usd'].values[0]
        
        c_y_pop_gdp.append([c,iso3,y,pop_ur,pop_ru,gdp])
df_pop_gdp_all = pd.DataFrame(c_y_pop_gdp,columns=['Nation','iso_code3', 'Year',
                                                   'population_gnrl_urban',
                                                   'population_gnrl_rural',
                                                   'gdp_mmm_usd'])
df_pop_gdp_all['gdp_percap']=df_pop_gdp_all.apply(lambda row:
    row['gdp_mmm_usd']/(row['population_gnrl_urban']+row['population_gnrl_rural']),axis=1)
df_pop_gdp_all
# Out:
#            Nation iso_code3  Year  population_gnrl_urban  \
# 0     Afghanistan       AFG  2011           7.212518e+06
# 1     Afghanistan       AFG  2012           7.528589e+06
# 2     Afghanistan       AFG  2013           7.865068e+06
# 3     Afghanistan       AFG  2014           8.204880e+06
# 4     Afghanistan       AFG  2015           8.535606e+06
# ...           ...       ...   ...                    ...
# 7275     Zimbabwe       ZWE  2046           5.352032e+06
# 7276     Zimbabwe       ZWE  2047           5.384492e+06
# 7277     Zimbabwe       ZWE  2048           5.416953e+06
# 7278     Zimbabwe       ZWE  2049           5.449414e+06
# 7279     Zimbabwe       ZWE  2050           5.481874e+06
#
#       population_gnrl_rural  gdp_mmm_usd  gdp_percap
# 0              2.290489e+07    35.369178    0.000001
# 1              2.363279e+07    38.085386    0.000001
# 2              2.440452e+07    40.801594    0.000001
# 3              2.516592e+07    43.517802    0.000001
# ...

# %%
# Si funciona
# df_pop_gdp_all[df_pop_gdp_all['iso_code3']=='ABW']

# %%
mean_gdp=np.mean(df_pop_gdp_all['gdp_percap'].values)
df_pop_gdp_all['gdp_class']= df_pop_gdp_all['gdp_percap'].apply(lambda x: 1 if x >= mean_gdp else 2)
df_pop_gdp_all
# Out:
#            Nation iso_code3  Year  population_gnrl_urban  \
# 0     Afghanistan       AFG  2011           7.212518e+06
# 1     Afghanistan       AFG  2012           7.528589e+06
# 2     Afghanistan       AFG  2013           7.865068e+06
# 3     Afghanistan       AFG  2014           8.204880e+06
# 4     Afghanistan       AFG  2015           8.535606e+06
# ...           ...       ...   ...                    ...
# 7275     Zimbabwe       ZWE  2046           5.352032e+06
# 7276     Zimbabwe       ZWE  2047           5.384492e+06
# 7277     Zimbabwe       ZWE  2048           5.416953e+06
# 7278     Zimbabwe       ZWE  2049           5.449414e+06
# 7279     Zimbabwe       ZWE  2050           5.481874e+06
#
#       population_gnrl_rural  gdp_mmm_usd  gdp_percap  gdp_class
# 0              2.290489e+07    35.369178    0.000001          2
# 1              2.363279e+07    38.085386    0.000001          2
# 2              2.440452e+07    40.801594    0.000001          2
# ...

# %%
mypath='../row_data'
files_in_row_data = [f for f in os.listdir(mypath)]
files_in_row_data
# Out:
# ['Ecuador_all_frac_scoe_heat_energy_residential.csv',
#  '.DS_Store',
#  'frac_scoe_heat_energy_residential_all_Bra_2015.csv',
#  'frac_scoe_heat_energy_proportion.xlsx',
#  'IEA - Energy Efficiency Indicators database - Extended (December 2022).xlsb',
#  'Mexico_all_frac.csv',
#  'Mexico_all_frac_scoe_heat_energy_residential.csv',
#  'Ecuador_all_frac.csv',
#  'frac_scoe_heat_energy_residential_all.csv',
#  'frac_scoe_heat_energy_residential_coal_Bra_2015.csv',
#  'Chile_all_frac_scoe_heat_energy_residential.csv',
#  'WorldEnergyBalancesHighlights2021.xlsx',
#  'Complete_IEA',
#  'Brazil_all_frac_scoe_heat_energy_residential.csv',
#  'Countries_ISO3.csv']

# %%
mypath=grandparentdir
scoe_vars = sorted([f for f in os.listdir(mypath) if f.startswith('frac_scoe_')])
scoe_vars
# Out:
# ['frac_scoe_heat_energy_commercial_municipal_coal',
#  'frac_scoe_heat_energy_commercial_municipal_diesel',
#  'frac_scoe_heat_energy_commercial_municipal_electricity',
#  'frac_scoe_heat_energy_commercial_municipal_gasoline',
#  'frac_scoe_heat_energy_commercial_municipal_hydrocarbon_gas_liquids',
#  'frac_scoe_heat_energy_commercial_municipal_hydrogen',
#  'frac_scoe_heat_energy_commercial_municipal_kerosene',
#  'frac_scoe_heat_energy_commercial_municipal_natural_gas',
#  'frac_scoe_heat_energy_commercial_municipal_solid_biomass',
#  'frac_scoe_heat_energy_other_se_coal',
#  'frac_scoe_heat_energy_other_se_diesel',
#  'frac_scoe_heat_energy_other_se_electricity',
#  'frac_scoe_heat_energy_other_se_gasoline',
#  'frac_scoe_heat_energy_other_se_hydrocarbon_gas_liquids',
#  'frac_scoe_heat_energy_other_se_hydrogen',
#  'frac_scoe_heat_energy_other_se_kerosene',
#  'frac_scoe_heat_energy_other_se_natural_gas',
#  'frac_scoe_heat_energy_other_se_solid_biomass',
# ...

# %%
# df_WEBH2021=pd.read_excel('../row_data/WorldEnergyBalancesHighlights2021.xlsx',sheet_name=3)

df_energy=pd.read_excel('../row_data/IEA - Energy Efficiency Indicators database - Extended (December 2022).xlsb',
                        engine='pyxlsb',sheet_name='Residential - Energy',skiprows=[0])
df_energy=df_energy.replace('..',0)
df_energy
# Out:
#         Country            End use  \
# 0     Australia  Total Residential
# 1     Australia  Total Residential
# 2     Australia  Total Residential
# 3     Australia  Total Residential
# 4     Australia  Total Residential
# ...         ...                ...
# 4408    Uruguay      Non-specified
# 4409    Uruguay      Non-specified
# 4410    Uruguay      Non-specified
# 4411    Uruguay      Non-specified
# 4412    Uruguay      Non-specified
#
#                                                 Product    2000    2001  \
# 0     Oil and oil products (PJ)                     ...   14.63   14.35
# 1     Gas (PJ)                                      ...  104.84  107.69
# 2     Coal and coal products (PJ)                   ...    0.00    0.00
# 3     Biofuels and waste (PJ)                       ...   80.60   79.50
# 4     Heat (PJ)                                     ...    0.00    0.00
# ...                                                 ...     ...     ...
# ...

# %%
# heat_enduse=['Residential space heating','Residential cooking','Clothes dryers']
heat_enduse=['Total Residential']

df_energy_heat=df_energy[df_energy['End use'].isin(heat_enduse)]


df_energy_heat=df_energy_heat.replace('Czech Republic','Czechia')
df_energy_heat=df_energy_heat.replace('Korea','Korea, Rep.')
df_energy_heat=df_energy_heat.replace('Republic of Türkiye','Turkey')
df_energy_heat=df_energy_heat.replace('Hong Kong (China)','Hong Kong SAR, China')
df_energy_heat=df_energy_heat.replace('Republic of Moldova','Moldova')
df_energy_heat=df_energy_heat.replace('Republic of North Macedonia','North Macedonia')

# df_energy_heat['Product'].unique()

Products=['Oil and oil products (PJ)',
       'Gas (PJ)',
       'Coal and coal products (PJ)',
       'Biofuels and waste (PJ)',
       'Heat (PJ)',
       'Electricity (PJ)',
       'Other sources (PJ)',
       'Total final energy use (PJ)']
df_energy_heat[df_energy_heat['Country']=='Albania']
# Out:
#       Country            End use  \
# 3021  Albania  Total Residential
# 3022  Albania  Total Residential
# 3023  Albania  Total Residential
# 3024  Albania  Total Residential
# 3025  Albania  Total Residential
# 3026  Albania  Total Residential
# 3027  Albania  Total Residential
# 3028  Albania  Total Residential
#
#                                                 Product   2000   2001   2002  \
# 3021  Oil and oil products (PJ)                     ...   1.89   2.03   7.44
# 3022  Gas (PJ)                                      ...   0.00   0.00   0.00
# 3023  Coal and coal products (PJ)                   ...   0.00   0.00   0.00
# 3024  Biofuels and waste (PJ)                       ...   4.86   4.82   8.79
# 3025  Heat (PJ)                                     ...   0.08   0.11   0.08
# 3026  Electricity (PJ)                              ...   8.87   8.66   8.46
# 3027  Other sources (PJ)                            ...   0.05   0.06   0.02
# ...

# %%
# df_energy_total=df_energy[df_energy['End use'].str.startswith('Total Residential')]
# df_energy_total=df_energy_total.replace('Czech Republic','Czechia')
# df_energy_total=df_energy_total.replace('Korea','Korea, Rep.')
# df_energy_total=df_energy_total.replace('Republic of Türkiye','Turkey')
# df_energy_total=df_energy_total.replace('Hong Kong (China)','Hong Kong SAR, China')
# df_energy_total=df_energy_total.replace('Republic of Moldova','Moldova')
# df_energy_total=df_energy_total.replace('Republic of North Macedonia','North Macedonia')
# # df_energy_total=df_energy_total.replace('Korea','Korea, Rep.')
# # df_energy_total=df_energy_total.replace('Korea','Korea, Rep.')

# df_energy_heat=df_energy_total
# df_energy_heat

# %%
Products=['Oil and oil products (PJ)',
       'Gas (PJ)',
       'Coal and coal products (PJ)',
       'Biofuels and waste (PJ)',
       'Heat (PJ)',
       'Electricity (PJ)',
       'Other sources (PJ)',
       'Total final energy use (PJ)']

# %%
nation_enduse = df_energy_heat['Country'].values
nation_pop_gdp_all=df_pop_gdp_all['Nation'].unique()

nation_pop_gdp_enduse = sorted(set(nation_pop_gdp_all).intersection(set(nation_enduse)))
years_hist = range(2011,2019+1)

c_y = []
for c in nation_pop_gdp_enduse:
    for y in years_hist:
        c_y.append([c,y])

df_energy_products=pd.DataFrame(c_y,columns=['Nation','Year'])
      
for product in Products:
    
    df_energy_products[product]=0
    
    for c in nation_pop_gdp_enduse:
        for y in years_hist:
            prod_val=0
            for end_use in heat_enduse:
                try:
                    prod_val+=df_energy_heat[(df_energy_heat['Product'].str.startswith(product))&
                              (df_energy_heat['Country']==c)&
                            (df_energy_heat['End use']==end_use)][y].values[0]
                # some End Use does not have all products specified, those are taken to be 0 by passing
                except:
                    pass
            df_energy_products.loc[(df_energy_products['Nation']==c)&
                                  (df_energy_products['Year']==y),product]=prod_val
    
df_energy_products
# Out:
#       Nation  Year  Oil and oil products (PJ)  Gas (PJ)  \
# 0    Albania  2011                       3.04      0.00
# 1    Albania  2012                       3.17      0.00
# 2    Albania  2013                       3.08      0.00
# 3    Albania  2014                       3.58      0.00
# 4    Albania  2015                       3.40      0.00
# ..       ...   ...                        ...       ...
# 481  Uruguay  2015                       5.15      0.75
# 482  Uruguay  2016                       5.13      0.76
# 483  Uruguay  2017                       5.05      0.74
# 484  Uruguay  2018                       5.08      0.77
# 485  Uruguay  2019                       5.33      0.93
#
#      Coal and coal products (PJ)  Biofuels and waste (PJ)  Heat (PJ)  \
# 0                            0.0                     6.45        0.0
# 1                            0.0                     6.73        0.0
# 2                            0.0                     6.20        0.0
# ...

# %%
for c in df_energy_products['Nation'].unique():
    for y in df_energy_products['Year'].unique():
        for product in Products:
            prod_val=df_energy_products.loc[(df_energy_products['Nation']==c)&
                                  (df_energy_products['Year']==y),'Total final energy use (PJ)'].values[0]
            if prod_val==0:
                val=np.mean(df_energy_products[df_energy_products['Nation']==c][product].values)
                
                df_energy_products.loc[(df_energy_products['Nation']==c)&
                                  (df_energy_products['Year']==y),product]=val
df_energy_products
# Out:
#       Nation  Year  Oil and oil products (PJ)  Gas (PJ)  \
# 0    Albania  2011                       3.04      0.00
# 1    Albania  2012                       3.17      0.00
# 2    Albania  2013                       3.08      0.00
# 3    Albania  2014                       3.58      0.00
# 4    Albania  2015                       3.40      0.00
# ..       ...   ...                        ...       ...
# 481  Uruguay  2015                       5.15      0.75
# 482  Uruguay  2016                       5.13      0.76
# 483  Uruguay  2017                       5.05      0.74
# 484  Uruguay  2018                       5.08      0.77
# 485  Uruguay  2019                       5.33      0.93
#
#      Coal and coal products (PJ)  Biofuels and waste (PJ)  Heat (PJ)  \
# 0                            0.0                     6.45        0.0
# 1                            0.0                     6.73        0.0
# 2                            0.0                     6.20        0.0
# ...

# %%
#Drop countries if all values are 0
# for c in df_energy_products['Nation'].unique():
#     val=0
#     for product in Products:
#         val+=np.mean(df_energy_products[df_energy_products['Nation']==c][product].values)
#     if val==0:
#         df_energy_products=df_energy_products.drop(df_energy_products[df_energy_products['Nation']==c].index)

df_energy_products['Nation'].unique()
# Out:
# array(['Albania', 'Argentina', 'Australia', 'Austria', 'Azerbaijan',
#        'Belarus', 'Belgium', 'Bosnia and Herzegovina', 'Brazil',
#        'Bulgaria', 'Canada', 'Chile', 'Colombia', 'Croatia', 'Cyprus',
#        'Denmark', 'Estonia', 'Finland', 'France', 'Georgia', 'Germany',
#        'Greece', 'Hong Kong SAR, China', 'Hungary', 'Ireland', 'Italy',
#        'Japan', 'Korea, Rep.', 'Latvia', 'Lithuania', 'Luxembourg',
#        'Malta', 'Mexico', 'Moldova', 'Morocco', 'Netherlands',
#        'New Zealand', 'North Macedonia', 'Norway', 'Poland', 'Portugal',
#        'Romania', 'Serbia', 'Slovak Republic', 'Slovenia', 'South Africa',
#        'Spain', 'Sweden', 'Switzerland', 'Turkey', 'Ukraine',
#        'United Kingdom', 'United States', 'Uruguay'], dtype=object)

# %%
# #  frac_scoe_X_coal : [Coal and coal products (PJ)      ]
# #  frac_scoe_X_diesel : [0.4*Oil and oil products (PJ)      ]
# #  frac_scoe_X_electricity : [Electricity (PJ)      ]
# #  frac_scoe_X_gas_petroleum_liquid:  [0.4*Oil and oil products (PJ)      ]
# #  frac_scoe_X_gasoline :  [0.1*Oil and oil products (PJ)      ]
# #  frac_scoe_X_hydrocarbon_gas_liquids :  [0.1*Oil and oil products (PJ)      ]
# #  frac_scoe_X_hydrogen : 0
# #  frac_scoe_X_kerosene:  [Other sources (PJ)        ]
# #  frac_scoe_X_natural_gas : [Gas (PJ) + Heat (PJ)              ]
# #  frac_scoe_X_solid_biomass : [Biofuels and waste (PJ)   ]

# cors_walk_dict={'frac_scoe_heat_energy_residential_coal':[(1,'Coal and coal products (PJ)')],
# 'frac_scoe_heat_energy_residential_diesel': [(0.4,'Oil and oil products (PJ)')],
# 'frac_scoe_heat_energy_residential_electricity':[(1,'Electricity (PJ)')],
# 'frac_scoe_heat_energy_residential_gas_petroleum_liquid':[(0.4,'Oil and oil products (PJ)')],
# 'frac_scoe_heat_energy_residential_gasoline':[(0.1,'Oil and oil products (PJ)')],
# 'frac_scoe_heat_energy_residential_hydrocarbon_gas_liquids':[(0.1,'Oil and oil products (PJ)')],
# 'frac_scoe_heat_energy_residential_hydrogen':[(0,'Oil and oil products (PJ)')],
# 'frac_scoe_heat_energy_residential_kerosene':[(0.4,'Other sources (PJ)')],
# 'frac_scoe_heat_energy_residential_natural_gas' [(1,'Gas (PJ)'),(1,'Heat (PJ)')],
# 'frac_scoe_heat_energy_residential_solid_biomass':[(1,'Biofuels and waste (PJ)')]}

# for c in df_energy_products['Nation'].unique():
#     for y in df_energy_products['Year'].unique():
        
#         total_energy=0
        
#         for ssp_var in cors_walk_dict.keys():    
#             for (frac,product) in cors_walk_dict[ssp_var]:
                
#                 total_energy+=frac*df_energy_products.loc[(df_energy_products['Nation']==c)&
#                                   (df_energy_products['Year']==y),product].values[0]
                
#         df_energy_products.loc[(df_energy_products['Nation']==c)&
#                                   (df_energy_products['Year']==y),'Pseudo Total (PJ)']=total_energy
        
#         for ssp_var in cors_walk_dict.keys():
#             var_energy=0
#             for (frac,product) in cors_walk_dict[ssp_var]:
                
#                 var_energy+=frac*df_energy_products.loc[(df_energy_products['Nation']==c)&
#                                   (df_energy_products['Year']==y),product].values[0]
#             total_ener=df_energy_products.loc[(df_energy_products['Nation']==c)&
#                                   (df_energy_products['Year']==y),'Pseudo Total (PJ)'].values[0]
                
#             df_energy_products.loc[(df_energy_products['Nation']==c)&
#                               (df_energy_products['Year']==y),ssp_var]=var_energy/total_ener
        
        
        
        
# df_energy_products['frac_scoe_heat_energy_residential_coal']=df_energy_products.apply(
# lambda row:
# row['Coal and coal products (PJ)'] / 
# (row['Coal and coal products (PJ)']+0.4*row['Oil and oil products (PJ)']+row['Electricity (PJ)']
# +0.4*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']
# +row['Other sources (PJ)']+row['Gas (PJ)']+row['Heat (PJ)']+row['Biofuels and waste (PJ)']
# ) if (row['Coal and coal products (PJ)']+0.4*row['Oil and oil products (PJ)']+row['Electricity (PJ)']
# +0.4*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']
# +row['Other sources (PJ)']+row['Gas (PJ)']+row['Heat (PJ)']+row['Biofuels and waste (PJ)']
# )!=0 else 0 , axis=1)

# df_energy_products['frac_scoe_heat_energy_residential_diesel']=df_energy_products.apply(
# lambda row:
# 0.4*row['Oil and oil products (PJ)'] / 
# (row['Coal and coal products (PJ)']+0.4*row['Oil and oil products (PJ)']+row['Electricity (PJ)']
# +0.4*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']
# +row['Other sources (PJ)']+row['Gas (PJ)']+row['Heat (PJ)']+row['Biofuels and waste (PJ)']
# ) if (row['Coal and coal products (PJ)']+0.4*row['Oil and oil products (PJ)']+row['Electricity (PJ)']
# +0.4*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']
# +row['Other sources (PJ)']+row['Gas (PJ)']+row['Heat (PJ)']+row['Biofuels and waste (PJ)']
# )!=0 else 0 ,axis=1)

# df_energy_products['frac_scoe_heat_energy_residential_electricity']=df_energy_products.apply(
# lambda row:
# row['Electricity (PJ)'] / 
# (row['Coal and coal products (PJ)']+0.4*row['Oil and oil products (PJ)']+row['Electricity (PJ)']
# +0.4*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']
# +row['Other sources (PJ)']+row['Gas (PJ)']+row['Heat (PJ)']+row['Biofuels and waste (PJ)']
# ) if (row['Coal and coal products (PJ)']+0.4*row['Oil and oil products (PJ)']+row['Electricity (PJ)']
# +0.4*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']
# +row['Other sources (PJ)']+row['Gas (PJ)']+row['Heat (PJ)']+row['Biofuels and waste (PJ)']
# )!=0 else 0 ,axis=1)

# df_energy_products['frac_scoe_heat_energy_residential_gas_petroleum_liquid']=df_energy_products.apply(
# lambda row:
# 0.4*row['Oil and oil products (PJ)'] / 
# (row['Coal and coal products (PJ)']+0.4*row['Oil and oil products (PJ)']+row['Electricity (PJ)']
# +0.4*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']
# +row['Other sources (PJ)']+row['Gas (PJ)']+row['Heat (PJ)']+row['Biofuels and waste (PJ)']
# ) if (row['Coal and coal products (PJ)']+0.4*row['Oil and oil products (PJ)']+row['Electricity (PJ)']
# +0.4*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']
# +row['Other sources (PJ)']+row['Gas (PJ)']+row['Heat (PJ)']+row['Biofuels and waste (PJ)']
# )!=0 else 0 ,axis=1)

# df_energy_products['frac_scoe_heat_energy_residential_gasoline']=df_energy_products.apply(
# lambda row:
# 0.1*row['Oil and oil products (PJ)'] / 
# (row['Coal and coal products (PJ)']+0.4*row['Oil and oil products (PJ)']+row['Electricity (PJ)']
# +0.4*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']
# +row['Other sources (PJ)']+row['Gas (PJ)']+row['Heat (PJ)']+row['Biofuels and waste (PJ)']
# ) if (row['Coal and coal products (PJ)']+0.4*row['Oil and oil products (PJ)']+row['Electricity (PJ)']
# +0.4*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']
# +row['Other sources (PJ)']+row['Gas (PJ)']+row['Heat (PJ)']+row['Biofuels and waste (PJ)']
# )!=0 else 0 ,axis=1)

# df_energy_products['frac_scoe_heat_energy_residential_hydrocarbon_gas_liquids']=df_energy_products.apply(
# lambda row:
# 0.1*row['Oil and oil products (PJ)'] / 
# (row['Coal and coal products (PJ)']+0.4*row['Oil and oil products (PJ)']+row['Electricity (PJ)']
# +0.4*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']
# +row['Other sources (PJ)']+row['Gas (PJ)']+row['Heat (PJ)']+row['Biofuels and waste (PJ)']
# ) if (row['Coal and coal products (PJ)']+0.4*row['Oil and oil products (PJ)']+row['Electricity (PJ)']
# +0.4*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']
# +row['Other sources (PJ)']+row['Gas (PJ)']+row['Heat (PJ)']+row['Biofuels and waste (PJ)']
# )!=0 else 0 ,axis=1)

# df_energy_products['frac_scoe_heat_energy_residential_hydrogen']=df_energy_products.apply(
# lambda row:
# 0*row['Oil and oil products (PJ)'] / 
# (row['Coal and coal products (PJ)']+0.4*row['Oil and oil products (PJ)']+row['Electricity (PJ)']
# +0.4*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']
# +row['Other sources (PJ)']+row['Gas (PJ)']+row['Heat (PJ)']+row['Biofuels and waste (PJ)']
# ) if (row['Coal and coal products (PJ)']+0.4*row['Oil and oil products (PJ)']+row['Electricity (PJ)']
# +0.4*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']
# +row['Other sources (PJ)']+row['Gas (PJ)']+row['Heat (PJ)']+row['Biofuels and waste (PJ)']
# )!=0 else 0 ,axis=1)

# df_energy_products['frac_scoe_heat_energy_residential_kerosene']=df_energy_products.apply(
# lambda row:
# row['Other sources (PJ)']/ 
# (row['Coal and coal products (PJ)']+0.4*row['Oil and oil products (PJ)']+row['Electricity (PJ)']
# +0.4*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']
# +row['Other sources (PJ)']+row['Gas (PJ)']+row['Heat (PJ)']+row['Biofuels and waste (PJ)']
# ) if (row['Coal and coal products (PJ)']+0.4*row['Oil and oil products (PJ)']+row['Electricity (PJ)']
# +0.4*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']
# +row['Other sources (PJ)']+row['Gas (PJ)']+row['Heat (PJ)']+row['Biofuels and waste (PJ)']
# )!=0 else 0 ,axis=1)

# df_energy_products['frac_scoe_heat_energy_residential_natural_gas']=df_energy_products.apply(
# lambda row:
# (row['Gas (PJ)']+row['Heat (PJ)'])/ 
# (row['Coal and coal products (PJ)']+0.4*row['Oil and oil products (PJ)']+row['Electricity (PJ)']
# +0.4*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']
# +row['Other sources (PJ)']+row['Gas (PJ)']+row['Heat (PJ)']+row['Biofuels and waste (PJ)']
# ) if (row['Coal and coal products (PJ)']+0.4*row['Oil and oil products (PJ)']+row['Electricity (PJ)']
# +0.4*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']
# +row['Other sources (PJ)']+row['Gas (PJ)']+row['Heat (PJ)']+row['Biofuels and waste (PJ)']
# )!=0 else 0 ,axis=1)

# df_energy_products['frac_scoe_heat_energy_residential_solid_biomass']=df_energy_products.apply(
# lambda row:
# row['Biofuels and waste (PJ)']/ 
# (row['Coal and coal products (PJ)']+0.4*row['Oil and oil products (PJ)']+row['Electricity (PJ)']
# +0.4*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']
# +row['Other sources (PJ)']+row['Gas (PJ)']+row['Heat (PJ)']+row['Biofuels and waste (PJ)']) if (row['Coal and coal products (PJ)']+0.4*row['Oil and oil products (PJ)']+row['Electricity (PJ)']
# +0.4*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']+0.1*row['Oil and oil products (PJ)']
# +row['Other sources (PJ)']+row['Gas (PJ)']+row['Heat (PJ)']+row['Biofuels and waste (PJ)']
# )!=0 else 0 
# ,axis=1)

# df_energy_products

# %%
# Cross Walk with IEA Fuel products

cross_walk_dict={'frac_scoe_heat_energy_residential_coal':[(1,'Coal and coal products (PJ)')],
'frac_scoe_heat_energy_residential_diesel': [(0.8,'Oil and oil products (PJ)')],
'frac_scoe_heat_energy_residential_electricity':[(0.1,'Electricity (PJ)')],
'frac_scoe_heat_energy_residential_gasoline':[(0.1,'Oil and oil products (PJ)')],
'frac_scoe_heat_energy_residential_hydrocarbon_gas_liquids':[(1,'Other sources (PJ)')],
'frac_scoe_heat_energy_residential_hydrogen':[(0,'Oil and oil products (PJ)')],
'frac_scoe_heat_energy_residential_kerosene':[(0.1,'Oil and oil products (PJ)')],
'frac_scoe_heat_energy_residential_natural_gas': [(1,'Gas (PJ)'),(1,'Heat (PJ)')],
'frac_scoe_heat_energy_residential_solid_biomass':[(1,'Biofuels and waste (PJ)')]}

for c in df_energy_products['Nation'].unique():
    for y in df_energy_products['Year'].unique():
        
        total_energy=0
        
        for ssp_var in cross_walk_dict.keys():    
            for (frac,product) in cross_walk_dict[ssp_var]:
                
                total_energy+=frac*df_energy_products.loc[(df_energy_products['Nation']==c)&
                                  (df_energy_products['Year']==y),product].values[0]
                
        df_energy_products.loc[(df_energy_products['Nation']==c)&
                                  (df_energy_products['Year']==y),'Pseudo Total (PJ)']=total_energy
        
        for ssp_var in cross_walk_dict.keys():
            var_energy=0
            for (frac,product) in cross_walk_dict[ssp_var]:
                
                var_energy+=frac*df_energy_products.loc[(df_energy_products['Nation']==c)&
                                  (df_energy_products['Year']==y),product].values[0]
            total_ener=df_energy_products.loc[(df_energy_products['Nation']==c)&
                                  (df_energy_products['Year']==y),'Pseudo Total (PJ)'].values[0]
            if  total_ener!=0:   
                df_energy_products.loc[(df_energy_products['Nation']==c)&
                              (df_energy_products['Year']==y),ssp_var]=var_energy/total_ener
            else:
                df_energy_products.loc[(df_energy_products['Nation']==c)&
                              (df_energy_products['Year']==y),ssp_var]=0
df_energy_products
# Out:
#       Nation  Year  Oil and oil products (PJ)  Gas (PJ)  \
# 0    Albania  2011                       3.04      0.00
# 1    Albania  2012                       3.17      0.00
# 2    Albania  2013                       3.08      0.00
# 3    Albania  2014                       3.58      0.00
# 4    Albania  2015                       3.40      0.00
# ..       ...   ...                        ...       ...
# 481  Uruguay  2015                       5.15      0.75
# 482  Uruguay  2016                       5.13      0.76
# 483  Uruguay  2017                       5.05      0.74
# 484  Uruguay  2018                       5.08      0.77
# 485  Uruguay  2019                       5.33      0.93
#
#      Coal and coal products (PJ)  Biofuels and waste (PJ)  Heat (PJ)  \
# 0                            0.0                     6.45        0.0
# 1                            0.0                     6.73        0.0
# 2                            0.0                     6.20        0.0
# ...

# %%
df_energy_products_gdp_class=df_energy_products.merge(df_pop_gdp_all[['Nation','Year','gdp_mmm_usd','gdp_class']],on=['Nation','Year'])
# df_energy_products_gdp_class.filter(regex='^frac')
df_energy_products_gdp_class
# Out:
#       Nation  Year  Oil and oil products (PJ)  Gas (PJ)  \
# 0    Albania  2011                       3.04      0.00
# 1    Albania  2012                       3.17      0.00
# 2    Albania  2013                       3.08      0.00
# 3    Albania  2014                       3.58      0.00
# 4    Albania  2015                       3.40      0.00
# ..       ...   ...                        ...       ...
# 481  Uruguay  2015                       5.15      0.75
# 482  Uruguay  2016                       5.13      0.76
# 483  Uruguay  2017                       5.05      0.74
# 484  Uruguay  2018                       5.08      0.77
# 485  Uruguay  2019                       5.33      0.93
#
#      Coal and coal products (PJ)  Biofuels and waste (PJ)  Heat (PJ)  \
# 0                            0.0                     6.45        0.0
# 1                            0.0                     6.73        0.0
# 2                            0.0                     6.20        0.0
# ...

# %%
df_energy_products_gdp_class_1=df_energy_products_gdp_class[df_energy_products_gdp_class['gdp_class']==1]
df_energy_products_gdp_class_2=df_energy_products_gdp_class[df_energy_products_gdp_class['gdp_class']==2]

nation_gdp_class_1=df_pop_gdp_all[df_pop_gdp_all['gdp_class']==1]['Nation'].unique()
nation_gdp_class_2=df_pop_gdp_all[df_pop_gdp_all['gdp_class']==2]['Nation'].unique()


# frac_vars=[
# 'frac_scoe_heat_energy_residential_coal',
# 'frac_scoe_heat_energy_residential_diesel',
# 'frac_scoe_heat_energy_residential_electricity',
# 'frac_scoe_heat_energy_residential_gas_petroleum_liquid',
# 'frac_scoe_heat_energy_residential_gasoline',
# 'frac_scoe_heat_energy_residential_hydrocarbon_gas_liquids',
# 'frac_scoe_heat_energy_residential_hydrogen',
# 'frac_scoe_heat_energy_residential_kerosene',
# 'frac_scoe_heat_energy_residential_natural_gas',
# 'frac_scoe_heat_energy_residential_solid_biomass']

frac_vars=cross_walk_dict.keys()

#Class 1

mean_frac_vect=[]
for frac_var in frac_vars:
    mean_frac_vect.append(np.mean(df_energy_products_gdp_class_1[frac_var].values))
    
class_1_mean_val_df=pd.DataFrame([mean_frac_vect],columns=frac_vars)

# define a custom function to normalize the row values
def normalize(row):
#     norm = np.linalg.norm(row)
    norm = np.sum(row)
    if norm == 0:
        return row
    else:
        return row / norm

# apply the custom function to each row of the DataFrame
class_1_mean_val_df = class_1_mean_val_df.apply(normalize, axis=1)

print( class_1_mean_val_df.apply(sum, axis=1))

class_1_mean_val_df['gpd_class']=1

class_1_mean_val_df
# Out:
# 0    1.0
# dtype: float64
#    frac_scoe_heat_energy_residential_coal  \
# 0                                0.021014
#
#    frac_scoe_heat_energy_residential_diesel  \
# 0                                  0.175619
#
#    frac_scoe_heat_energy_residential_electricity  \
# 0                                       0.069889
#
#    frac_scoe_heat_energy_residential_gasoline  \
# 0                                    0.021952
#
#    frac_scoe_heat_energy_residential_hydrocarbon_gas_liquids  \
# 0                                            0.02696
#
#    frac_scoe_heat_energy_residential_hydrogen  \
# 0                                         0.0
#
#    frac_scoe_heat_energy_residential_kerosene  \
# 0                                    0.021952
#
#    frac_scoe_heat_energy_residential_natural_gas  \
# 0                                       0.467303
#
#    frac_scoe_heat_energy_residential_solid_biomass  gpd_class
# 0                                          0.19531          1

# %%
#Class 2

mean_frac_vect=[]
for frac_var in frac_vars:
    mean_frac_vect.append(np.mean(df_energy_products_gdp_class_2[frac_var].values))
    
class_2_mean_val_df=pd.DataFrame([mean_frac_vect],columns=frac_vars)

# define a custom function to normalize the row values
def normalize(row):
#     norm = np.linalg.norm(row)
    norm = np.sum(row)
    if norm == 0:
        return row
    else:
        return row / norm

# apply the custom function to each row of the DataFrame
class_2_mean_val_df = class_1_mean_val_df.apply(normalize, axis=1)

print( class_2_mean_val_df.apply(sum, axis=1))

class_2_mean_val_df['gpd_class']=1

class_2_mean_val_df
# Out:
# 0    1.0
# dtype: float64
#    frac_scoe_heat_energy_residential_coal  \
# 0                                0.010507
#
#    frac_scoe_heat_energy_residential_diesel  \
# 0                                  0.087809
#
#    frac_scoe_heat_energy_residential_electricity  \
# 0                                       0.034944
#
#    frac_scoe_heat_energy_residential_gasoline  \
# 0                                    0.010976
#
#    frac_scoe_heat_energy_residential_hydrocarbon_gas_liquids  \
# 0                                            0.01348
#
#    frac_scoe_heat_energy_residential_hydrogen  \
# 0                                         0.0
#
#    frac_scoe_heat_energy_residential_kerosene  \
# 0                                    0.010976
#
#    frac_scoe_heat_energy_residential_natural_gas  \
# 0                                       0.233652
#
#    frac_scoe_heat_energy_residential_solid_biomass  gpd_class
# 0                                         0.097655          1

# %%
nation_pop_gdp_all=df_pop_gdp_all['Nation'].unique()
df_pop_gdp_all_hist=df_pop_gdp_all[df_pop_gdp_all['Year']<2020].copy()
for c in nation_pop_gdp_all:
    for y in years_hist:
        for frac_var in frac_vars:
#              df_pop_gdp_all_copy[frac_var]=0
            if (c,y) in zip(df_energy_products['Nation'].values,
                            df_energy_products['Year'].values):
                
                val=df_energy_products.loc[(df_energy_products['Nation']==c)&
                                  (df_energy_products['Year']==y),frac_var].values[0]
                
                df_pop_gdp_all_hist.loc[(df_pop_gdp_all_hist['Nation']==c)&
                                  (df_pop_gdp_all_hist['Year']==y),frac_var]=val
            else:
                if c in nation_gdp_class_1:
                    df_pop_gdp_all_hist.loc[(df_pop_gdp_all_hist['Nation']==c)&
                                  (df_pop_gdp_all_hist['Year']==y),frac_var]=class_1_mean_val_df[frac_var].values[0]
                if c in nation_gdp_class_2:
                    df_pop_gdp_all_hist.loc[(df_pop_gdp_all_hist['Nation']==c)&
                                  (df_pop_gdp_all_hist['Year']==y),frac_var]=class_2_mean_val_df[frac_var].values[0]
df_pop_gdp_all_hist
# Out:
#            Nation iso_code3  Year  population_gnrl_urban  \
# 0     Afghanistan       AFG  2011           7.212518e+06
# 1     Afghanistan       AFG  2012           7.528589e+06
# 2     Afghanistan       AFG  2013           7.865068e+06
# 3     Afghanistan       AFG  2014           8.204880e+06
# 4     Afghanistan       AFG  2015           8.535606e+06
# ...           ...       ...   ...                    ...
# 7244     Zimbabwe       ZWE  2015           4.473872e+06
# 7245     Zimbabwe       ZWE  2016           4.531238e+06
# 7246     Zimbabwe       ZWE  2017           4.589452e+06
# 7247     Zimbabwe       ZWE  2018           4.650597e+06
# 7248     Zimbabwe       ZWE  2019           4.717307e+06
#
#       population_gnrl_rural  gdp_mmm_usd    gdp_percap  gdp_class  \
# 0              2.290489e+07    35.369178  1.174376e-06          2
# 1              2.363279e+07    38.085386  1.222198e-06          2
# 2              2.440452e+07    40.801594  1.264398e-06          2
# ...

# %%
nation_pop_gdp_all=df_pop_gdp_all['Nation'].unique()
df_pop_gdp_all_proj=df_pop_gdp_all[df_pop_gdp_all['Year']>=2020].copy()
for c in nation_pop_gdp_all:
    for y in range(min(years_hist),2051):
        for frac_var in frac_vars:
            
            val=df_pop_gdp_all_hist.loc[(df_pop_gdp_all_hist['Nation']==c)&
                                  (df_pop_gdp_all_hist['Year']==2019),frac_var].values[0]
            df_pop_gdp_all_proj.loc[(df_pop_gdp_all_proj['Nation']==c)&
                                  (df_pop_gdp_all_proj['Year']==y),frac_var]=val
df_pop_gdp_all_proj
# Out:
#            Nation iso_code3  Year  population_gnrl_urban  \
# 9     Afghanistan       AFG  2020           1.013149e+07
# 10    Afghanistan       AFG  2021           1.095378e+07
# 11    Afghanistan       AFG  2022           1.134045e+07
# 12    Afghanistan       AFG  2023           1.172712e+07
# 13    Afghanistan       AFG  2024           1.211379e+07
# ...           ...       ...   ...                    ...
# 7275     Zimbabwe       ZWE  2046           5.352032e+06
# 7276     Zimbabwe       ZWE  2047           5.384492e+06
# 7277     Zimbabwe       ZWE  2048           5.416953e+06
# 7278     Zimbabwe       ZWE  2049           5.449414e+06
# 7279     Zimbabwe       ZWE  2050           5.481874e+06
#
#       population_gnrl_rural  gdp_mmm_usd  gdp_percap  gdp_class  \
# 9              2.879685e+07    50.050108    0.000001          2
# 10             3.071641e+07    51.885013    0.000001          2
# 11             3.139778e+07    53.719919    0.000001          2
# ...

# %%
for ssp_var in frac_vars:
    df_pop_gdp_all_hist[['Nation','iso_code3','Year',
    ssp_var]].to_csv(grandparentdir+'/'+ssp_var+
    '/input_to_sisepuede/historical/'+ssp_var+'.csv')

    df_pop_gdp_all_proj[['Nation','iso_code3','Year',
    ssp_var]].to_csv(grandparentdir+'/'+ssp_var+
    '/input_to_sisepuede/projected/'+ssp_var+'.csv')
    
    pd.concat([df_pop_gdp_all_hist,df_pop_gdp_all_proj]).loc[(pd.concat([df_pop_gdp_all_hist,df_pop_gdp_all_proj])['Nation']=='Brazil')&
                 (pd.concat([df_pop_gdp_all_hist,df_pop_gdp_all_proj])['Year']==2015)].to_csv(grandparentdir+'/'+ssp_var+
    '/row_data/'+ssp_var[0:33]+'_all_Bra_2015.csv')
    
    pd.concat([df_pop_gdp_all_hist,df_pop_gdp_all_proj]).to_csv(grandparentdir+'/'+ssp_var+
    '/row_data/'+ssp_var[0:33]+'_all.csv')
    
    
    var_list=['Nation','Year']+list(frac_vars)


    df_all=pd.concat([df_pop_gdp_all_hist,df_pop_gdp_all_proj])

    for n in ['Ecuador','Chile','Brazil','Mexico']:
        df_all[var_list][df_all['Nation']==n].to_csv(grandparentdir+'/'+ssp_var+
    '/row_data/'+n+'_all_'+ssp_var[0:33]+'.csv')

# %%
df_pop_gdp_all_hist[['Nation',
             'Year',
             'frac_scoe_heat_energy_residential_diesel',
             'frac_scoe_heat_energy_residential_electricity']][df_pop_gdp_all_hist['Nation']=='Mexico']
# Out:
#       Nation  Year  frac_scoe_heat_energy_residential_diesel  \
# 4240  Mexico  2011                                  0.374159
# 4241  Mexico  2012                                  0.376616
# 4242  Mexico  2013                                  0.360301
# 4243  Mexico  2014                                  0.359255
# 4244  Mexico  2015                                  0.358277
# 4245  Mexico  2016                                  0.352289
# 4246  Mexico  2017                                  0.351365
# 4247  Mexico  2018                                  0.356812
# 4248  Mexico  2019                                  0.344184
#
#       frac_scoe_heat_energy_residential_electricity
# 4240                                       0.031956
# 4241                                       0.031961
# 4242                                       0.033375
# 4243                                       0.034164
# 4244                                       0.035817
# ...

# %%
frac_vars
# Out:
# dict_keys(['frac_scoe_heat_energy_residential_coal', 'frac_scoe_heat_energy_residential_diesel', 'frac_scoe_heat_energy_residential_electricity', 'frac_scoe_heat_energy_residential_gasoline', 'frac_scoe_heat_energy_residential_hydrocarbon_gas_liquids', 'frac_scoe_heat_energy_residential_hydrogen', 'frac_scoe_heat_energy_residential_kerosene', 'frac_scoe_heat_energy_residential_natural_gas', 'frac_scoe_heat_energy_residential_solid_biomass'])

# %%
# #other process not used

# def is_number(s):
#     try:
#         float(s)
#         return True
#     except ValueError:
#         return False
# nation_pop_gdp_all=df_pop_gdp_all['Nation'].unique()

# df_enduse=df_energy_total
# nation_enduse = df_enduse['Country'].values
# nation_pop_gdp_enduse = sorted(set(nation_pop_gdp_all).intersection(set(nation_enduse)))
# years_all = range(min(df_pop_gdp_all['Year'].values),2020+1)

# c_y_pop_gdp = []
# for c in nation_pop_gdp_enduse:
#     for y in years_all:
#         pop_ur = df_pop_all.loc[(df_pop_all['Nation']==c) &
#                                        (df_pop_all['Year']==y),]['population_gnrl_urban'].values[0]

#         pop_ru = df_pop_all.loc[(df_pop_all['Nation']==c) &
#                                        (df_pop_all['Year']==y),]['population_gnrl_rural'].values[0]

#         gdp = df_gdp_all.loc[(df_gdp_all['Nation']==c) & (df_gdp_all['Year']==y)]['gdp_mmm_usd'].values[0]

#         end_use = df_enduse.loc[(df_enduse['Country']==c)][y].values[0]

#         if is_number(end_use):
#             end_use=float(end_use)

#             c_y_pop_gdp.append([c,y,pop_ur,pop_ru,gdp,end_use])

# df_pop_gdp_enduse = pd.DataFrame(c_y_pop_gdp,columns=['Nation', 'Year',
#                                                    'population_gnrl_urban',
#                                                    'population_gnrl_rural',
#                                                    'gdp_mmm_usd',
#                                                     'Total Residential Total (PJ)'])

# nation_mean=[]
# for nation in df_pop_gdp_enduse['Nation'].unique():
#     values=df_pop_gdp_enduse.loc[df_pop_gdp_enduse['Nation']==nation]['Total Residential Total (PJ)'].values
#     nation_mean.append([nation,np.mean(values)])
# mean_df=pd.DataFrame(nation_mean,columns=['Nation','end_use_mean'])

# # Fill holes in present nations with the mean value
# Nations = sorted(set(df_pop_gdp_enduse['Nation'].values))

# for count in Nations:
#     for year in years_hist:
#         PJ=df_pop_gdp_enduse.loc[(df_pop_gdp_enduse['Nation'] ==count) & 
#                         (df_pop_gdp_enduse['Year']== year), 'Total Residential Total (PJ)'].values[0]
#         if PJ==0:
#             PJ=mean_df.loc[mean_df['Nation'] ==count,'end_use_mean'].values[0]
#             df_pop_gdp_enduse.loc[(df_pop_gdp_enduse['Nation'] ==count) & 
#                         (df_pop_gdp_enduse['Year']== year), 'Total Residential Total (PJ)']=PJ
            
# df_pop_gdp_enduse

# #Linear regression

# from sklearn.linear_model import Lasso 
# from sklearn.linear_model import Ridge
# from sklearn.linear_model import LinearRegression
# from sklearn.preprocessing import normalize

# X=df_pop_gdp_enduse[['population_gnrl_urban','population_gnrl_rural','gdp_mmm_usd']]
# Y=df_pop_gdp_enduse['Total Residential Total (PJ)']

# linear_model = LinearRegression()
# linear_model.fit(X,Y)

# years_hist=range(min(df_pop_gdp_enduse['Year'].values),max(df_pop_gdp_enduse['Year'].values)+1)

# years_all=range(min(df_pop_gdp_enduse['Year'].values),2051)

# ISO3 = sorted(set(df_pop_gdp_all['iso_code3'].values))


# coun_year_PJ=[]
# coun_year_dato=[]

# for iso3 in ISO3:
#     count = df_gdp_hist.loc[df_gdp_hist['iso_code3']==iso3]['Nation'].values[0]
#     for year in years_all:

#         if (count,year) in zip(df_pop_gdp_enduse['Nation'].values,df_pop_gdp_enduse['Year'].values):

#             PJ=df_pop_gdp_enduse.loc[(df_pop_gdp_enduse['Nation'] ==count) & 
#                         (df_pop_gdp_enduse['Year']== year), 'Total Residential Total (PJ)'].values[0]
#             if PJ==0:
#                 try:

#                     PJ=mean_df.loc[mean_df['Nation'] ==count,'end_use_mean'].values[0]

#                 except:

#                     X_test = df_pop_gdp_all.loc[(df_pop_gdp_all['Nation'] == count) & 
#                                     (df_pop_gdp_all['Year']== year)][['population_gnrl_urban',
#                                                                       'population_gnrl_rural',
#                                                                       'gdp_mmm_usd']]
#                     PJ =linear_model.predict(X_test)[0]
                
#         else:

#             try:

#                 PJ=mean_df.loc[mean_df['Nation'] ==count,'end_use_mean'].values[0]

#             except:

#                 X_test = df_pop_gdp_all.loc[(df_pop_gdp_all['Nation'] == count) & 
#                                 (df_pop_gdp_all['Year']== year)][['population_gnrl_urban',
#                                                                   'population_gnrl_rural',
#                                                                   'gdp_mmm_usd']]
#                 PJ =linear_model.predict(X_test)[0]

#         if PJ<0:
#             PJ=0


#         coun_year_PJ.append([count,iso3,year,PJ])

# df_enduse_complete = pd.DataFrame(coun_year_PJ,columns=['Nation','iso_code3','Year','Total Residential Total (PJ)'])

# #     df_enduse_complete.to_csv(grandparentdir+'/Complete_IEA/'+subsector+'_Total_PJ_complete'+'.csv')

# for var_name in scoe_vars:
#     direc=grandparentdir+'/'+var_name+'/row_data'+'/Complete_IEA/'
#     if  not os.path.exists(direc):
#         os.mkdir(direc)
#     df_enduse_complete.to_csv(direc+'Total_Residential_Total_PJ_complete.csv')
#     print('ready in', var_name)

# %%
# # Make GDP classes
# df_enduse_sociec=df_enduse_complete.merge(df_pop_gdp_all, on=['Nation','iso_code3','Year'])
# mean_gdp=np.mean(df_pop_gdp_enduse['gdp_mmm_usd'].values)
# df_enduse_sociec['gdp_class']= df_enduse_sociec['gdp_mmm_usd'].apply(lambda x: 1 if x >= mean_gdp else 2)
# df_enduse_sociec

# %%
# gdp_class_df = df_enduse_sociec[['Nation','Year','gdp_class']]
# gdp_class_df=gdp_class_df.drop_duplicates()
# gdp_class_df.reset_index(drop=True, inplace=True)
# gdp_class_df

# %%
# df_energy_totalproduct=df_energy[df_energy['Product'].str.startswith('Total final energy use (PJ)')]
# df_energy_totalproduct[df_energy_totalproduct['Country']=='Uruguay']

# %%
# Nations = sorted(set(df_energy_totalproduct['Country'].unique()).intersection(df_enduse_complete['Nation'].unique()))
# coun_year=[]
# for count in Nations:
#         for year in years_hist:
#             coun_year.append([count,year])
            
# merged_df=pd.DataFrame(coun_year, columns=['Nation', 'Year'])

# for end_use in [eu for eu in df_energy_totalproduct['End use'].unique() if eu !='Total Residential']:
#     df_enduse=df_energy_totalproduct[df_energy_totalproduct['End use']==end_use]
#     nation_enduse = df_enduse['Country'].values
#     years_hist = range(min(df_pop_gdp_all['Year'].values),2020+1)

#     c_y_enduse = []
#     for c in Nations:
#         for y in years_hist:

#             end_use_num = df_enduse.loc[(df_enduse['Country']==c)][y].values[0]
            
#             total=df_energy_totalproduct.loc[(df_energy_totalproduct['Country']==c)][y].values[0]
            
# #             total=df_enduse_complete[(df_enduse_complete['Nation']==c)&
# #                             (df_enduse_complete['Year']==y)]['Total Residential Total (PJ)'].values[0]
#             if total!=0:
#                 end_use_frac= end_use_num/total
#             else:
#                 end_use_frac=0

#             if is_number(end_use_num):
#                 end_use_num=float(end_use_num)

# #                 c_y_enduse.append([c,y,end_use_num,end_use_frac])

# #     df_enduse = pd.DataFrame(c_y_enduse,columns=['Nation', 'Year',end_use+'Total (PJ)',end_use+'_Fraction'])
#                 c_y_enduse.append([c,y,end_use_num])

#     df_enduse = pd.DataFrame(c_y_enduse,columns=['Nation', 'Year',end_use])

# #     nation_mean=[]
# #     for nation in df_enduse['Nation'].unique():
# #         values=df_enduse.loc[df_enduse['Nation']==nation][end_use+'Total (PJ)'].values
# #         nation_mean.append([nation,np.mean(values)])
# #     mean_df=pd.DataFrame(nation_mean,columns=['Nation','end_use_mean'])

# #     # Fill holes in present nations with the mean value
    
# #     for count in Nations:
# #         for year in years_hist:
# #             PJ=df_enduse.loc[(df_enduse['Nation'] ==count) & 
# #                             (df_enduse['Year']== year), end_use+'Total (PJ)'].values[0]
# #             if PJ==0:
# #                 PJ=mean_df.loc[mean_df['Nation'] ==count,'end_use_mean'].values[0]
# #                 df_enduse.loc[(df_enduse['Nation'] ==count) & 
# #                             (df_enduse['Year']== year), end_use+'Total (PJ)']=PJ
# #    consumpinit_scoe_gj_per_hh_residential_elec_appliances : [all but (residential space heating +residential cooking+ clothes dryers)]
# #    consumpinit_scoe_gj_per_hh_residential_heat_energy : [residential space heating +residential cooking+ clothes dryers]

#     merged_df=pd.merge(merged_df, df_enduse, on=['Nation', 'Year'])
# merged_df

# %%
# Nations = sorted(set(df_energy_totalproduct['Country'].unique()).intersection(df_enduse_complete['Nation'].unique()))
# coun_year=[]
# for count in Nations:
#         for year in years_hist:
#             coun_year.append([count,year])
            
# merged_df=pd.DataFrame(coun_year, columns=['Nation', 'Year'])

# for end_use in [eu for eu in df_energy_totalproduct['End use'].unique() if eu !='Total Residential']:
# # for end_use in df_energy_totalproduct['End use'].unique():

#     df_enduse=df_energy_totalproduct[df_energy_totalproduct['End use']==end_use]
#     nation_enduse = df_enduse['Country'].values
#     years_hist = range(min(df_pop_gdp_all['Year'].values),2020+1)

#     c_y_enduse = []
#     for c in Nations:
#         for y in years_hist:

#             end_use_num = df_enduse.loc[(df_enduse['Country']==c)][y].values[0]
            

#             if is_number(end_use_num):
#                 end_use_num=float(end_use_num)

#                 c_y_enduse.append([c,y,end_use_num])

#     df_enduse = pd.DataFrame(c_y_enduse,columns=['Nation', 'Year',end_use+'Total (PJ)'])

#     nation_mean=[]
#     for nation in df_enduse['Nation'].unique():
#         values=df_enduse.loc[df_enduse['Nation']==nation][end_use+'Total (PJ)'].values
#         nation_mean.append([nation,np.mean(values)])
#     mean_df=pd.DataFrame(nation_mean,columns=['Nation','end_use_mean'])

#     # Fill holes in present nations with the mean value
    
#     for count in Nations:
#         for year in years_hist:
#             PJ=df_enduse.loc[(df_enduse['Nation'] ==count) & 
#                             (df_enduse['Year']== year), end_use+'Total (PJ)'].values[0]
#             if PJ==0:
#                 PJ=mean_df.loc[mean_df['Nation'] ==count,'end_use_mean'].values[0]
#                 df_enduse.loc[(df_enduse['Nation'] ==count) & 
#                             (df_enduse['Year']== year), end_use+'Total (PJ)']=PJ

#     merged_df=pd.merge(merged_df, df_enduse, on=['Nation', 'Year'])


    
# for count in Nations:
#     for year in years_hist:
#         total_vect=[]
#         for end_use in [eu for eu in df_energy_totalproduct['End use'].unique() if eu !='Total Residential']:
#             merged_df

# %%
# #scoe crowss walk 
# scoe_energy_demands = {
#    consumpinit_scoe_gj_per_hh_residential_elec_appliances : [all but (residential space heating +residential cooking+ clothes dryers)]
#    consumpinit_scoe_gj_per_hh_residential_heat_energy : [residential space heating +residential cooking+ clothes dryers]
#    consumpinit_scoe_tj_per_mmmgdp_commercial_municipal_elec_appliances : (share of electric in residential [0-1.0])*0.9*[sheet: services, End use =="other building energy use" & PRoduct= "total final energy"]
#    consumpinit_scoe_tj_per_mmmgdp_commercial_municipal_heat_energy  (1- share of electri in residential)*0.9*[sheet: services, End use =="other building energy use" & PRoduct= "total final energy"]
#    consumpinit_scoe_tj_per_mmmgdp_other_se_elec_appliances :  (share of electric in residential [0-1.0])*0.1*[sheet: services, End use =="other building energy use"]
#    consumpinit_scoe_tj_per_mmmgdp_other_se_heat_energy (1-share of electric in residential [0-1.0])*0.1*[sheet: services, End use =="other building energy use"]
